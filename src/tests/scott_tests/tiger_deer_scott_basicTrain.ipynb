# %%
from magent2.environments import battle_v4, adversarial_pursuit_v4, tiger_deer_v4
from pettingzoo.utils import random_demo
import torch
import time
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from dqn_basic import DQN_Basic
from collections import namedtuple, deque
import numpy as np
# import matplotlib.pyplot as plt
# from AnimalLSTM import Animal
from Animal import Animal
from pathlib import Path
from collections import deque
import datetime, os
from metric_logger import MetricLogger
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# import magent2
# print(magent2)

# %%
# def convert_numpy_binary_to_integer(arr):
#     assert len(arr.shape) == 3
#     assert arr.shape[0] <= 8
#     arr = arr.astype(np.int32)
#     input_array_transposed = np.transpose(arr, (1, 2, 0))
#     packed_array = np.packbits(input_array_transposed, axis=-1, bitorder='little').squeeze(-1)
#     return packed_array

def convert_numpy_binary_to_integer(arr):
    assert len(arr.shape) == 3
    arr = arr.astype(np.int32)
    input_array_transposed = np.transpose(arr, (1, 2, 0))
    packed_array = np.packbits(input_array_transposed, axis=-1, bitorder='little')
    packed_array_higher = packed_array[:,:,0]
    packed_array_lower = packed_array[:,:,1]
    packed_array = packed_array_higher + packed_array_lower*256
    return packed_array

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# frame_size = (128, 128)
max_cycles = 300
# total_episodes = 50
# map_size = 30
map_size = 100

# env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', tiger_step_recover=-0.1, deer_attacked=-0.1, max_cycles=max_cycles, extra_features=False)
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='rgb_array', max_cycles=max_cycles, extra_features=True)
env.reset(seed=None)
obs_indices_to_keep = [0,1,3]

# get number of deer and tigers
number_of_deer = len([x for x in env.agents if 'deer' in x])
number_of_tigers = len([x for x in env.agents if 'tiger' in x])


# set deer data
deer_observation_shape = env.observation_spaces['deer_0'].shape
deer_observation_shape = tuple(np.roll(deer_observation_shape,1))
# deer_action_space = env.action_spaces['deer_0'].n
deer_action_space = 3
deer_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['deer_0'].n, deer_observation_shape[1], deer_observation_shape[2])


# set tiger data
tiger_observation_shape = env.observation_spaces['tiger_0'].shape
tiger_observation_shape = tuple(np.roll(tiger_observation_shape,1))
# tiger_action_space = env.action_spaces['tiger_0'].n
tiger_action_space = 6
tiger_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['tiger_0'].n, tiger_observation_shape[1], tiger_observation_shape[2])

# print outputs
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)
print("Deer Observations:", deer_observation_shape, "Tiger Observations:",tiger_observation_shape)
assert deer_observation_shape != None
assert tiger_observation_shape != None
# 'rgb_array' or 'human'
# Out:
# Number of Tigers: 25
# Number of Deer: 100
# Deer Observations: (8, 7, 7) Tiger Observations: (16, 10, 10)
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\wrappers\base.py:50: UserWarning: The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.
#   warnings.warn(
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\wrappers\base.py:64: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# ### Action Mapping
# Takes the limited actions (forward, left, right) and maps to the true actions (up, left, down, right,...)

# %%
deer_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
}
def deer_action_mapper(new_unmapped_action, prev_actual_action, size_of_actions=5):
    global deer_action_mapping
    return deer_action_mapping.get(new_unmapped_action, {}).get(prev_actual_action, np.random.choice(np.delete(np.arange(0, size_of_actions), 2)))

tiger_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
    3: {0: 5, 1: 6, 3: 7, 4: 8},
    4: {0: 6, 1: 8, 3: 5, 4: 7},
    5: {0: 7, 1: 5, 3: 8, 4: 6},
}

tiger_direction_mapping = {
    0: 0,
    1: 1,
    3: 3,
    4: 4,
    5: 0,
    6: 1,
    7: 3,
    8: 4,
}

def tiger_action_mapper(new_action, prev_action, size_of_actions=5): # slower
    global tiger_action_mapping, tiger_direction_mapping
    direction = tiger_direction_mapping.get(prev_action, 0)
    return tiger_action_mapping.get(new_action, {}).get(direction, 0)

def mask_observations(observations, prev_actual_action):
    current_position = (observations.shape[1] // 2, observations.shape[2] // 2)
    direction = tiger_direction_mapping.get(prev_actual_action, 0)
    # print(observations)
    if direction == 1:  # Up
        observations[:, current_position[0]:, :] = 0 # actually_left
    elif direction == 0:  # Left
        observations[:, :, current_position[1]:] = 0
    elif direction == 4:  # Right
        observations[:, :, :current_position[1]] = 0
    elif direction == 3:  # Down
        observations[:, :current_position[0]+1, :] = 0 # actually right
    else:
        raise ValueError("Direction mapping issue for mask observations")
    # print("direction: ", direction, " observations: ", observations)

# %%
def get_agent_type_from_agent_name(agent):
    if 'tiger' in agent:
        return 'tiger'
    return 'deer'

# %%
def generate_first_action(agentType):
    if 'tiger' in agentType:
        # action = np.random.randint(0,tiger_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 6))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 9), 2))
        actual_action = tiger_action_mapper(action, previous_actual_action)
    else:
        # action = np.random.randint(0,deer_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 3))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 5), 2))
        actual_action = deer_action_mapper(action, previous_actual_action)
    
    return action, actual_action, previous_actual_action

# %%
def change_active_model(activeDeer, activeTiger, deerCurrentSteps, tigerCurrentSteps, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger):
    if deerCurrentSteps >= total_steps_deer:
        return False, True
    if tigerCurrentSteps >= total_steps_tiger:
        return True, False
    if deerCurrentSteps//steps_to_switch_at_deer < tigerCurrentSteps//steps_to_switch_at_tiger:
        # if not activeDeer:
        #     print("Switching to Deer")
        return True, False
    if tigerCurrentSteps//steps_to_switch_at_tiger < deerCurrentSteps//steps_to_switch_at_deer:
        # if not activeTiger:
        #     print("Switching to Tiger")
        return False, True
    return activeDeer, activeTiger

# %%
def custom_reward_modifier(agentType, observation, prev_actual_action, reward, start_index_one_hot=3):
    if 'deer' not in agentType:
        return reward
    
    #############################################################
    # alignment reward
    # alignment_reward = 0.005
    alignment_reward = 0.005*5
    action_array = observation[prev_actual_action+start_index_one_hot]
    _, K, _ = observation.shape
    center = K//2
    # Assuming 'center' is the index of the center of the (K,K) section
    center_coords = np.array([center // K, center % K])
    coords = np.indices((K,K)).reshape(2,-1).T
    distances = np.linalg.norm(coords - center_coords, axis=1)
    # distances = distances
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    # Sum the values and print the result
    alignement_result = np.sum(values[np.isfinite(values)])
    alignement_result *= alignment_reward
    #############################################################
    # wall_penalty
    # wall_penalty = -0.01
    wall_penalty = -0.05
    action_array = observation[0]
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    wall_result = np.sum(values[np.isfinite(values)])
    wall_result *= wall_penalty

    return reward + alignement_result + wall_result

# %%
agent_name_to_id_dict = {str(name): index for index,name in enumerate(env.agents)}
agent_id_to_name_list = [x for x in env.agents]
def agent_name_to_id(agent_name):
    global agent_name_to_id_dict
    return agent_name_to_id_dict[agent_name]

def agent_id_to_name(id):
    global agent_id_to_name_list
    return agent_id_to_name_list[id]

# %% [markdown]
# One hot actions takes the observed actions of nearby agents and converts them to one hot actions in the observed numpy array

# %%
import numpy as np

def one_hot_actions(array, num_actions):
    # Get the shape of the input array
    K, K = array.shape

    # Create an empty output array filled with zeros
    output = np.zeros((num_actions, K, K))

    # Iterate over the range of num_actions
    for action in range(num_actions):
        # Set the corresponding elements to 1 based on the original array
        output[action, :, :] = (array == action)

    return output

# %%
import numpy as np

def get_subsection_of_env_map(array, position, size=(13, 13)):
    # Get the shape of the input array
    array_shape = array.shape

    # Create an empty output array filled with -1
    output_size = [array.shape[0]]
    output_size.extend(list(size))
    output = np.full(tuple(output_size), -1)

    # Calculate the start and end indices for the subsection
    start_row = int(position[0] - size[0] // 2)
    end_row = int(start_row + size[0])
    start_col = int(position[1] - size[1] // 2)
    end_col = int(start_col + size[1])

    # Calculate the slices for the input array and output array
    slice_row_in = slice(max(start_row, 0), min(end_row, array_shape[1]))
    slice_col_in = slice(max(start_col, 0), min(end_col, array_shape[2]))

    slice_row_out = slice(max(-start_row, 0), min(array_shape[1] - start_row, size[0]))
    slice_col_out = slice(max(-start_col, 0), min(array_shape[2] - start_col, size[1]))

    # Copy the subsection from the input array to the output array
    output[:,slice_row_out, slice_col_out] = array[:,slice_row_in, slice_col_in]

    return output

# # Example usage
# array = np.random.randint(0, 100, (2, 20, 20))
# position = (19, 0)
# sub_array = get_subsection_of_env_map(array, position, size=(11, 11))

# print(sub_array)

# %% [markdown]
# Cleans up observations by removing unncessary layers, and one hot actions.

# %%
def handle_observations(observation, obs_indices_to_keep, agent_id, env_map, num_actions):
    observation = np.transpose(observation, (2,0,1))
    observation_size = observation.shape[1]
    observation = observation[obs_indices_to_keep,:,:]
    # print(observation.shape)
    position = np.where(env_map[0,:,:] == agent_id)
    # print("Position", position)

    sub_env_map = get_subsection_of_env_map(env_map, position, size=(observation_size, observation_size))
    one_hot_actions_arr = one_hot_actions(sub_env_map[1,:,:], num_actions)
    observation = np.concatenate((observation, one_hot_actions_arr), axis=0, dtype=np.float32)
    return observation

# %% [markdown]
# ## Train Model
# ### Make Models and Loggers

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

deer_save_dir = Path("deer_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
deer_save_dir.mkdir(parents=True)

tiger_save_dir = Path("tiger_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
tiger_save_dir.mkdir(parents=True)



deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

# deer.load("deer_checkpoints\\2023-04-26T22-43-08\\animal_net_8.chkpt")
# tiger.load("tiger_checkpoints\\2023-04-26T22-43-08\\animal_net_2.chkpt")

deer_logger = MetricLogger(deer_save_dir, animal='deer')
tiger_logger = MetricLogger(tiger_save_dir, animal='tiger')


# active training flags
activeDeer = True
activeTiger = False


# Switch the training set
switching = True
steps_to_switch_at_deer = 15000
steps_to_switch_at_tiger = int((steps_to_switch_at_deer*2)//5)
total_steps_deer = 800000000
total_steps_tiger = int((total_steps_deer//3))

# divide steps to switch at to actually switch at the proper requested switching steps
# steps_to_switch_at = steps_to_switch_at//2
# if switching enabled, make sure no equivalence between active variables
if switching:
    if activeDeer == activeTiger:
        activeTiger = not activeTiger
# Out:
# Using CUDA: True
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# ### Train Basic Model Basic With ADV+ reward 3643

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:15,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            # prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            prev_observation, prev_action, prev_done, prev_actual_action = agents_prev_data[agent][0:4]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                # animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                animal.cache(prev_observation, observation, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward, info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)

#4604 basic with adv reward
# Out:
# Number of Tigers: 25
# Number of Deer: 100
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_0.chkpt at step 0
# Episode 0 - deer - Step 18047 - Epsilon 0.9954984120924412 - Mean Reward -105.627 - Mean Length 18047.0 - Mean Loss 0.001 - Mean Q Value -0.044 - Time Delta 44.053 - Time 2023-04-30T20:27:42
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_0.chkpt at step 0
# Episode 1 - tiger - Step 3006 - Epsilon 0.9992487822114308 - Mean Reward 6.0 - Mean Length 1503.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 75.837 - Time 2023-04-30T20:28:13
# Episode 2 - tiger - Step 5831 - Epsilon 0.998543311819268 - Mean Reward 7.0 - Mean Length 1943.667 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 25.331 - Time 2023-04-30T20:28:39
# Episode 3 - tiger - Step 8653 - Epsilon 0.9978390878688577 - Mean Reward 7.5 - Mean Length 2163.25 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 26.78 - Time 2023-04-30T20:29:05
# Episode 4 - tiger - Step 11924 - Epsilon 0.9970234383968144 - Mean Reward 10.0 - Mean Length 2384.8 - Mean Loss 0.001 - Mean Q Value 0.019 - Time Delta 35.409 - Time 2023-04-30T20:29:41
# Episode 5 - tiger - Step 15109 - Epsilon 0.9962298743642919 - Mean Reward 11.5 - Mean Length 2518.167 - Mean Loss 0.001 - Mean Q Value 0.031 - Time Delta 38.146 - Time 2023-04-30T20:30:19
# Episode 6 - deer - Step 44611 - Epsilon 0.9889092099756668 - Mean Reward -47.841 - Mean Length 6373.0 - Mean Loss 0.0 - Mean Q Value -0.01 - Time Delta 235.308 - Time 2023-04-30T20:31:37
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_1.chkpt at step 50000
# Episode 7 - deer - Step 64654 - Epsilon 0.983966426401434 - Mean Reward -61.956 - Mean Length 8081.75 - Mean Loss 0.0 - Mean Q Value -0.012 - Time Delta 65.688 - Time 2023-04-30T20:32:43
# Episode 8 - tiger - Step 18217 - Epsilon 0.9954561043036798 - Mean Reward 9.333 - Mean Length 2024.111 - Mean Loss 0.001 - Mean Q Value 0.031 - Time Delta 185.438 - Time 2023-04-30T20:33:24
# Episode 9 - tiger - Step 21105 - Epsilon 0.9947376443017351 - Mean Reward 9.4 - Mean Length 2110.5 - Mean Loss 0.001 - Mean Q Value 0.034 - Time Delta 37.837 - Time 2023-04-30T20:34:02
# Episode 10 - tiger - Step 24284 - Epsilon 0.9939473905287209 - Mean Reward 10.0 - Mean Length 2207.636 - Mean Loss 0.001 - Mean Q Value 0.038 - Time Delta 42.615 - Time 2023-04-30T20:34:45
# Episode 11 - tiger - Step 27496 - Epsilon 0.9931495710416821 - Mean Reward 10.25 - Mean Length 2291.333 - Mean Loss 0.001 - Mean Q Value 0.042 - Time Delta 43.029 - Time 2023-04-30T20:35:28
# Episode 12 - tiger - Step 31060 - Epsilon 0.992265068767478 - Mean Reward 11.077 - Mean Length 2389.231 - Mean Loss 0.001 - Mean Q Value 0.047 - Time Delta 44.194 - Time 2023-04-30T20:36:12
# Episode 13 - deer - Step 83717 - Epsilon 0.9792882441971893 - Mean Reward -47.516 - Mean Length 5979.786 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 268.362 - Time 2023-04-30T20:37:11
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_2.chkpt at step 100000
# Episode 14 - deer - Step 102100 - Epsilon 0.9747980055972029 - Mean Reward -53.516 - Mean Length 6806.667 - Mean Loss 0.0 - Mean Q Value -0.01 - Time Delta 57.711 - Time 2023-04-30T20:38:09
# Episode 15 - tiger - Step 34002 - Epsilon 0.9915355260403282 - Mean Reward 9.812 - Mean Length 2125.125 - Mean Loss 0.001 - Mean Q Value 0.045 - Time Delta 154.768 - Time 2023-04-30T20:38:47
# Episode 16 - tiger - Step 37004 - Epsilon 0.99079165770645 - Mean Reward 9.765 - Mean Length 2176.706 - Mean Loss 0.001 - Mean Q Value 0.048 - Time Delta 37.415 - Time 2023-04-30T20:39:24
# Episode 17 - tiger - Step 40030 - Epsilon 0.9900424071633852 - Mean Reward 9.944 - Mean Length 2223.889 - Mean Loss 0.001 - Mean Q Value 0.052 - Time Delta 38.803 - Time 2023-04-30T20:40:03
# Episode 18 - tiger - Step 42833 - Epsilon 0.989348877883474 - Mean Reward 9.947 - Mean Length 2254.368 - Mean Loss 0.002 - Mean Q Value 0.055 - Time Delta 32.367 - Time 2023-04-30T20:40:35
# Episode 19 - deer - Step 120938 - Epsilon 0.9702179870804721 - Mean Reward -50.132 - Mean Length 6046.9 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 205.073 - Time 2023-04-30T20:41:34
# Episode 20 - tiger - Step 46326 - Epsilon 0.9884853059797564 - Mean Reward 10.238 - Mean Length 2206.0 - Mean Loss 0.002 - Mean Q Value 0.055 - Time Delta 99.741 - Time 2023-04-30T20:42:15
# Episode 21 - tiger - Step 49349 - Epsilon 0.9877385403359233 - Mean Reward 10.409 - Mean Length 2243.136 - Mean Loss 0.002 - Mean Q Value 0.058 - Time Delta 34.46 - Time 2023-04-30T20:42:50
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_1.chkpt at step 50000
# Episode 22 - tiger - Step 52983 - Epsilon 0.9868415872624128 - Mean Reward 10.913 - Mean Length 2303.609 - Mean Loss 0.002 - Mean Q Value 0.061 - Time Delta 43.944 - Time 2023-04-30T20:43:34
# Episode 23 - tiger - Step 56095 - Epsilon 0.9860741229937929 - Mean Reward 11.0 - Mean Length 2337.292 - Mean Loss 0.002 - Mean Q Value 0.063 - Time Delta 45.719 - Time 2023-04-30T20:44:19
# Episode 24 - deer - Step 140585 - Epsilon 0.9654642025453295 - Mean Reward -47.421 - Mean Length 5623.4 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 226.398 - Time 2023-04-30T20:45:20
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_3.chkpt at step 150000
# Episode 25 - deer - Step 164401 - Epsilon 0.9597329069643546 - Mean Reward -52.913 - Mean Length 6323.115 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 74.303 - Time 2023-04-30T20:46:34
# Episode 26 - tiger - Step 59248 - Epsilon 0.9852971562313679 - Mean Reward 10.296 - Mean Length 2194.37 - Mean Loss 0.002 - Mean Q Value 0.061 - Time Delta 171.271 - Time 2023-04-30T20:47:11
# Episode 27 - tiger - Step 62185 - Epsilon 0.9845739672371564 - Mean Reward 10.357 - Mean Length 2220.893 - Mean Loss 0.002 - Mean Q Value 0.064 - Time Delta 35.208 - Time 2023-04-30T20:47:46
# Episode 28 - tiger - Step 65500 - Epsilon 0.9837583394821775 - Mean Reward 10.655 - Mean Length 2258.621 - Mean Loss 0.002 - Mean Q Value 0.066 - Time Delta 44.34 - Time 2023-04-30T20:48:30
# Episode 29 - tiger - Step 68664 - Epsilon 0.982980494216668 - Mean Reward 10.767 - Mean Length 2288.8 - Mean Loss 0.002 - Mean Q Value 0.069 - Time Delta 46.222 - Time 2023-04-30T20:49:16
# Episode 30 - deer - Step 186791 - Epsilon 0.9543758085139021 - Mean Reward -51.433 - Mean Length 6025.516 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 229.261 - Time 2023-04-30T20:50:24
# Episode 31 - tiger - Step 72042 - Epsilon 0.9821507175079961 - Mean Reward 10.719 - Mean Length 2251.312 - Mean Loss 0.002 - Mean Q Value 0.069 - Time Delta 105.737 - Time 2023-04-30T20:51:02
# Episode 32 - tiger - Step 75216 - Epsilon 0.9813716899362311 - Mean Reward 10.848 - Mean Length 2279.273 - Mean Loss 0.002 - Mean Q Value 0.072 - Time Delta 42.005 - Time 2023-04-30T20:51:44
# Episode 33 - tiger - Step 78405 - Epsilon 0.9805896030593653 - Mean Reward 11.059 - Mean Length 2306.029 - Mean Loss 0.002 - Mean Q Value 0.074 - Time Delta 40.889 - Time 2023-04-30T20:52:25
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_4.chkpt at step 200000
# Episode 34 - deer - Step 204418 - Epsilon 0.950179365523216 - Mean Reward -48.214 - Mean Length 5840.514 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 175.613 - Time 2023-04-30T20:53:19
# Episode 35 - deer - Step 231553 - Epsilon 0.9437553993741302 - Mean Reward -52.705 - Mean Length 6432.028 - Mean Loss 0.0 - Mean Q Value -0.009 - Time Delta 80.975 - Time 2023-04-30T20:54:40
# Episode 36 - tiger - Step 81384 - Epsilon 0.9798595807369369 - Mean Reward 10.432 - Mean Length 2199.568 - Mean Loss 0.002 - Mean Q Value 0.073 - Time Delta 169.644 - Time 2023-04-30T20:55:15
# Episode 37 - tiger - Step 84818 - Epsilon 0.9790187321675414 - Mean Reward 10.763 - Mean Length 2232.053 - Mean Loss 0.002 - Mean Q Value 0.075 - Time Delta 45.979 - Time 2023-04-30T20:56:01
# Episode 38 - tiger - Step 87849 - Epsilon 0.9782771616284656 - Mean Reward 10.897 - Mean Length 2252.538 - Mean Loss 0.002 - Mean Q Value 0.078 - Time Delta 40.687 - Time 2023-04-30T20:56:41
# Episode 39 - tiger - Step 91008 - Epsilon 0.9775048721413765 - Mean Reward 10.975 - Mean Length 2275.2 - Mean Loss 0.003 - Mean Q Value 0.08 - Time Delta 38.18 - Time 2023-04-30T20:57:19
# Episode 40 - tiger - Step 93930 - Epsilon 0.9767910654925749 - Mean Reward 10.976 - Mean Length 2290.976 - Mean Loss 0.003 - Mean Q Value 0.083 - Time Delta 33.113 - Time 2023-04-30T20:57:53
# Episode 41 - tiger - Step 97013 - Epsilon 0.9760384937442621 - Mean Reward 11.024 - Mean Length 2309.833 - Mean Loss 0.003 - Mean Q Value 0.086 - Time Delta 32.324 - Time 2023-04-30T20:58:25
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_5.chkpt at step 250000
# Episode 42 - deer - Step 257509 - Epsilon 0.9376511963296896 - Mean Reward -48.019 - Mean Length 5988.581 - Mean Loss 0.0 - Mean Q Value -0.008 - Time Delta 301.362 - Time 2023-04-30T20:59:42
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_2.chkpt at step 100000
# Episode 43 - tiger - Step 100030 - Epsilon 0.9753025941792756 - Mean Reward 10.773 - Mean Length 2273.409 - Mean Loss 0.003 - Mean Q Value 0.087 - Time Delta 108.063 - Time 2023-04-30T21:00:13
# Episode 44 - tiger - Step 103424 - Epsilon 0.9744754008110161 - Mean Reward 10.911 - Mean Length 2298.311 - Mean Loss 0.003 - Mean Q Value 0.09 - Time Delta 45.24 - Time 2023-04-30T21:00:58
# Episode 45 - tiger - Step 106437 - Epsilon 0.9737416535058075 - Mean Reward 10.957 - Mean Length 2313.848 - Mean Loss 0.003 - Mean Q Value 0.093 - Time Delta 37.054 - Time 2023-04-30T21:01:35
# Episode 46 - tiger - Step 109269 - Epsilon 0.9730524883221471 - Mean Reward 10.915 - Mean Length 2324.872 - Mean Loss 0.003 - Mean Q Value 0.096 - Time Delta 32.226 - Time 2023-04-30T21:02:07
# Episode 47 - deer - Step 280971 - Epsilon 0.9321675005818821 - Mean Reward -46.722 - Mean Length 5853.562 - Mean Loss 0.0 - Mean Q Value -0.008 - Time Delta 216.535 - Time 2023-04-30T21:03:18
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_6.chkpt at step 300000
# Episode 48 - deer - Step 302792 - Epsilon 0.9270961385404569 - Mean Reward -48.977 - Mean Length 6179.429 - Mean Loss 0.0 - Mean Q Value -0.008 - Time Delta 65.826 - Time 2023-04-30T21:04:24
# Episode 49 - tiger - Step 112610 - Epsilon 0.9722400854565886 - Mean Reward 10.58 - Mean Length 2252.2 - Mean Loss 0.003 - Mean Q Value 0.095 - Time Delta 183.569 - Time 2023-04-30T21:05:11
# Episode 50 - tiger - Step 115721 - Epsilon 0.971484219610971 - Mean Reward 10.706 - Mean Length 2269.039 - Mean Loss 0.003 - Mean Q Value 0.098 - Time Delta 45.248 - Time 2023-04-30T21:05:56
# Episode 51 - tiger - Step 118648 - Epsilon 0.9707735959754753 - Mean Reward 10.712 - Mean Length 2281.692 - Mean Loss 0.003 - Mean Q Value 0.101 - Time Delta 37.369 - Time 2023-04-30T21:06:34
# Episode 52 - tiger - Step 121715 - Epsilon 0.9700295405163651 - Mean Reward 10.792 - Mean Length 2296.509 - Mean Loss 0.003 - Mean Q Value 0.104 - Time Delta 39.817 - Time 2023-04-30T21:07:14
# Episode 53 - tiger - Step 124618 - Epsilon 0.9693257968911225 - Mean Reward 10.741 - Mean Length 2307.741 - Mean Loss 0.003 - Mean Q Value 0.106 - Time Delta 34.909 - Time 2023-04-30T21:07:48
# Episode 54 - tiger - Step 127990 - Epsilon 0.9685089994706135 - Mean Reward 10.855 - Mean Length 2327.091 - Mean Loss 0.003 - Mean Q Value 0.109 - Time Delta 46.362 - Time 2023-04-30T21:08:35
# Episode 55 - deer - Step 320392 - Epsilon 0.9230258761654371 - Mean Reward -44.947 - Mean Length 5721.286 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 305.218 - Time 2023-04-30T21:09:29
# Episode 56 - deer - Step 338765 - Epsilon 0.918795909115447 - Mean Reward -46.581 - Mean Length 5943.246 - Mean Loss 0.0 - Mean Q Value -0.008 - Time Delta 55.994 - Time 2023-04-30T21:10:25
# Episode 57 - tiger - Step 130890 - Epsilon 0.9678070848329607 - Mean Reward 10.431 - Mean Length 2256.724 - Mean Loss 0.003 - Mean Q Value 0.108 - Time Delta 156.422 - Time 2023-04-30T21:11:11
# Episode 58 - tiger - Step 133907 - Epsilon 0.9670773914681147 - Mean Reward 10.441 - Mean Length 2269.61 - Mean Loss 0.003 - Mean Q Value 0.111 - Time Delta 37.38 - Time 2023-04-30T21:11:49
# Episode 59 - tiger - Step 136699 - Epsilon 0.9664026068916423 - Mean Reward 10.467 - Mean Length 2278.317 - Mean Loss 0.003 - Mean Q Value 0.114 - Time Delta 35.097 - Time 2023-04-30T21:12:24
# Episode 60 - tiger - Step 139967 - Epsilon 0.9656133783068215 - Mean Reward 10.508 - Mean Length 2294.541 - Mean Loss 0.003 - Mean Q Value 0.116 - Time Delta 41.32 - Time 2023-04-30T21:13:05
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_7.chkpt at step 350000
# Episode 61 - deer - Step 364987 - Epsilon 0.9127924411487898 - Mean Reward -45.684 - Mean Length 5886.887 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 238.187 - Time 2023-04-30T21:14:23
# Episode 62 - tiger - Step 143121 - Epsilon 0.964852292160429 - Mean Reward 10.381 - Mean Length 2271.762 - Mean Loss 0.003 - Mean Q Value 0.117 - Time Delta 120.514 - Time 2023-04-30T21:15:06
# Episode 63 - tiger - Step 146828 - Epsilon 0.9639585293981137 - Mean Reward 10.641 - Mean Length 2294.188 - Mean Loss 0.003 - Mean Q Value 0.12 - Time Delta 44.487 - Time 2023-04-30T21:15:50
# Episode 64 - tiger - Step 149860 - Epsilon 0.9632281255994388 - Mean Reward 10.723 - Mean Length 2305.538 - Mean Loss 0.003 - Mean Q Value 0.122 - Time Delta 46.66 - Time 2023-04-30T21:16:37
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_3.chkpt at step 150000
# Episode 65 - tiger - Step 153242 - Epsilon 0.9624140603119674 - Mean Reward 10.833 - Mean Length 2321.848 - Mean Loss 0.003 - Mean Q Value 0.125 - Time Delta 45.571 - Time 2023-04-30T21:17:22
# Episode 66 - deer - Step 392459 - Epsilon 0.9065448606305493 - Mean Reward -44.797 - Mean Length 5857.597 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 259.922 - Time 2023-04-30T21:18:43
# Episode 67 - tiger - Step 156824 - Epsilon 0.9615526041877028 - Mean Reward 10.838 - Mean Length 2306.235 - Mean Loss 0.003 - Mean Q Value 0.125 - Time Delta 126.101 - Time 2023-04-30T21:19:28
# Episode 68 - tiger - Step 159955 - Epsilon 0.960800243286289 - Mean Reward 10.913 - Mean Length 2318.188 - Mean Loss 0.003 - Mean Q Value 0.128 - Time Delta 39.133 - Time 2023-04-30T21:20:07
# Episode 69 - tiger - Step 163117 - Epsilon 0.960041030717267 - Mean Reward 10.957 - Mean Length 2330.243 - Mean Loss 0.003 - Mean Q Value 0.13 - Time Delta 40.467 - Time 2023-04-30T21:20:48
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_8.chkpt at step 400000
# Episode 70 - deer - Step 412182 - Epsilon 0.9020859160055414 - Mean Reward -43.466 - Mean Length 5805.38 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 184.696 - Time 2023-04-30T21:21:48
# Episode 71 - deer - Step 428607 - Epsilon 0.8983893200181077 - Mean Reward -44.345 - Mean Length 5952.875 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 51.732 - Time 2023-04-30T21:22:40
# Episode 72 - tiger - Step 166108 - Epsilon 0.959323428273795 - Mean Reward 10.644 - Mean Length 2275.452 - Mean Loss 0.003 - Mean Q Value 0.129 - Time Delta 151.898 - Time 2023-04-30T21:23:20
# Episode 73 - tiger - Step 169575 - Epsilon 0.958492294832816 - Mean Reward 10.784 - Mean Length 2291.554 - Mean Loss 0.003 - Mean Q Value 0.131 - Time Delta 43.341 - Time 2023-04-30T21:24:03
# Episode 74 - tiger - Step 172309 - Epsilon 0.9578373891068696 - Mean Reward 10.733 - Mean Length 2297.453 - Mean Loss 0.004 - Mean Q Value 0.134 - Time Delta 36.124 - Time 2023-04-30T21:24:39
# Episode 75 - tiger - Step 175162 - Epsilon 0.957154455083925 - Mean Reward 10.737 - Mean Length 2304.763 - Mean Loss 0.004 - Mean Q Value 0.137 - Time Delta 36.242 - Time 2023-04-30T21:25:16
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_9.chkpt at step 450000
# Episode 76 - deer - Step 450596 - Epsilon 0.8934641984276324 - Mean Reward -43.172 - Mean Length 5851.896 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 222.851 - Time 2023-04-30T21:26:23
# Episode 77 - tiger - Step 178568 - Epsilon 0.9563397848585471 - Mean Reward 10.744 - Mean Length 2289.333 - Mean Loss 0.004 - Mean Q Value 0.137 - Time Delta 108.571 - Time 2023-04-30T21:27:04
# Episode 78 - tiger - Step 181577 - Epsilon 0.9556206486843998 - Mean Reward 10.785 - Mean Length 2298.443 - Mean Loss 0.004 - Mean Q Value 0.14 - Time Delta 46.339 - Time 2023-04-30T21:27:50
# Episode 79 - tiger - Step 184974 - Epsilon 0.9548094322585207 - Mean Reward 10.938 - Mean Length 2312.175 - Mean Loss 0.004 - Mean Q Value 0.142 - Time Delta 41.508 - Time 2023-04-30T21:28:32
# Episode 80 - tiger - Step 188462 - Epsilon 0.9539772012349069 - Mean Reward 11.086 - Mean Length 2326.691 - Mean Loss 0.004 - Mean Q Value 0.145 - Time Delta 44.643 - Time 2023-04-30T21:29:17
# Episode 81 - deer - Step 468177 - Epsilon 0.8895458168604535 - Mean Reward -41.818 - Mean Length 5709.476 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 228.268 - Time 2023-04-30T21:30:11
# Episode 82 - deer - Step 486888 - Epsilon 0.885394460469586 - Mean Reward -42.698 - Mean Length 5866.12 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 56.705 - Time 2023-04-30T21:31:08
# Episode 83 - tiger - Step 192043 - Epsilon 0.953123535217942 - Mean Reward 10.976 - Mean Length 2286.226 - Mean Loss 0.004 - Mean Q Value 0.143 - Time Delta 150.591 - Time 2023-04-30T21:31:47
# Episode 84 - tiger - Step 195119 - Epsilon 0.9523908648755246 - Mean Reward 11.012 - Mean Length 2295.518 - Mean Loss 0.004 - Mean Q Value 0.146 - Time Delta 43.145 - Time 2023-04-30T21:32:30
# Episode 85 - tiger - Step 198323 - Epsilon 0.9516283051432805 - Mean Reward 11.081 - Mean Length 2306.081 - Mean Loss 0.004 - Mean Q Value 0.148 - Time Delta 47.602 - Time 2023-04-30T21:33:18
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_10.chkpt at step 500000
# Episode 86 - deer - Step 512940 - Epsilon 0.8796466237776329 - Mean Reward -42.476 - Mean Length 5895.862 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 209.366 - Time 2023-04-30T21:34:37
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_4.chkpt at step 200000
# Episode 87 - tiger - Step 201276 - Epsilon 0.9509260247202814 - Mean Reward 10.943 - Mean Length 2287.227 - Mean Loss 0.004 - Mean Q Value 0.149 - Time Delta 122.266 - Time 2023-04-30T21:35:20
# Episode 88 - tiger - Step 204240 - Epsilon 0.9502216494510837 - Mean Reward 10.978 - Mean Length 2294.831 - Mean Loss 0.004 - Mean Q Value 0.151 - Time Delta 43.278 - Time 2023-04-30T21:36:03
# Episode 89 - tiger - Step 207522 - Epsilon 0.9494423122569878 - Mean Reward 11.033 - Mean Length 2305.8 - Mean Loss 0.004 - Mean Q Value 0.154 - Time Delta 38.288 - Time 2023-04-30T21:36:42
# Episode 90 - tiger - Step 210697 - Epsilon 0.9486889913411539 - Mean Reward 11.088 - Mean Length 2315.352 - Mean Loss 0.004 - Mean Q Value 0.156 - Time Delta 45.086 - Time 2023-04-30T21:37:27
# Episode 91 - deer - Step 536411 - Epsilon 0.8745001904152983 - Mean Reward -41.967 - Mean Length 5830.554 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 241.576 - Time 2023-04-30T21:38:38
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_11.chkpt at step 550000
# Episode 92 - deer - Step 560420 - Epsilon 0.8692669423356464 - Mean Reward -43.301 - Mean Length 6026.022 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 72.983 - Time 2023-04-30T21:39:51
# Episode 93 - tiger - Step 213954 - Epsilon 0.9479168356398763 - Mean Reward 10.926 - Mean Length 2276.106 - Mean Loss 0.004 - Mean Q Value 0.154 - Time Delta 192.15 - Time 2023-04-30T21:40:39
# Episode 94 - tiger - Step 216821 - Epsilon 0.9472376595917305 - Mean Reward 10.895 - Mean Length 2282.326 - Mean Loss 0.004 - Mean Q Value 0.156 - Time Delta 35.405 - Time 2023-04-30T21:41:14
# Episode 95 - tiger - Step 220099 - Epsilon 0.9464617162188176 - Mean Reward 10.958 - Mean Length 2292.698 - Mean Loss 0.004 - Mean Q Value 0.158 - Time Delta 44.335 - Time 2023-04-30T21:41:59
# Episode 96 - tiger - Step 223319 - Epsilon 0.9457001210251499 - Mean Reward 11.052 - Mean Length 2302.258 - Mean Loss 0.004 - Mean Q Value 0.16 - Time Delta 43.041 - Time 2023-04-30T21:42:42
# Episode 97 - tiger - Step 226659 - Epsilon 0.9449107909164939 - Mean Reward 11.163 - Mean Length 2312.847 - Mean Loss 0.004 - Mean Q Value 0.162 - Time Delta 45.736 - Time 2023-04-30T21:43:28
# Episode 98 - tiger - Step 229833 - Epsilon 0.9441613015093593 - Mean Reward 11.263 - Mean Length 2321.545 - Mean Loss 0.004 - Mean Q Value 0.164 - Time Delta 35.062 - Time 2023-04-30T21:44:03
# Episode 99 - deer - Step 582665 - Epsilon 0.8644461481946146 - Mean Reward -41.263 - Mean Length 5826.65 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 319.723 - Time 2023-04-30T21:45:11
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_12.chkpt at step 600000
# Episode 100 - deer - Step 604588 - Epsilon 0.8597212940760662 - Mean Reward -41.238 - Mean Length 5865.41 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 66.961 - Time 2023-04-30T21:46:18
# Episode 101 - tiger - Step 232635 - Epsilon 0.9435001480309584 - Mean Reward 11.12 - Mean Length 2296.29 - Mean Loss 0.004 - Mean Q Value 0.166 - Time Delta 170.575 - Time 2023-04-30T21:46:53
# Episode 102 - tiger - Step 236428 - Epsilon 0.942605897957008 - Mean Reward 11.3 - Mean Length 2305.97 - Mean Loss 0.004 - Mean Q Value 0.169 - Time Delta 45.868 - Time 2023-04-30T21:47:39
# Episode 103 - tiger - Step 239405 - Epsilon 0.9419046244234813 - Mean Reward 11.35 - Mean Length 2307.52 - Mean Loss 0.004 - Mean Q Value 0.173 - Time Delta 35.17 - Time 2023-04-30T21:48:14
# Episode 104 - tiger - Step 242929 - Epsilon 0.9410751717731112 - Mean Reward 11.36 - Mean Length 2310.05 - Mean Loss 0.004 - Mean Q Value 0.175 - Time Delta 46.19 - Time 2023-04-30T21:49:00
# Episode 105 - tiger - Step 245902 - Epsilon 0.9403759774344783 - Mean Reward 11.29 - Mean Length 2307.93 - Mean Loss 0.004 - Mean Q Value 0.178 - Time Delta 47.77 - Time 2023-04-30T21:49:48
# Episode 106 - tiger - Step 249484 - Epsilon 0.9395342475821433 - Mean Reward 11.52 - Mean Length 2343.75 - Mean Loss 0.004 - Mean Q Value 0.181 - Time Delta 45.907 - Time 2023-04-30T21:50:34
# Episode 107 - deer - Step 622165 - Epsilon 0.8559517515296644 - Mean Reward -38.146 - Mean Length 5575.11 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 310.507 - Time 2023-04-30T21:51:29
# Episode 108 - deer - Step 644927 - Epsilon 0.8510947898564066 - Mean Reward -39.518 - Mean Length 5802.73 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 69.411 - Time 2023-04-30T21:52:38
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_5.chkpt at step 250000
# Episode 109 - tiger - Step 252701 - Epsilon 0.9387789308414611 - Mean Reward 11.45 - Mean Length 2315.96 - Mean Loss 0.004 - Mean Q Value 0.183 - Time Delta 171.164 - Time 2023-04-30T21:53:25
# Episode 110 - tiger - Step 255910 - Epsilon 0.9380260973706881 - Mean Reward 11.43 - Mean Length 2316.26 - Mean Loss 0.004 - Mean Q Value 0.186 - Time Delta 41.763 - Time 2023-04-30T21:54:07
# Episode 111 - tiger - Step 259023 - Epsilon 0.9372963624640197 - Mean Reward 11.44 - Mean Length 2315.27 - Mean Loss 0.004 - Mean Q Value 0.189 - Time Delta 47.922 - Time 2023-04-30T21:54:55
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_13.chkpt at step 650000
# Episode 112 - deer - Step 666385 - Epsilon 0.8465413157622277 - Mean Reward -41.046 - Mean Length 6017.31 - Mean Loss 0.0 - Mean Q Value -0.006 - Time Delta 203.605 - Time 2023-04-30T21:56:02
# Episode 113 - tiger - Step 262585 - Epsilon 0.936462071472041 - Mean Reward 11.49 - Mean Length 2315.25 - Mean Loss 0.004 - Mean Q Value 0.191 - Time Delta 112.622 - Time 2023-04-30T21:56:48
# Episode 114 - tiger - Step 265654 - Epsilon 0.935743846422139 - Mean Reward 11.64 - Mean Length 2345.94 - Mean Loss 0.004 - Mean Q Value 0.195 - Time Delta 39.481 - Time 2023-04-30T21:57:27
# Episode 115 - tiger - Step 268723 - Epsilon 0.9350261722191345 - Mean Reward 11.65 - Mean Length 2347.21 - Mean Loss 0.004 - Mean Q Value 0.197 - Time Delta 44.474 - Time 2023-04-30T21:58:11
# Episode 116 - tiger - Step 272271 - Epsilon 0.9341971716167569 - Mean Reward 11.81 - Mean Length 2352.67 - Mean Loss 0.004 - Mean Q Value 0.2 - Time Delta 46.019 - Time 2023-04-30T21:58:58
# Episode 117 - deer - Step 691198 - Epsilon 0.8413062616520101 - Mean Reward -40.35 - Mean Length 5890.98 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 252.028 - Time 2023-04-30T22:00:14
# Episode 118 - tiger - Step 275524 - Epsilon 0.9334377445158055 - Mean Reward 11.74 - Mean Length 2326.91 - Mean Loss 0.004 - Mean Q Value 0.201 - Time Delta 114.837 - Time 2023-04-30T22:00:52
# Episode 119 - tiger - Step 278906 - Epsilon 0.9326488563535639 - Mean Reward 11.99 - Mean Length 2360.73 - Mean Loss 0.004 - Mean Q Value 0.205 - Time Delta 45.306 - Time 2023-04-30T22:01:38
# Episode 120 - tiger - Step 282438 - Epsilon 0.9318256907914709 - Mean Reward 11.93 - Mean Length 2361.12 - Mean Loss 0.004 - Mean Q Value 0.207 - Time Delta 46.906 - Time 2023-04-30T22:02:25
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_14.chkpt at step 700000
# Episode 121 - deer - Step 714612 - Epsilon 0.836396059788311 - Mean Reward -39.621 - Mean Length 5936.74 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 203.651 - Time 2023-04-30T22:03:37
# Episode 122 - deer - Step 740168 - Epsilon 0.8310693589608881 - Mean Reward -41.021 - Mean Length 6192.3 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 77.822 - Time 2023-04-30T22:04:55
# Episode 123 - tiger - Step 285675 - Epsilon 0.9310719157942158 - Mean Reward 11.65 - Mean Length 2295.8 - Mean Loss 0.004 - Mean Q Value 0.207 - Time Delta 198.419 - Time 2023-04-30T22:05:43
# Episode 124 - tiger - Step 288997 - Epsilon 0.9302989814768275 - Mean Reward 11.84 - Mean Length 2329.02 - Mean Loss 0.004 - Mean Q Value 0.211 - Time Delta 46.424 - Time 2023-04-30T22:06:29
# Episode 125 - tiger - Step 292444 - Epsilon 0.9294976415561882 - Mean Reward 12.07 - Mean Length 2363.49 - Mean Loss 0.004 - Mean Q Value 0.214 - Time Delta 43.749 - Time 2023-04-30T22:07:13
# Episode 126 - tiger - Step 295618 - Epsilon 0.928760377633494 - Mean Reward 12.13 - Mean Length 2363.7 - Mean Loss 0.004 - Mean Q Value 0.217 - Time Delta 45.366 - Time 2023-04-30T22:07:59
# Episode 127 - tiger - Step 298561 - Epsilon 0.9280772934205894 - Mean Reward 12.18 - Mean Length 2363.76 - Mean Loss 0.004 - Mean Q Value 0.219 - Time Delta 32.397 - Time 2023-04-30T22:08:31
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_6.chkpt at step 300000
# Episode 128 - tiger - Step 302201 - Epsilon 0.9272331271318516 - Mean Reward 12.26 - Mean Length 2367.01 - Mean Loss 0.004 - Mean Q Value 0.222 - Time Delta 43.176 - Time 2023-04-30T22:09:14
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_15.chkpt at step 750000
# Episode 129 - deer - Step 766830 - Epsilon 0.8255482862541399 - Mean Reward -38.575 - Mean Length 6024.29 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 340.718 - Time 2023-04-30T22:10:36
# Episode 130 - tiger - Step 305139 - Epsilon 0.9265523243701995 - Mean Reward 12.25 - Mean Length 2364.75 - Mean Loss 0.004 - Mean Q Value 0.224 - Time Delta 122.867 - Time 2023-04-30T22:11:17
# Episode 131 - tiger - Step 308546 - Epsilon 0.9257634693305323 - Mean Reward 12.26 - Mean Length 2365.04 - Mean Loss 0.004 - Mean Q Value 0.226 - Time Delta 43.424 - Time 2023-04-30T22:12:00
# Episode 132 - tiger - Step 311879 - Epsilon 0.9249923981153737 - Mean Reward 12.28 - Mean Length 2366.63 - Mean Loss 0.005 - Mean Q Value 0.228 - Time Delta 47.894 - Time 2023-04-30T22:12:48
# Episode 133 - tiger - Step 315024 - Epsilon 0.9242654085865886 - Mean Reward 12.29 - Mean Length 2366.19 - Mean Loss 0.005 - Mean Q Value 0.231 - Time Delta 47.489 - Time 2023-04-30T22:13:36
# Episode 134 - deer - Step 792306 - Epsilon 0.820307076911346 - Mean Reward -37.014 - Mean Length 5878.88 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 257.935 - Time 2023-04-30T22:14:54
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_16.chkpt at step 800000
# Episode 135 - deer - Step 818537 - Epsilon 0.814945307293936 - Mean Reward -35.828 - Mean Length 5869.84 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 80.783 - Time 2023-04-30T22:16:15
# Episode 136 - tiger - Step 318382 - Epsilon 0.9234898132807046 - Mean Reward 12.46 - Mean Length 2369.98 - Mean Loss 0.005 - Mean Q Value 0.233 - Time Delta 203.849 - Time 2023-04-30T22:17:00
# Episode 137 - tiger - Step 321978 - Epsilon 0.9226599689056552 - Mean Reward 12.49 - Mean Length 2371.6 - Mean Loss 0.005 - Mean Q Value 0.235 - Time Delta 46.517 - Time 2023-04-30T22:17:46
# Episode 138 - tiger - Step 325290 - Epsilon 0.9218963225490612 - Mean Reward 12.5 - Mean Length 2374.41 - Mean Loss 0.005 - Mean Q Value 0.237 - Time Delta 45.816 - Time 2023-04-30T22:18:32
# Episode 139 - tiger - Step 328664 - Epsilon 0.9211190307726151 - Mean Reward 12.59 - Mean Length 2376.56 - Mean Loss 0.005 - Mean Q Value 0.239 - Time Delta 38.129 - Time 2023-04-30T22:19:10
# Episode 140 - tiger - Step 332296 - Epsilon 0.9202830341879433 - Mean Reward 12.72 - Mean Length 2383.66 - Mean Loss 0.005 - Mean Q Value 0.241 - Time Delta 42.703 - Time 2023-04-30T22:19:53
# Episode 141 - deer - Step 842183 - Epsilon 0.8101419689641011 - Mean Reward -37.236 - Mean Length 6106.3 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 292.813 - Time 2023-04-30T22:21:07
# Episode 142 - tiger - Step 335787 - Epsilon 0.9194802074538646 - Mean Reward 12.83 - Mean Length 2387.74 - Mean Loss 0.005 - Mean Q Value 0.242 - Time Delta 121.091 - Time 2023-04-30T22:21:54
# Episode 143 - tiger - Step 338900 - Epsilon 0.9187649002729109 - Mean Reward 12.88 - Mean Length 2388.7 - Mean Loss 0.005 - Mean Q Value 0.244 - Time Delta 49.231 - Time 2023-04-30T22:22:43
# Episode 144 - tiger - Step 342061 - Epsilon 0.9180391330261971 - Mean Reward 12.85 - Mean Length 2386.37 - Mean Loss 0.005 - Mean Q Value 0.246 - Time Delta 49.663 - Time 2023-04-30T22:23:33
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_17.chkpt at step 850000
# Episode 145 - deer - Step 866996 - Epsilon 0.8051320102467745 - Mean Reward -36.714 - Mean Length 6094.87 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 222.471 - Time 2023-04-30T22:24:50
# Episode 146 - deer - Step 893678 - Epsilon 0.7997792491468775 - Mean Reward -38.087 - Mean Length 6361.69 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 81.755 - Time 2023-04-30T22:26:12
# Episode 147 - tiger - Step 345108 - Epsilon 0.9173400829136499 - Mean Reward 12.81 - Mean Length 2358.39 - Mean Loss 0.004 - Mean Q Value 0.245 - Time Delta 207.483 - Time 2023-04-30T22:27:00
# Episode 148 - tiger - Step 348079 - Epsilon 0.9166589814571977 - Mean Reward 12.93 - Mean Length 2388.1 - Mean Loss 0.005 - Mean Q Value 0.248 - Time Delta 39.644 - Time 2023-04-30T22:27:40
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_7.chkpt at step 350000
# Episode 149 - tiger - Step 351684 - Epsilon 0.9158332146138984 - Mean Reward 13.02 - Mean Length 2390.74 - Mean Loss 0.005 - Mean Q Value 0.25 - Time Delta 47.059 - Time 2023-04-30T22:28:27
# Episode 150 - tiger - Step 355003 - Epsilon 0.9150736170906208 - Mean Reward 13.04 - Mean Length 2392.82 - Mean Loss 0.005 - Mean Q Value 0.251 - Time Delta 46.95 - Time 2023-04-30T22:29:14
# Episode 151 - tiger - Step 358178 - Epsilon 0.9143475655060401 - Mean Reward 13.08 - Mean Length 2395.3 - Mean Loss 0.005 - Mean Q Value 0.253 - Time Delta 43.064 - Time 2023-04-30T22:29:57
# Episode 152 - tiger - Step 361538 - Epsilon 0.9135798359465012 - Mean Reward 13.11 - Mean Length 2398.23 - Mean Loss 0.005 - Mean Q Value 0.254 - Time Delta 47.763 - Time 2023-04-30T22:30:45
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_18.chkpt at step 900000
# Episode 153 - deer - Step 918266 - Epsilon 0.7948780846508969 - Mean Reward -35.705 - Mean Length 6154.74 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 350.784 - Time 2023-04-30T22:32:02
# Episode 154 - tiger - Step 364852 - Epsilon 0.9128232484174035 - Mean Reward 13.0 - Mean Length 2368.62 - Mean Loss 0.004 - Mean Q Value 0.252 - Time Delta 124.792 - Time 2023-04-30T22:32:50
# Episode 155 - tiger - Step 367892 - Epsilon 0.9121297662184391 - Mean Reward 13.16 - Mean Length 2399.02 - Mean Loss 0.005 - Mean Q Value 0.256 - Time Delta 37.175 - Time 2023-04-30T22:33:27
# Episode 156 - tiger - Step 371251 - Epsilon 0.911364126669345 - Mean Reward 13.37 - Mean Length 2432.61 - Mean Loss 0.005 - Mean Q Value 0.26 - Time Delta 43.985 - Time 2023-04-30T22:34:11
# Episode 157 - tiger - Step 374678 - Epsilon 0.9105836497406992 - Mean Reward 13.51 - Mean Length 2437.88 - Mean Loss 0.005 - Mean Q Value 0.261 - Time Delta 40.864 - Time 2023-04-30T22:34:52
# Episode 158 - deer - Step 941003 - Epsilon 0.7903726155719399 - Mean Reward -33.89 - Mean Length 6022.38 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 239.946 - Time 2023-04-30T22:36:02
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_19.chkpt at step 950000
# Episode 159 - deer - Step 966807 - Epsilon 0.7852903317245343 - Mean Reward -34.849 - Mean Length 6280.42 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 80.513 - Time 2023-04-30T22:37:23
# Episode 160 - tiger - Step 377737 - Epsilon 0.9098875470136576 - Mean Reward 13.31 - Mean Length 2377.7 - Mean Loss 0.004 - Mean Q Value 0.257 - Time Delta 199.51 - Time 2023-04-30T22:38:11
# Episode 161 - tiger - Step 381230 - Epsilon 0.9090933344373783 - Mean Reward 13.53 - Mean Length 2412.63 - Mean Loss 0.005 - Mean Q Value 0.261 - Time Delta 47.783 - Time 2023-04-30T22:38:59
# Episode 162 - tiger - Step 384414 - Epsilon 0.9083699839843211 - Mean Reward 13.58 - Mean Length 2412.93 - Mean Loss 0.005 - Mean Q Value 0.262 - Time Delta 47.654 - Time 2023-04-30T22:39:46
# Episode 163 - tiger - Step 387424 - Epsilon 0.9076866926064919 - Mean Reward 13.46 - Mean Length 2405.96 - Mean Loss 0.005 - Mean Q Value 0.263 - Time Delta 46.756 - Time 2023-04-30T22:40:33
# Episode 164 - tiger - Step 391177 - Epsilon 0.9068354548599848 - Mean Reward 13.59 - Mean Length 2413.17 - Mean Loss 0.005 - Mean Q Value 0.264 - Time Delta 48.407 - Time 2023-04-30T22:41:22
# Episode 165 - deer - Step 987530 - Epsilon 0.7812324588193379 - Mean Reward -34.104 - Mean Length 6225.43 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 305.055 - Time 2023-04-30T22:42:28
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_20.chkpt at step 1000000
# Episode 166 - deer - Step 1009878 - Epsilon 0.7768798827703951 - Mean Reward -33.261 - Mean Length 6174.19 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 69.894 - Time 2023-04-30T22:43:38
# Episode 167 - tiger - Step 394588 - Epsilon 0.9060624804529263 - Mean Reward 13.38 - Mean Length 2377.64 - Mean Loss 0.005 - Mean Q Value 0.262 - Time Delta 181.691 - Time 2023-04-30T22:44:23
# Episode 168 - tiger - Step 397490 - Epsilon 0.9054053704366075 - Mean Reward 13.34 - Mean Length 2375.35 - Mean Loss 0.005 - Mean Q Value 0.263 - Time Delta 42.402 - Time 2023-04-30T22:45:06
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_8.chkpt at step 400000
# Episode 169 - tiger - Step 400801 - Epsilon 0.9046562311402817 - Mean Reward 13.45 - Mean Length 2376.84 - Mean Loss 0.005 - Mean Q Value 0.263 - Time Delta 44.507 - Time 2023-04-30T22:45:50
# Episode 170 - tiger - Step 403703 - Epsilon 0.9040001409879691 - Mean Reward 13.56 - Mean Length 2405.86 - Mean Loss 0.005 - Mean Q Value 0.267 - Time Delta 42.969 - Time 2023-04-30T22:46:33
# Episode 171 - tiger - Step 406857 - Epsilon 0.9032876177368427 - Mean Reward 13.74 - Mean Length 2437.4 - Mean Loss 0.005 - Mean Q Value 0.271 - Time Delta 43.771 - Time 2023-04-30T22:47:17
# Episode 172 - tiger - Step 410346 - Epsilon 0.9025000685335465 - Mean Reward 13.88 - Mean Length 2442.38 - Mean Loss 0.005 - Mean Q Value 0.272 - Time Delta 41.205 - Time 2023-04-30T22:47:58
# Episode 173 - deer - Step 1035556 - Epsilon 0.7719086751464597 - Mean Reward -33.234 - Mean Length 6069.49 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 339.104 - Time 2023-04-30T22:49:17
# Episode 174 - tiger - Step 413612 - Epsilon 0.9017634778894671 - Mean Reward 13.78 - Mean Length 2413.03 - Mean Loss 0.005 - Mean Q Value 0.269 - Time Delta 114.114 - Time 2023-04-30T22:49:52
# Episode 175 - tiger - Step 416846 - Epsilon 0.9010346966758972 - Mean Reward 13.87 - Mean Length 2416.84 - Mean Loss 0.005 - Mean Q Value 0.27 - Time Delta 47.672 - Time 2023-04-30T22:50:40
# Episode 176 - tiger - Step 420207 - Epsilon 0.9002779201625711 - Mean Reward 14.07 - Mean Length 2450.45 - Mean Loss 0.005 - Mean Q Value 0.274 - Time Delta 43.546 - Time 2023-04-30T22:51:24
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_21.chkpt at step 1050000
# Episode 177 - deer - Step 1057958 - Epsilon 0.7675976831951034 - Mean Reward -33.096 - Mean Length 6073.62 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 197.79 - Time 2023-04-30T22:52:35
# Episode 178 - deer - Step 1082463 - Epsilon 0.7629095622646309 - Mean Reward -34.099 - Mean Length 6318.67 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 77.71 - Time 2023-04-30T22:53:52
# Episode 179 - tiger - Step 423808 - Epsilon 0.8994678095693127 - Mean Reward 13.75 - Mean Length 2388.34 - Mean Loss 0.004 - Mean Q Value 0.268 - Time Delta 193.668 - Time 2023-04-30T22:54:37
# Episode 180 - tiger - Step 427360 - Epsilon 0.8986694365845779 - Mean Reward 13.83 - Mean Length 2388.98 - Mean Loss 0.004 - Mean Q Value 0.268 - Time Delta 44.479 - Time 2023-04-30T22:55:22
# Episode 181 - tiger - Step 430879 - Epsilon 0.8978791797140617 - Mean Reward 14.06 - Mean Length 2424.17 - Mean Loss 0.005 - Mean Q Value 0.272 - Time Delta 47.056 - Time 2023-04-30T22:56:09
# Episode 182 - tiger - Step 434809 - Epsilon 0.896997446532009 - Mean Reward 14.41 - Mean Length 2463.47 - Mean Loss 0.005 - Mean Q Value 0.276 - Time Delta 45.473 - Time 2023-04-30T22:56:54
# Episode 183 - tiger - Step 438017 - Epsilon 0.8962783428890075 - Mean Reward 14.35 - Mean Length 2459.74 - Mean Loss 0.005 - Mean Q Value 0.276 - Time Delta 48.71 - Time 2023-04-30T22:57:43
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_22.chkpt at step 1100000
# Episode 184 - deer - Step 1105755 - Epsilon 0.7584800483750257 - Mean Reward -32.672 - Mean Length 6188.67 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 303.817 - Time 2023-04-30T22:58:56
# Episode 185 - deer - Step 1131983 - Epsilon 0.7535229636403045 - Mean Reward -34.339 - Mean Length 6450.95 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 82.3 - Time 2023-04-30T23:00:19
# Episode 186 - tiger - Step 441387 - Epsilon 0.8955235462933799 - Mean Reward 14.28 - Mean Length 2430.64 - Mean Loss 0.005 - Mean Q Value 0.273 - Time Delta 202.976 - Time 2023-04-30T23:01:06
# Episode 187 - tiger - Step 444229 - Epsilon 0.8948875027153796 - Mean Reward 14.3 - Mean Length 2429.53 - Mean Loss 0.005 - Mean Q Value 0.273 - Time Delta 46.699 - Time 2023-04-30T23:01:53
# Episode 188 - tiger - Step 447399 - Epsilon 0.8941785852264207 - Mean Reward 14.37 - Mean Length 2431.59 - Mean Loss 0.005 - Mean Q Value 0.273 - Time Delta 35.278 - Time 2023-04-30T23:02:28
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_9.chkpt at step 450000
# Episode 189 - tiger - Step 451101 - Epsilon 0.8933514056786579 - Mean Reward 14.42 - Mean Length 2435.79 - Mean Loss 0.005 - Mean Q Value 0.273 - Time Delta 52.228 - Time 2023-04-30T23:03:20
# Episode 190 - tiger - Step 453863 - Epsilon 0.8927347593775049 - Mean Reward 14.36 - Mean Length 2431.66 - Mean Loss 0.005 - Mean Q Value 0.274 - Time Delta 40.215 - Time 2023-04-30T23:04:00
# Episode 191 - tiger - Step 456726 - Epsilon 0.8920960130121738 - Mean Reward 14.49 - Mean Length 2460.29 - Mean Loss 0.005 - Mean Q Value 0.278 - Time Delta 35.356 - Time 2023-04-30T23:04:36
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_23.chkpt at step 1150000
# Episode 192 - deer - Step 1157050 - Epsilon 0.7488155883964543 - Mean Reward -30.739 - Mean Length 5966.3 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 335.177 - Time 2023-04-30T23:05:54
# Episode 193 - tiger - Step 460051 - Epsilon 0.8913547662319738 - Mean Reward 14.55 - Mean Length 2460.97 - Mean Loss 0.005 - Mean Q Value 0.278 - Time Delta 118.414 - Time 2023-04-30T23:06:34
# Episode 194 - tiger - Step 463461 - Epsilon 0.8905952100055538 - Mean Reward 14.68 - Mean Length 2466.4 - Mean Loss 0.005 - Mean Q Value 0.278 - Time Delta 48.391 - Time 2023-04-30T23:07:22
# Episode 195 - tiger - Step 466931 - Epsilon 0.8898229535788902 - Mean Reward 14.75 - Mean Length 2468.32 - Mean Loss 0.005 - Mean Q Value 0.279 - Time Delta 48.972 - Time 2023-04-30T23:08:11
# Episode 196 - tiger - Step 470317 - Epsilon 0.8890700370713364 - Mean Reward 14.78 - Mean Length 2469.98 - Mean Loss 0.005 - Mean Q Value 0.279 - Time Delta 46.305 - Time 2023-04-30T23:08:58
# Episode 197 - deer - Step 1180102 - Epsilon 0.7445125746654742 - Mean Reward -31.649 - Mean Length 6196.82 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 257.773 - Time 2023-04-30T23:10:11
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_24.chkpt at step 1200000
# Episode 198 - deer - Step 1200813 - Epsilon 0.7406676368541526 - Mean Reward -32.185 - Mean Length 6403.93 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 66.404 - Time 2023-04-30T23:11:18
# Episode 199 - tiger - Step 473398 - Epsilon 0.8883854944579361 - Mean Reward 14.56 - Mean Length 2435.65 - Mean Loss 0.005 - Mean Q Value 0.276 - Time Delta 188.846 - Time 2023-04-30T23:12:07
# Episode 200 - tiger - Step 476977 - Epsilon 0.8875909669420956 - Mean Reward 14.82 - Mean Length 2471.44 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 47.437 - Time 2023-04-30T23:12:54
# Episode 201 - tiger - Step 480241 - Epsilon 0.8868669880460343 - Mean Reward 14.94 - Mean Length 2476.06 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 50.154 - Time 2023-04-30T23:13:44
# Episode 202 - tiger - Step 483796 - Epsilon 0.886079135065847 - Mean Reward 14.91 - Mean Length 2473.68 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 48.784 - Time 2023-04-30T23:14:33
# Episode 203 - tiger - Step 486963 - Epsilon 0.8853778594770096 - Mean Reward 14.97 - Mean Length 2475.58 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 45.932 - Time 2023-04-30T23:15:19
# Episode 204 - deer - Step 1225421 - Epsilon 0.736125036349928 - Mean Reward -31.455 - Mean Length 6208.33 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 318.56 - Time 2023-04-30T23:16:36
# Episode 205 - deer - Step 1248112 - Epsilon 0.7319610044514422 - Mean Reward -32.216 - Mean Length 6435.24 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 71.938 - Time 2023-04-30T23:17:48
# Episode 206 - tiger - Step 489936 - Epsilon 0.8847200467905568 - Mean Reward 14.55 - Mean Length 2404.52 - Mean Loss 0.005 - Mean Q Value 0.274 - Time Delta 189.506 - Time 2023-04-30T23:18:28
# Episode 207 - tiger - Step 493665 - Epsilon 0.8838956507550796 - Mean Reward 14.88 - Mean Length 2441.81 - Mean Loss 0.005 - Mean Q Value 0.278 - Time Delta 47.756 - Time 2023-04-30T23:19:16
# Episode 208 - tiger - Step 497327 - Epsilon 0.8830868144868899 - Mean Reward 15.17 - Mean Length 2478.43 - Mean Loss 0.005 - Mean Q Value 0.282 - Time Delta 47.383 - Time 2023-04-30T23:20:04
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_10.chkpt at step 500000
# Episode 209 - tiger - Step 500701 - Epsilon 0.8823422447321324 - Mean Reward 15.24 - Mean Length 2480.0 - Mean Loss 0.005 - Mean Q Value 0.282 - Time Delta 48.19 - Time 2023-04-30T23:20:52
# Episode 210 - tiger - Step 504435 - Epsilon 0.8815189624704302 - Mean Reward 15.45 - Mean Length 2485.25 - Mean Loss 0.005 - Mean Q Value 0.282 - Time Delta 44.375 - Time 2023-04-30T23:21:36
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_25.chkpt at step 1250000
# Episode 211 - deer - Step 1265583 - Epsilon 0.7287709531198389 - Mean Reward -30.88 - Mean Length 6206.56 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 284.912 - Time 2023-04-30T23:22:33
# Episode 212 - deer - Step 1283754 - Epsilon 0.7254678367555534 - Mean Reward -29.892 - Mean Length 6173.69 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 58.031 - Time 2023-04-30T23:23:31
# Episode 213 - tiger - Step 507549 - Epsilon 0.8808329669307063 - Mean Reward 15.21 - Mean Length 2449.64 - Mean Loss 0.005 - Mean Q Value 0.279 - Time Delta 165.909 - Time 2023-04-30T23:24:22
# Episode 214 - tiger - Step 510700 - Epsilon 0.8801393639029699 - Mean Reward 15.26 - Mean Length 2450.46 - Mean Loss 0.005 - Mean Q Value 0.279 - Time Delta 49.019 - Time 2023-04-30T23:25:11
# Episode 215 - tiger - Step 513863 - Epsilon 0.8794436687106393 - Mean Reward 15.3 - Mean Length 2451.4 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 41.352 - Time 2023-04-30T23:25:52
# Episode 216 - tiger - Step 517150 - Epsilon 0.8787212826365064 - Mean Reward 15.29 - Mean Length 2448.79 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 40.977 - Time 2023-04-30T23:26:33
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_26.chkpt at step 1300000
# Episode 217 - deer - Step 1305605 - Epsilon 0.7215155917274525 - Mean Reward -28.664 - Mean Length 6144.07 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 253.544 - Time 2023-04-30T23:27:45
# Episode 218 - tiger - Step 520451 - Epsilon 0.8779964169461465 - Mean Reward 15.31 - Mean Length 2449.27 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 122.786 - Time 2023-04-30T23:28:36
# Episode 219 - tiger - Step 523968 - Epsilon 0.8772247777815614 - Mean Reward 15.25 - Mean Length 2450.62 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 52.088 - Time 2023-04-30T23:29:28
# Episode 220 - tiger - Step 527454 - Epsilon 0.8764606093268681 - Mean Reward 15.31 - Mean Length 2450.16 - Mean Loss 0.005 - Mean Q Value 0.28 - Time Delta 45.07 - Time 2023-04-30T23:30:13
# Episode 221 - tiger - Step 530667 - Epsilon 0.8757568749295268 - Mean Reward 15.5 - Mean Length 2482.29 - Mean Loss 0.005 - Mean Q Value 0.284 - Time Delta 48.481 - Time 2023-04-30T23:31:02
# Episode 222 - deer - Step 1331499 - Epsilon 0.7168599453834571 - Mean Reward -27.054 - Mean Length 5913.31 - Mean Loss 0.0 - Mean Q Value -0.001 - Time Delta 277.85 - Time 2023-04-30T23:32:23
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_27.chkpt at step 1350000
# Episode 223 - deer - Step 1352292 - Epsilon 0.7131431963719702 - Mean Reward -28.18 - Mean Length 6121.24 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 68.238 - Time 2023-04-30T23:33:31
# Episode 224 - tiger - Step 534107 - Epsilon 0.8750040476849936 - Mean Reward 15.35 - Mean Length 2451.1 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 199.624 - Time 2023-04-30T23:34:21
# Episode 225 - tiger - Step 537374 - Epsilon 0.8742896798093428 - Mean Reward 15.34 - Mean Length 2449.3 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 43.938 - Time 2023-04-30T23:35:05
# Episode 226 - tiger - Step 540717 - Epsilon 0.8735592973691145 - Mean Reward 15.42 - Mean Length 2450.99 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 49.415 - Time 2023-04-30T23:35:55
# Episode 227 - tiger - Step 544508 - Epsilon 0.8727317736462248 - Mean Reward 15.57 - Mean Length 2459.47 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 50.744 - Time 2023-04-30T23:36:46
# Episode 228 - tiger - Step 547562 - Epsilon 0.8720656971607483 - Mean Reward 15.46 - Mean Length 2453.61 - Mean Loss 0.005 - Mean Q Value 0.281 - Time Delta 46.758 - Time 2023-04-30T23:37:32
# Episode 229 - deer - Step 1373710 - Epsilon 0.7093348755762009 - Mean Reward -27.462 - Mean Length 6068.8 - Mean Loss 0.0 - Mean Q Value -0.001 - Time Delta 313.961 - Time 2023-04-30T23:38:45
# Episode 230 - deer - Step 1397037 - Epsilon 0.7052102499816923 - Mean Reward -28.117 - Mean Length 6302.07 - Mean Loss 0.0 - Mean Q Value -0.001 - Time Delta 77.589 - Time 2023-04-30T23:40:03
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_11.chkpt at step 550000
# Episode 231 - tiger - Step 551225 - Epsilon 0.8712674684434409 - Mean Reward 15.4 - Mean Length 2426.79 - Mean Loss 0.005 - Mean Q Value 0.277 - Time Delta 201.755 - Time 2023-04-30T23:40:54
# ...
# Episode 968 - tiger - Step 2415725 - Epsilon 0.5466583143504595 - Mean Reward 26.99 - Mean Length 2466.87 - Mean Loss 0.006 - Mean Q Value 0.204 - Time Delta 181.357 - Time 2023-05-01T11:18:26
# Episode 969 - tiger - Step 2419135 - Epsilon 0.5461924866664425 - Mean Reward 26.94 - Mean Length 2463.92 - Mean Loss 0.006 - Mean Q Value 0.204 - Time Delta 44.157 - Time 2023-05-01T11:19:11
# Episode 970 - tiger - Step 2422307 - Epsilon 0.545759527661271 - Mean Reward 26.95 - Mean Length 2465.14 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 53.13 - Time 2023-05-01T11:20:04
# Episode 971 - tiger - Step 2425746 - Epsilon 0.5452905124954586 - Mean Reward 27.01 - Mean Length 2462.1 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 42.028 - Time 2023-05-01T11:20:46
# Episode 972 - deer - Step 6074002 - Epsilon 0.21904004981343075 - Mean Reward 13.351 - Mean Length 6163.72 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 250.448 - Time 2023-05-01T11:21:46
# Episode 973 - deer - Step 6096680 - Epsilon 0.21780171578045246 - Mean Reward 12.832 - Mean Length 6157.43 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 81.411 - Time 2023-05-01T11:23:07
# Episode 974 - tiger - Step 2429582 - Epsilon 0.5447678294951247 - Mean Reward 27.16 - Mean Length 2460.98 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 186.141 - Time 2023-05-01T11:23:52
# Episode 975 - tiger - Step 2433692 - Epsilon 0.5442083679528958 - Mean Reward 27.44 - Mean Length 2463.59 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 40.837 - Time 2023-05-01T11:24:33
# Episode 976 - tiger - Step 2437461 - Epsilon 0.5436958290618601 - Mean Reward 27.59 - Mean Length 2463.93 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 49.465 - Time 2023-05-01T11:25:22
# Episode 977 - tiger - Step 2441025 - Epsilon 0.5432116117684108 - Mean Reward 27.81 - Mean Length 2468.55 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 35.359 - Time 2023-05-01T11:25:57
# Episode 978 - tiger - Step 2444682 - Epsilon 0.5427152074436361 - Mean Reward 28.05 - Mean Length 2471.53 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 43.685 - Time 2023-05-01T11:26:41
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_122.chkpt at step 6100000
# Episode 979 - deer - Step 6118993 - Epsilon 0.21659014557023754 - Mean Reward 13.604 - Mean Length 6161.09 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 291.194 - Time 2023-05-01T11:27:59
# Episode 980 - deer - Step 6139706 - Epsilon 0.21547148635715196 - Mean Reward 14.057 - Mean Length 6210.51 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 73.022 - Time 2023-05-01T11:29:12
# Episode 981 - tiger - Step 2448101 - Epsilon 0.5422515197588029 - Mean Reward 27.82 - Mean Length 2466.73 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 203.109 - Time 2023-05-01T11:30:04
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_49.chkpt at step 2450000
# Episode 982 - tiger - Step 2451361 - Epsilon 0.5418097647545342 - Mean Reward 27.78 - Mean Length 2465.55 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 40.861 - Time 2023-05-01T11:30:45
# Episode 983 - tiger - Step 2455458 - Epsilon 0.5412551001396769 - Mean Reward 27.96 - Mean Length 2470.69 - Mean Loss 0.006 - Mean Q Value 0.202 - Time Delta 49.505 - Time 2023-05-01T11:31:35
# Episode 984 - tiger - Step 2459065 - Epsilon 0.5407672432875944 - Mean Reward 28.34 - Mean Length 2506.76 - Mean Loss 0.006 - Mean Q Value 0.205 - Time Delta 51.332 - Time 2023-05-01T11:32:26
# Episode 985 - tiger - Step 2462771 - Epsilon 0.5402664544002945 - Mean Reward 28.78 - Mean Length 2543.82 - Mean Loss 0.006 - Mean Q Value 0.208 - Time Delta 48.385 - Time 2023-05-01T11:33:14
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_123.chkpt at step 6150000
# Episode 986 - deer - Step 6160029 - Epsilon 0.21437950585519447 - Mean Reward 13.956 - Mean Length 6060.43 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 315.736 - Time 2023-05-01T11:34:27
# Episode 987 - deer - Step 6183671 - Epsilon 0.2131161528296029 - Mean Reward 14.501 - Mean Length 6296.85 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 81.616 - Time 2023-05-01T11:35:49
# Episode 988 - tiger - Step 2466246 - Epsilon 0.5397973016770479 - Mean Reward 27.92 - Mean Length 2466.63 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 208.726 - Time 2023-05-01T11:36:43
# Episode 989 - tiger - Step 2469923 - Epsilon 0.5393013209454841 - Mean Reward 27.97 - Mean Length 2469.21 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 50.963 - Time 2023-05-01T11:37:34
# Episode 990 - tiger - Step 2473653 - Epsilon 0.5387986568043809 - Mean Reward 28.09 - Mean Length 2473.89 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 53.6 - Time 2023-05-01T11:38:28
# Episode 991 - tiger - Step 2477090 - Epsilon 0.5383358928440486 - Mean Reward 28.41 - Mean Length 2508.26 - Mean Loss 0.006 - Mean Q Value 0.204 - Time Delta 53.764 - Time 2023-05-01T11:39:21
# Episode 992 - tiger - Step 2480739 - Epsilon 0.5378450197978776 - Mean Reward 28.79 - Mean Length 2544.75 - Mean Loss 0.006 - Mean Q Value 0.207 - Time Delta 51.128 - Time 2023-05-01T11:40:13
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_124.chkpt at step 6200000
# Episode 993 - deer - Step 6203751 - Epsilon 0.21204899042755984 - Mean Reward 13.981 - Mean Length 6087.35 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 334.351 - Time 2023-05-01T11:41:23
# Episode 994 - deer - Step 6222240 - Epsilon 0.21107110860735923 - Mean Reward 14.61 - Mean Length 6272.24 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 65.274 - Time 2023-05-01T11:42:29
# Episode 995 - tiger - Step 2484097 - Epsilon 0.537393688320172 - Mean Reward 27.8 - Mean Length 2462.24 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 185.2 - Time 2023-05-01T11:43:18
# Episode 996 - tiger - Step 2487337 - Epsilon 0.5369585756226128 - Mean Reward 27.72 - Mean Length 2455.0 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 46.042 - Time 2023-05-01T11:44:04
# Episode 997 - tiger - Step 2490743 - Epsilon 0.5365015499445753 - Mean Reward 27.65 - Mean Length 2450.64 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 47.578 - Time 2023-05-01T11:44:51
# Episode 998 - deer - Step 6243640 - Epsilon 0.20994489334745295 - Mean Reward 15.185 - Mean Length 6327.75 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 218.407 - Time 2023-05-01T11:46:07
# Episode 999 - tiger - Step 2494105 - Epsilon 0.5360508097855254 - Mean Reward 28.01 - Mean Length 2484.26 - Mean Loss 0.006 - Mean Q Value 0.204 - Time Delta 128.46 - Time 2023-05-01T11:47:00
# Episode 1000 - tiger - Step 2497622 - Epsilon 0.5355796941966081 - Mean Reward 28.32 - Mean Length 2519.43 - Mean Loss 0.006 - Mean Q Value 0.207 - Time Delta 53.791 - Time 2023-05-01T11:47:54
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_50.chkpt at step 2500000
# Episode 1001 - tiger - Step 2501781 - Epsilon 0.5350231145419071 - Mean Reward 28.54 - Mean Length 2523.52 - Mean Loss 0.006 - Mean Q Value 0.207 - Time Delta 46.271 - Time 2023-05-01T11:48:40
# Episode 1002 - tiger - Step 2504994 - Epsilon 0.5345935297264914 - Mean Reward 28.61 - Mean Length 2525.99 - Mean Loss 0.006 - Mean Q Value 0.207 - Time Delta 53.49 - Time 2023-05-01T11:49:33
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_125.chkpt at step 6250000
# Episode 1003 - deer - Step 6259472 - Epsilon 0.20911557366212125 - Mean Reward 15.26 - Mean Length 6119.8 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 263.347 - Time 2023-05-01T11:50:30
# Episode 1004 - deer - Step 6280299 - Epsilon 0.20802959068742105 - Mean Reward 15.821 - Mean Length 6328.07 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 73.887 - Time 2023-05-01T11:51:44
# Episode 1005 - tiger - Step 2508583 - Epsilon 0.5341140807469109 - Mean Reward 27.93 - Mean Length 2455.29 - Mean Loss 0.006 - Mean Q Value 0.201 - Time Delta 186.17 - Time 2023-05-01T11:52:40
# Episode 1006 - tiger - Step 2512119 - Epsilon 0.533642132472343 - Mean Reward 28.27 - Mean Length 2490.65 - Mean Loss 0.006 - Mean Q Value 0.204 - Time Delta 44.309 - Time 2023-05-01T11:53:24
# Episode 1007 - tiger - Step 2515416 - Epsilon 0.5332024591149075 - Mean Reward 28.61 - Mean Length 2523.62 - Mean Loss 0.006 - Mean Q Value 0.207 - Time Delta 37.389 - Time 2023-05-01T11:54:01
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_126.chkpt at step 6300000
# Episode 1008 - deer - Step 6300255 - Epsilon 0.20699431557104755 - Mean Reward 14.919 - Mean Length 6097.21 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 207.667 - Time 2023-05-01T11:55:12
# Episode 1009 - tiger - Step 2519253 - Epsilon 0.5326912298295747 - Mean Reward 28.32 - Mean Length 2486.9 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 121.279 - Time 2023-05-01T11:56:03
# Episode 1010 - tiger - Step 2523130 - Epsilon 0.5321751689268988 - Mean Reward 28.41 - Mean Length 2490.85 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 49.679 - Time 2023-05-01T11:56:52
# Episode 1011 - tiger - Step 2526799 - Epsilon 0.5316872549958774 - Mean Reward 28.4 - Mean Length 2490.38 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 48.647 - Time 2023-05-01T11:57:41
# Episode 1012 - deer - Step 6321077 - Epsilon 0.20591960615359423 - Mean Reward 15.31 - Mean Length 6305.43 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 222.685 - Time 2023-05-01T11:58:55
# Episode 1013 - deer - Step 6339477 - Epsilon 0.20497455114000313 - Mean Reward 15.275 - Mean Length 6294.39 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 65.42 - Time 2023-05-01T12:00:00
# Episode 1014 - tiger - Step 2530850 - Epsilon 0.5311490612348967 - Mean Reward 28.63 - Mean Length 2491.95 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 183.721 - Time 2023-05-01T12:00:45
# Episode 1015 - tiger - Step 2535081 - Epsilon 0.5305875352744991 - Mean Reward 28.67 - Mean Length 2492.16 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 45.25 - Time 2023-05-01T12:01:30
# Episode 1016 - tiger - Step 2538908 - Epsilon 0.5300801383513359 - Mean Reward 28.9 - Mean Length 2491.65 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 45.3 - Time 2023-05-01T12:02:15
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_127.chkpt at step 6350000
# Episode 1017 - deer - Step 6356304 - Epsilon 0.20411408549020665 - Mean Reward 14.892 - Mean Length 6246.37 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 195.871 - Time 2023-05-01T12:03:16
# Episode 1018 - deer - Step 6377482 - Epsilon 0.20303625912332646 - Mean Reward 15.588 - Mean Length 6458.15 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 75.388 - Time 2023-05-01T12:04:31
# Episode 1019 - tiger - Step 2542354 - Epsilon 0.5296236709066074 - Mean Reward 28.03 - Mean Length 2411.64 - Mean Loss 0.006 - Mean Q Value 0.197 - Time Delta 184.939 - Time 2023-05-01T12:05:20
# Episode 1020 - tiger - Step 2545677 - Epsilon 0.5291838686951051 - Mean Reward 28.31 - Mean Length 2444.87 - Mean Loss 0.006 - Mean Q Value 0.2 - Time Delta 47.269 - Time 2023-05-01T12:06:07
# Episode 1021 - tiger - Step 2549496 - Epsilon 0.5286788714446968 - Mean Reward 28.79 - Mean Length 2483.06 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 44.559 - Time 2023-05-01T12:06:52
# Animal saved to tiger_checkpoints\2023-04-30T20-26-57\animal_net_51.chkpt at step 2550000
# Episode 1022 - tiger - Step 2553036 - Epsilon 0.5282111975611613 - Mean Reward 28.71 - Mean Length 2481.67 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 56.944 - Time 2023-05-01T12:07:49
# Episode 1023 - tiger - Step 2556722 - Epsilon 0.5277246750813872 - Mean Reward 28.66 - Mean Length 2481.13 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 51.361 - Time 2023-05-01T12:08:40
# Episode 1024 - deer - Step 6392331 - Epsilon 0.20228393494792987 - Mean Reward 15.73 - Mean Length 6243.26 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 305.864 - Time 2023-05-01T12:09:37
# Animal saved to deer_checkpoints\2023-04-30T20-26-57\animal_net_128.chkpt at step 6400000
# Episode 1025 - deer - Step 6409331 - Epsilon 0.20142605240873462 - Mean Reward 16.104 - Mean Length 6199.15 - Mean Loss 0.0 - Mean Q Value 0.017 - Time Delta 64.059 - Time 2023-05-01T12:10:41
# Episode 1026 - tiger - Step 2559533 - Epsilon 0.5273539467994921 - Mean Reward 28.58 - Mean Length 2473.81 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 159.501 - Time 2023-05-01T12:11:20
# Episode 1027 - tiger - Step 2563192 - Epsilon 0.5268717702854221 - Mean Reward 28.57 - Mean Length 2473.39 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 49.085 - Time 2023-05-01T12:12:09
# Episode 1028 - tiger - Step 2567202 - Epsilon 0.5263438459359393 - Mean Reward 28.75 - Mean Length 2477.93 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 47.696 - Time 2023-05-01T12:12:56
# Episode 1029 - tiger - Step 2571026 - Epsilon 0.525840901601981 - Mean Reward 29.0 - Mean Length 2479.0 - Mean Loss 0.006 - Mean Q Value 0.203 - Time Delta 37.852 - Time 2023-05-01T12:13:34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_basicTrain.ipynb Cell 20 in <cell line: 11>()
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_basicTrain.ipynb#X25sZmlsZQ%3D%3D?line=33'>34</a>     env.step(None)
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_basicTrain.ipynb#X25sZmlsZQ%3D%3D?line=34'>35</a>     continue
# ---> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_basicTrain.ipynb#X25sZmlsZQ%3D%3D?line=36'>37</a> state = np.transpose(env.state(),(2,0,1))
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_basicTrain.ipynb#X25sZmlsZQ%3D%3D?line=37'>38</a> state_with_ids = convert_numpy_binary_to_integer(state[5:15,:,:])
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_basicTrain.ipynb#X25sZmlsZQ%3D%3D?line=38'>39</a> env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\wrappers\order_enforcing.py:85, in OrderEnforcingWrapper.state(self)
#      83 if not self._has_reset:
#      84     EnvLogger.error_state_before_reset()
# ---> 85 return super().state()
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\wrappers\base.py:105, in BaseWrapper.state(self)
#     104 def state(self):
# --> 105     return self.env.state()
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\wrappers\base.py:105, in BaseWrapper.state(self)
#     104 def state(self):
# --> 105     return self.env.state()
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\pettingzoo\utils\conversions.py:266, in parallel_to_aec_wrapper.state(self)
#     265 def state(self):
# --> 266     return self.env.state()
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\magent2\environments\magent_env.py:222, in magent_parallel_env.state(self)
#     220 def state(self):
#     221     """Returns an observation of the global environment."""
# --> 222     state = np.copy(self.base_state)
#     224     for handle in self._all_handles:
#     225         view, features = self.env.get_observation(handle)
#
# File <__array_function__ internals>:180, in copy(*args, **kwargs)
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:959, in copy(a, order, subok)
#     870 @array_function_dispatch(_copy_dispatcher)
#     871 def copy(a, order='K', subok=False):
#     872     """
#     873     Return an array copy of the given object.
#     874
#    (...)
#     957
#     958     """
# --> 959     return array(a, order=order, subok=subok, copy=True)
#
# KeyboardInterrupt:

# %%
tiger.save_dir=Path("tiger_checkpoints") / "Basic_With_AdvReward2"
tiger.save()
deer.save_dir=Path("deer_checkpoints") / "Basic_With_AdvReward2"
deer.save()

# %% [markdown]
# ### Train LSTM Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
         state_with_ids = convert_numpy_binary_to_integer(state[5:15,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm3.ipynb Cell 23 in <cell line: 11>()
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=104'>105</a> # if not prev_done:
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=105'>106</a> if activeAnimal:
# --> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=106'>107</a>     animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=107'>108</a>     #learn
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=108'>109</a>     q, loss = animal.learn()
#
# TypeError: Animal.cache() takes from 6 to 7 positional arguments but 8 were given

# %% [markdown]
# ### Visualize Trained Model

# %%
map_size=100
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 20
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:15,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# deer_save_dir=
# tiger_save_dir=
deer2 = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger2 = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

deer2.load("deer_checkpoints\\Basic_With_AdvReward2\\animal_net_161.chkpt")
tiger2.load("tiger_checkpoints\\Basic_With_AdvReward2\\animal_net_64.chkpt")
# tiger2.net.eval()
# deer2.net.eval()
# Out:
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
map_size=50
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 3
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
         state_with_ids = convert_numpy_binary_to_integer(state[5:15,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger2
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer2
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm.ipynb Cell 27 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=14'>15</a> for agent in env.agent_iter():
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=16'>17</a>     agentType = get_agent_type_from_agent_name(agent)
# ---> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=17'>18</a>     agent_id = agent_name_to_id(agent)
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=18'>19</a>     # print("Agent id: ", agent_id)
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=20'>21</a>     observation, reward, termination, truncation, info = env.last()
#
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm.ipynb Cell 27 in agent_name_to_id(agent_name)
#       <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> def agent_name_to_id(agent_name):
#       <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a>     global agent_name_to_id_dict
# ----> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a>     return agent_name_to_id_dict[agent_name]
#
# KeyError: 'deer_125'
