# %%
from magent2.environments import battle_v4, adversarial_pursuit_v4, tiger_deer_v4
from pettingzoo.utils import random_demo
import torch
import time
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from dqn_basic import DQN_Basic
from collections import namedtuple, deque
import numpy as np
# import matplotlib.pyplot as plt
from Animal import Animal
from pathlib import Path
from collections import deque
import datetime, os
from metric_logger import MetricLogger
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# frame_size = (128, 128)
max_cycles = 300
total_episodes = 50
map_size = 40

# env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', tiger_step_recover=-0.1, deer_attacked=-0.1, max_cycles=max_cycles, extra_features=False)
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='rgb_array', max_cycles=max_cycles, extra_features=False)

print(env.action_spaces['deer_0'].n)
print(env.observation_spaces['deer_0'].shape)
deer_observation_shape = env.observation_spaces['deer_0'].shape
deer_observation_shape = tuple(np.roll(deer_observation_shape,1))
# deer_action_space = env.action_spaces['deer_0'].n
deer_action_space = 3

tiger_observation_shape = env.observation_spaces['tiger_0'].shape
tiger_observation_shape = tuple(np.roll(tiger_observation_shape,1))
# tiger_action_space = env.action_spaces['tiger_0'].n
tiger_action_space = 6

print(deer_observation_shape, tiger_observation_shape)
assert deer_observation_shape != None
assert tiger_observation_shape != None
# 'rgb_array' or 'human'
# random_demo(env, render=False , episodes=1)
# 'rgb_array'
# pygame.quit()
# Out:
# 5
# (13, 13, 5)
# (5, 13, 13) (5, 13, 13)
# c:\Users\Scott\a3\lib\site-packages\pettingzoo\utils\wrappers\base.py:64: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# c:\Users\Scott\a3\lib\site-packages\pettingzoo\utils\wrappers\base.py:50: UserWarning: The `observation_spaces` dictionary is deprecated. Use the `observation_space` function instead.
#   warnings.warn(

# %%
# def deer_action_mapper(new_unmapped_action, prev_actual_action):
#     # 0 - forward, 1-left, 2-right
#     # 0 - up
#     # 1 - left
#     # 2 - stay still/  nothing
#     # 3 - right
#     # 4 - down
#     if new_unmapped_action == 0:
#         return prev_actual_action
#     if new_unmapped_action == 1:
#         if prev_actual_action == 0:
#             return 1
#         if prev_actual_action == 1:
#             return 4
#         if prev_actual_action == 3:
#             return 0
#         if prev_actual_action == 4:
#             return 3
#         return prev_actual_action
#     if new_unmapped_action == 2:
#         if prev_actual_action == 0:
#             return 3
#         if prev_actual_action == 1:
#             return 0
#         if prev_actual_action == 3:
#             return 4
#         if prev_actual_action == 4:
#             return 1
#     return 0
    

# def tiger_action_mapper(new_action, prev_action):
#     # new_action possibilities:
#     # 0 - forward, 1-left, 2-right
#     # 3 - attack forward, 4 - attack left, 5 - attack right
#     # prev_action possibilities:
#     # 0 - up
#     # 1 - left
#     # 2 - stay still/  nothing
#     # 3 - right
#     # 4 - down
#     # 5 - attack up
#     # 6 - attack left
#     # 7 - attack right
#     # 8 - attack down
#     direction = 0
#     if prev_action == 0 or prev_action == 5:
#         direction = 0
#     elif prev_action == 1 or prev_action == 6:
#         direction = 1
#     elif prev_action == 3 or prev_action == 7:
#         direction = 3
#     else:
#         direction = 4

#     if new_action == 0:
#         return direction
#     if new_action == 1:
#         if direction == 0:
#             return 1
#         if direction == 1:
#             return 4
#         if direction == 3:
#             return 0
#         if direction == 4:
#             return 3
#     if new_action == 2:
#         if direction == 0:
#             return 3
#         if direction == 1:
#             return 0
#         if direction == 3:
#             return 4
#         if direction == 4:
#             return 1
#     if new_action == 3:
#         if direction > 2:
#             return direction+4
#         return direction+5
#     if new_action == 4:
#         if direction == 0:
#             return 6
#         if direction == 1:
#             return 8
#         if direction == 3:
#             return 5
#         if direction == 4:
#             return 7
#     if new_action == 5:
#         if direction == 0:
#             return 7
#         if direction == 1:
#             return 5
#         if direction == 3:
#             return 8
#         if direction == 4:
#             return 6
#     return 0

deer_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
}
def deer_action_mapper(new_unmapped_action, prev_actual_action, size_of_actions=5):
    global deer_action_mapping
    return deer_action_mapping.get(new_unmapped_action, {}).get(prev_actual_action, np.random.choice(np.delete(np.arange(0, size_of_actions), 2)))

tiger_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
    3: {0: 5, 1: 6, 3: 7, 4: 8},
    4: {0: 6, 1: 8, 3: 5, 4: 7},
    5: {0: 7, 1: 5, 3: 8, 4: 6},
}

tiger_direction_mapping = {
    0: 0,
    1: 1,
    3: 3,
    4: 4,
    5: 0,
    6: 1,
    7: 3,
    8: 4,
}

def tiger_action_mapper(new_action, prev_action, size_of_actions=5): # slower
    global tiger_action_mapping, tiger_direction_mapping
    # tiger_action_mapping = {
    #     0: {0: 0, 1: 1, 3: 3, 4: 4},
    #     1: {0: 1, 1: 4, 3: 0, 4: 3},
    #     2: {0: 3, 1: 0, 3: 4, 4: 1},
    #     3: {0: 5, 1: 6, 3: 7, 4: 8},
    #     4: {0: 6, 1: 8, 3: 5, 4: 7},
    #     5: {0: 7, 1: 5, 3: 8, 4: 6},
    # }

    # tiger_direction_mapping = {
    #     0: 0,
    #     1: 1,
    #     3: 3,
    #     4: 4,
    #     5: 0,
    #     6: 1,
    #     7: 3,
    #     8: 4,
    # }

    direction = tiger_direction_mapping.get(prev_action, 0)
    return tiger_action_mapping.get(new_action, {}).get(direction, 0)

# %%
def get_agent_type_from_agent_name(agent):
    if 'tiger' in agent:
        return 'tiger'
    return 'deer'

# %%
def generate_first_action(agentType):
    if 'tiger' in agentType:
        # action = np.random.randint(0,tiger_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 6))
        actual_action = tiger_action_mapper(action, np.random.choice(np.delete(np.arange(0, 9), 2)))
    else:
        # action = np.random.randint(0,deer_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 3))
        actual_action = deer_action_mapper(action, np.random.choice(np.delete(np.arange(0, 5), 2)))
    
    return action, actual_action

# %%
def change_active_model(activeDeer, activeTiger, deerCurrentSteps, tigerCurrentSteps, steps_to_switch_at):
    if tigerCurrentSteps < deerCurrentSteps-steps_to_switch_at:
        if not activeTiger:
            print("Switching to Tiger")
        return False, True
    if deerCurrentSteps < tigerCurrentSteps- steps_to_switch_at:
        if not activeDeer:
            print("Switching to Deer")
        return True, False
    return activeDeer, activeTiger

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Make Models and Loggers

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

deer_save_dir = Path("deer_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
deer_save_dir.mkdir(parents=True)

tiger_save_dir = Path("tiger_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
tiger_save_dir.mkdir(parents=True)

modelType = 'basic'

if modelType == 'basic':
    deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
    tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)
else:
    deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
    tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

deer_logger = MetricLogger(deer_save_dir)
tiger_logger = MetricLogger(tiger_save_dir)


# active training flags
activeDeer = True
activeTiger = False


# Switch the training set
switching = True
steps_to_switch_at = 100000
total_steps = 200000

# if switching enabled, make sure no equivalence between active variables
if switching:
    if activeDeer == activeTiger:
        activeTiger = not activeTiger
# Out:
# Using CUDA: True
# c:\Users\Scott\a3\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# ### Train Model

# %%
e = -1
while deer.curr_step < total_steps or tiger.curr_step < total_steps:
    e = e + 1
# for e in range(total_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    agents_prev_data = {}
    # Play the game!
    for agent in env.agent_iter():
        
        observation, reward, termination, truncation, info = env.last()
        observation = np.transpose(observation, (2,0,1))
        done = termination or truncation
        agentType = get_agent_type_from_agent_name(agent)

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action = generate_first_action(agentType)
            agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]
            env.step(actual_action)
            continue
        
        prev_observation, prev_action, prev_done, prev_actual_action = agents_prev_data[agent][0:4]
        
        if not prev_done:
            if 'tiger' in agentType:
                if activeTiger:
                    tiger.cache(prev_observation, observation, prev_action, reward, done, agentName=agent)
                    #learn
                    q, loss = tiger.learn()
                    # logging
                    tiger_logger.log_step(reward, loss, q)
                action = tiger.act(observation, activeTiger)
                actual_action = tiger_action_mapper(action, prev_actual_action)
            else:
                if activeDeer:
                    deer.cache(prev_observation, observation, prev_action, reward, done, agentName=agent)
                    #learn
                    q, loss = deer.learn()
                    # logging
                    deer_logger.log_step(reward, loss, q)
                action = deer.act(observation, activeDeer)
                actual_action = deer_action_mapper(action, prev_actual_action)
        
        if done:
            action = None
            actual_action = None
        
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    if e % 5 == 0:
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at)

# log last episode
# if total_episodes != 0:
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
# Out:
# Episode:  0
# Animal saved to deer_checkpoints\2023-04-24T14-40-01\animal_net_0.chkpt at step 0
# Episode 0 - Step 21431 - Epsilon 0.9946565764771381 - Mean Reward -12.0 - Mean Length 21431.0 - Mean Loss 0.001 - Mean Q Value -0.047 - Time Delta 20.025 - Time 2023-04-24T14:40:21
# Episode 0 - Step 0 - Epsilon 1 - Mean Reward 0.0 - Mean Length 0.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 20.246 - Time 2023-04-24T14:40:21
# Episode:  1
# Episode:  2
# Animal saved to deer_checkpoints\2023-04-24T14-40-01\animal_net_1.chkpt at step 50000
# Episode:  3
# Episode:  4
# Animal saved to deer_checkpoints\2023-04-24T14-40-01\animal_net_2.chkpt at step 100000
# Switching to Tiger
# Episode:  5
# Animal saved to tiger_checkpoints\2023-04-24T14-40-01\animal_net_0.chkpt at step 0
# Episode 5 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -17.167 - Mean Length 16716.167 - Mean Loss 0.0 - Mean Q Value -0.028 - Time Delta 128.641 - Time 2023-04-24T14:42:29
# Episode 5 - Step 2309 - Epsilon 0.999422916504532 - Mean Reward 6.667 - Mean Length 384.833 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 128.621 - Time 2023-04-24T14:42:29
# Episode:  6
# Episode:  7
# Episode:  8
# Episode:  9
# Episode:  10
# Episode 10 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -9.364 - Mean Length 9117.909 - Mean Loss 0.0 - Mean Q Value -0.015 - Time Delta 13.621 - Time 2023-04-24T14:42:43
# Episode 10 - Step 15355 - Epsilon 0.9961686081033088 - Mean Reward 22.909 - Mean Length 1395.909 - Mean Loss 0.002 - Mean Q Value 0.031 - Time Delta 13.632 - Time 2023-04-24T14:42:43
# Episode:  11
# Episode:  12
# Episode:  13
# Episode:  14
# Episode:  15
# Episode 15 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -6.438 - Mean Length 6268.562 - Mean Loss 0.0 - Mean Q Value -0.011 - Time Delta 24.3 - Time 2023-04-24T14:43:07
# Episode 15 - Step 27406 - Epsilon 0.9931719171612199 - Mean Reward 29.062 - Mean Length 1712.875 - Mean Loss 0.004 - Mean Q Value 0.058 - Time Delta 24.349 - Time 2023-04-24T14:43:07
# Episode:  16
# Episode:  17
# Episode:  18
# Episode:  19
# Episode:  20
# Episode 20 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -4.905 - Mean Length 4776.048 - Mean Loss 0.0 - Mean Q Value -0.008 - Time Delta 24.404 - Time 2023-04-24T14:43:32
# Episode 20 - Step 39520 - Epsilon 0.9901686456336273 - Mean Reward 32.0 - Mean Length 1881.905 - Mean Loss 0.005 - Mean Q Value 0.079 - Time Delta 24.352 - Time 2023-04-24T14:43:32
# Episode:  21
# Episode:  22
# Episode:  23
# Episode:  24
# Episode:  25
# Animal saved to tiger_checkpoints\2023-04-24T14-40-01\animal_net_1.chkpt at step 50000
# Episode 25 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -3.962 - Mean Length 3857.577 - Mean Loss 0.0 - Mean Q Value -0.007 - Time Delta 24.958 - Time 2023-04-24T14:43:57
# Episode 25 - Step 51707 - Epsilon 0.9871564399844898 - Mean Reward 33.5 - Mean Length 1988.731 - Mean Loss 0.006 - Mean Q Value 0.102 - Time Delta 24.944 - Time 2023-04-24T14:43:57
# Episode:  26
# Episode:  27
# Episode:  28
# Episode:  29
# Episode:  30
# Episode 30 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -3.323 - Mean Length 3235.387 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 25.674 - Time 2023-04-24T14:44:22
# Episode 30 - Step 64493 - Epsilon 0.9840060318521073 - Mean Reward 35.71 - Mean Length 2080.419 - Mean Loss 0.007 - Mean Q Value 0.125 - Time Delta 25.715 - Time 2023-04-24T14:44:22
# Episode:  31
# Episode:  32
# Episode:  33
# Episode:  34
# Episode:  35
# Episode 35 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -2.861 - Mean Length 2786.028 - Mean Loss 0.0 - Mean Q Value -0.005 - Time Delta 24.462 - Time 2023-04-24T14:44:47
# Episode 35 - Step 76414 - Epsilon 0.9810778130885742 - Mean Reward 36.75 - Mean Length 2122.611 - Mean Loss 0.007 - Mean Q Value 0.146 - Time Delta 24.429 - Time 2023-04-24T14:44:47
# Episode:  36
# Episode:  37
# Episode:  38
# Episode:  39
# Episode:  40
# Episode 40 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -2.512 - Mean Length 2446.268 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 25.918 - Time 2023-04-24T14:45:13
# Episode 40 - Step 88980 - Epsilon 0.9780005928281624 - Mean Reward 37.61 - Mean Length 2170.244 - Mean Loss 0.007 - Mean Q Value 0.165 - Time Delta 25.927 - Time 2023-04-24T14:45:13
# Episode:  41
# Episode:  42
# Episode:  43
# Episode:  44
# Episode:  45
# Animal saved to tiger_checkpoints\2023-04-24T14-40-01\animal_net_2.chkpt at step 100000
# Episode 45 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -2.239 - Mean Length 2180.37 - Mean Loss 0.0 - Mean Q Value -0.004 - Time Delta 23.701 - Time 2023-04-24T14:45:36
# Episode 45 - Step 100530 - Epsilon 0.9751806889589851 - Mean Reward 38.043 - Mean Length 2185.435 - Mean Loss 0.008 - Mean Q Value 0.184 - Time Delta 23.726 - Time 2023-04-24T14:45:37
# Episode:  46
# Episode:  47
# Episode:  48
# Episode:  49
# Episode:  50
# Episode 50 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -2.02 - Mean Length 1966.608 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 25.941 - Time 2023-04-24T14:46:02
# Episode 50 - Step 113236 - Epsilon 0.9720879417697296 - Mean Reward 38.863 - Mean Length 2220.314 - Mean Loss 0.008 - Mean Q Value 0.202 - Time Delta 25.892 - Time 2023-04-24T14:46:02
# Episode:  51
# Episode:  52
# Episode:  53
# Episode:  54
# Episode:  55
# Episode 55 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.839 - Mean Length 1791.018 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 24.87 - Time 2023-04-24T14:46:27
# Episode 55 - Step 125378 - Epsilon 0.9691416424618924 - Mean Reward 39.107 - Mean Length 2238.893 - Mean Loss 0.008 - Mean Q Value 0.219 - Time Delta 24.868 - Time 2023-04-24T14:46:27
# Episode:  56
# Episode:  57
# Episode:  58
# Episode:  59
# Episode:  60
# Episode 60 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.689 - Mean Length 1644.213 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 24.597 - Time 2023-04-24T14:46:52
# Episode 60 - Step 137470 - Epsilon 0.9662163507168677 - Mean Reward 39.295 - Mean Length 2253.607 - Mean Loss 0.008 - Mean Q Value 0.234 - Time Delta 24.603 - Time 2023-04-24T14:46:52
# Episode:  61
# Episode:  62
# Episode:  63
# Episode:  64
# Episode:  65
# Animal saved to tiger_checkpoints\2023-04-24T14-40-01\animal_net_3.chkpt at step 150000
# Episode 65 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.561 - Mean Length 1519.652 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 25.903 - Time 2023-04-24T14:47:18
# Episode 65 - Step 150227 - Epsilon 0.9631397534619899 - Mean Reward 39.712 - Mean Length 2276.167 - Mean Loss 0.008 - Mean Q Value 0.25 - Time Delta 25.908 - Time 2023-04-24T14:47:18
# Episode:  66
# Episode:  67
# Episode:  68
# Episode:  69
# Episode:  70
# Episode 70 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.451 - Mean Length 1412.634 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 25.035 - Time 2023-04-24T14:47:43
# Episode 70 - Step 162587 - Epsilon 0.9601682445974897 - Mean Reward 39.93 - Mean Length 2289.958 - Mean Loss 0.008 - Mean Q Value 0.265 - Time Delta 25.037 - Time 2023-04-24T14:47:43
# Episode:  71
# Episode:  72
# Episode:  73
# Episode:  74
# Episode:  75
# Episode 75 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.355 - Mean Length 1319.697 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 25.31 - Time 2023-04-24T14:48:08
# Episode 75 - Step 174987 - Epsilon 0.9571963315126156 - Mean Reward 39.974 - Mean Length 2302.461 - Mean Loss 0.008 - Mean Q Value 0.279 - Time Delta 25.309 - Time 2023-04-24T14:48:08
# Episode:  76
# Episode:  77
# Episode:  78
# Episode:  79
# Episode:  80
# Episode 80 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.272 - Mean Length 1238.235 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 26.162 - Time 2023-04-24T14:48:34
# Episode 80 - Step 188000 - Epsilon 0.9540873919788314 - Mean Reward 40.346 - Mean Length 2320.988 - Mean Loss 0.008 - Mean Q Value 0.293 - Time Delta 26.166 - Time 2023-04-24T14:48:34
# Episode:  81
# Episode:  82
# Episode:  83
# Episode:  84
# Episode:  85
# Animal saved to tiger_checkpoints\2023-04-24T14-40-01\animal_net_4.chkpt at step 200000
# Episode 85 - Step 100297 - Epsilon 0.9752374948956799 - Mean Reward -1.198 - Mean Length 1166.244 - Mean Loss 0.0 - Mean Q Value -0.002 - Time Delta 24.696 - Time 2023-04-24T14:48:59
# Episode 85 - Step 200063 - Epsilon 0.9512144368016415 - Mean Reward 40.384 - Mean Length 2326.314 - Mean Loss 0.008 - Mean Q Value 0.305 - Time Delta 24.695 - Time 2023-04-24T14:48:59
# Episode:  86
# Switching to Deer
# Episode:  87
# Episode:  88
# Episode:  89
# Animal saved to deer_checkpoints\2023-04-24T14-40-01\animal_net_3.chkpt at step 150000
# Episode:  90
# Episode 90 - Step 172277 - Epsilon 0.9578450518375922 - Mean Reward -2.198 - Mean Length 1893.154 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 123.217 - Time 2023-04-24T14:51:02
# Episode 90 - Step 203002 - Epsilon 0.9505157886040847 - Mean Reward 38.637 - Mean Length 2230.791 - Mean Loss 0.008 - Mean Q Value 0.293 - Time Delta 123.216 - Time 2023-04-24T14:51:02
# Episode:  91
# Episode:  92
# Animal saved to deer_checkpoints\2023-04-24T14-40-01\animal_net_4.chkpt at step 200000
# Episode 92 - Step 211623 - Epsilon 0.9484693952314058 - Mean Reward -2.613 - Mean Length 2275.516 - Mean Loss 0.0 - Mean Q Value -0.003 - Time Delta 65.375 - Time 2023-04-24T14:52:07
# Episode 92 - Step 203002 - Epsilon 0.9505157886040847 - Mean Reward 37.806 - Mean Length 2182.817 - Mean Loss 0.008 - Mean Q Value 0.287 - Time Delta 65.426 - Time 2023-04-24T14:52:08

# %% [markdown]
# ### Visualize Trained Model

# %%
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=False)
example_episodes = 10
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    # Play the game!
    agents_prev_data = {}
    init_agent = None
    for agent in env.agent_iter():
        if init_agent is None:
            init_agent = agent
        else:
            if init_agent == agent:
                time.sleep(0.01)

        observation, reward, termination, truncation, info = env.last()
        observation = np.transpose(observation, (2,0,1))
        done = termination or truncation
        agentType = get_agent_type_from_agent_name(agent)
        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action = generate_first_action(agentType)
            agents_prev_data[agent] = [observation, action, done, action, actual_action, info]
            env.step(actual_action)
            continue

        prev_actual_action = agents_prev_data[agent][3]
        if not done:
            if 'tiger' in agentType:
                # tiger.cache(prev_observation, observation, prev_action, reward, done, agentName=agent)
                action = tiger.act(observation, False)
                actual_action = tiger_action_mapper(action, prev_actual_action)
            else:
                # deer.cache(prev_observation, observation, prev_action, reward, done, agentName=agent)
                # action =
                action = deer.act(observation, False)
                actual_action = deer_action_mapper(action, prev_actual_action)
        else:
            action = None
            actual_action = None
        agents_prev_data[agent] = [observation, action, done, action, actual_action, info]
        env.step(actual_action)
# Out:
# Episode:  0
# Episode:  1
# Episode:  2
# Episode:  3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17780\2470234168.py in <module>
#      34                 # deer.cache(prev_observation, observation, prev_action, reward, done, agentName=agent)
#      35                 # action =
# ---> 36                 action = deer.act(observation, False)
#      37                 actual_action = deer_action_mapper(action, prev_actual_action)
#      38         else:
#
# c:\Users\Scott\OneDrive - Georgia Institute of Technology\Georgia Tech\GTSR\Underwater Platforms\Python_Code\TheLearningShoal\The-Learning-Shoal\src\tests\scott_tests\Animal.py in act(self, state, active)
#      56         else:
#      57             # state = state[0].__array__() if isinstance(state, tuple) else state.__array__()
# ---> 58             state = torch.tensor(state, device=self.device).unsqueeze(0)
#      59             action_values = self.net(state, model="online")
#      60             action_idx = torch.argmax(action_values, axis=1).item()
#
# KeyboardInterrupt:
