# %%
from magent2.environments import battle_v4, adversarial_pursuit_v4, tiger_deer_v4
from pettingzoo.utils import random_demo
import torch
import time
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from dqn_basic import DQN_Basic
from collections import namedtuple, deque
import numpy as np
# import matplotlib.pyplot as plt
# from AnimalLSTM import Animal
from Animal import Animal
from pathlib import Path
from collections import deque
import datetime, os
from metric_logger import MetricLogger
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
def convert_numpy_binary_to_integer(arr):
    assert len(arr.shape) == 3
    assert arr.shape[0] <= 8
    arr = arr.astype(np.int32)
    input_array_transposed = np.transpose(arr, (1, 2, 0))
    packed_array = np.packbits(input_array_transposed, axis=-1, bitorder='little').squeeze(-1)
    return packed_array

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# frame_size = (128, 128)
max_cycles = 300
# total_episodes = 50
# map_size = 30
map_size = 50

# env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', tiger_step_recover=-0.1, deer_attacked=-0.1, max_cycles=max_cycles, extra_features=False)
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='rgb_array', max_cycles=max_cycles, extra_features=True)
env.reset(seed=None)
obs_indices_to_keep = [0,1,3]

# get number of deer and tigers
number_of_deer = len([x for x in env.agents if 'deer' in x])
number_of_tigers = len([x for x in env.agents if 'tiger' in x])


# set deer data
deer_observation_shape = env.observation_spaces['deer_0'].shape
deer_observation_shape = tuple(np.roll(deer_observation_shape,1))
# deer_action_space = env.action_spaces['deer_0'].n
deer_action_space = 3
deer_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['deer_0'].n, deer_observation_shape[1], deer_observation_shape[2])


# set tiger data
tiger_observation_shape = env.observation_spaces['tiger_0'].shape
tiger_observation_shape = tuple(np.roll(tiger_observation_shape,1))
# tiger_action_space = env.action_spaces['tiger_0'].n
tiger_action_space = 6
tiger_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['tiger_0'].n, tiger_observation_shape[1], tiger_observation_shape[2])

# print outputs
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)
print("Deer Observations:", deer_observation_shape, "Tiger Observations:",tiger_observation_shape)
assert deer_observation_shape != None
assert tiger_observation_shape != None
# 'rgb_array' or 'human'
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Deer Observations: (8, 7, 7) Tiger Observations: (16, 10, 10)

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# ### Action Mapping
# Takes the limited actions (forward, left, right) and maps to the true actions (up, left, down, right,...)

# %%
deer_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
}
def deer_action_mapper(new_unmapped_action, prev_actual_action, size_of_actions=5):
    global deer_action_mapping
    return deer_action_mapping.get(new_unmapped_action, {}).get(prev_actual_action, np.random.choice(np.delete(np.arange(0, size_of_actions), 2)))

tiger_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
    3: {0: 5, 1: 6, 3: 7, 4: 8},
    4: {0: 6, 1: 8, 3: 5, 4: 7},
    5: {0: 7, 1: 5, 3: 8, 4: 6},
}

tiger_direction_mapping = {
    0: 0,
    1: 1,
    3: 3,
    4: 4,
    5: 0,
    6: 1,
    7: 3,
    8: 4,
}

def tiger_action_mapper(new_action, prev_action, size_of_actions=5): # slower
    global tiger_action_mapping, tiger_direction_mapping
    direction = tiger_direction_mapping.get(prev_action, 0)
    return tiger_action_mapping.get(new_action, {}).get(direction, 0)

def mask_observations(observations, prev_actual_action):
    current_position = (observations.shape[1] // 2, observations.shape[2] // 2)
    direction = tiger_direction_mapping.get(prev_actual_action, 0)
    # print(observations)
    if direction == 1:  # Up
        observations[:, current_position[0]:, :] = 0 # actually_left
    elif direction == 0:  # Left
        observations[:, :, current_position[1]:] = 0
    elif direction == 4:  # Right
        observations[:, :, :current_position[1]] = 0
    elif direction == 3:  # Down
        observations[:, :current_position[0]+1, :] = 0 # actually right
    else:
        raise ValueError("Direction mapping issue for mask observations")
    # print("direction: ", direction, " observations: ", observations)

# %%
def get_agent_type_from_agent_name(agent):
    if 'tiger' in agent:
        return 'tiger'
    return 'deer'

# %%
def generate_first_action(agentType):
    if 'tiger' in agentType:
        # action = np.random.randint(0,tiger_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 6))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 9), 2))
        actual_action = tiger_action_mapper(action, previous_actual_action)
    else:
        # action = np.random.randint(0,deer_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 3))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 5), 2))
        actual_action = deer_action_mapper(action, previous_actual_action)
    
    return action, actual_action, previous_actual_action

# %%
def change_active_model(activeDeer, activeTiger, deerCurrentSteps, tigerCurrentSteps, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger):
    if deerCurrentSteps >= total_steps_deer:
        return False, True
    if tigerCurrentSteps >= total_steps_tiger:
        return True, False
    if deerCurrentSteps//steps_to_switch_at_deer < tigerCurrentSteps//steps_to_switch_at_tiger:
        # if not activeDeer:
        #     print("Switching to Deer")
        return True, False
    if tigerCurrentSteps//steps_to_switch_at_tiger < deerCurrentSteps//steps_to_switch_at_deer:
        # if not activeTiger:
        #     print("Switching to Tiger")
        return False, True
    return activeDeer, activeTiger

# %%
def custom_reward_modifier(agentType, observation, prev_actual_action, reward, start_index_one_hot=3):
    if 'deer' not in agentType:
        return reward
    
    #############################################################
    # alignment reward
    alignment_reward = 0.005
    action_array = observation[prev_actual_action+start_index_one_hot]
    _, K, _ = observation.shape
    center = K//2
    # Assuming 'center' is the index of the center of the (K,K) section
    center_coords = np.array([center // K, center % K])
    coords = np.indices((K,K)).reshape(2,-1).T
    distances = np.linalg.norm(coords - center_coords, axis=1)
    # distances = distances
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    # Sum the values and print the result
    alignement_result = np.sum(values[np.isfinite(values)])
    alignement_result *= alignment_reward
    #############################################################
    # wall_penalty
    wall_penalty = -0.01
    action_array = observation[0]
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    wall_result = np.sum(values[np.isfinite(values)])
    wall_result *= wall_penalty

    return reward + alignement_result + wall_result

# %%
agent_name_to_id_dict = {str(name): index for index,name in enumerate(env.agents)}
agent_id_to_name_list = [x for x in env.agents]
def agent_name_to_id(agent_name):
    global agent_name_to_id_dict
    return agent_name_to_id_dict[agent_name]

def agent_id_to_name(id):
    global agent_id_to_name_list
    return agent_id_to_name_list[id]

# %% [markdown]
# One hot actions takes the observed actions of nearby agents and converts them to one hot actions in the observed numpy array

# %%
import numpy as np

def one_hot_actions(array, num_actions):
    # Get the shape of the input array
    K, K = array.shape

    # Create an empty output array filled with zeros
    output = np.zeros((num_actions, K, K))

    # Iterate over the range of num_actions
    for action in range(num_actions):
        # Set the corresponding elements to 1 based on the original array
        output[action, :, :] = (array == action)

    return output

# %%
import numpy as np

def get_subsection_of_env_map(array, position, size=(13, 13)):
    # Get the shape of the input array
    array_shape = array.shape

    # Create an empty output array filled with -1
    output_size = [array.shape[0]]
    output_size.extend(list(size))
    output = np.full(tuple(output_size), -1)

    # Calculate the start and end indices for the subsection
    start_row = int(position[0] - size[0] // 2)
    end_row = int(start_row + size[0])
    start_col = int(position[1] - size[1] // 2)
    end_col = int(start_col + size[1])

    # Calculate the slices for the input array and output array
    slice_row_in = slice(max(start_row, 0), min(end_row, array_shape[1]))
    slice_col_in = slice(max(start_col, 0), min(end_col, array_shape[2]))

    slice_row_out = slice(max(-start_row, 0), min(array_shape[1] - start_row, size[0]))
    slice_col_out = slice(max(-start_col, 0), min(array_shape[2] - start_col, size[1]))

    # Copy the subsection from the input array to the output array
    output[:,slice_row_out, slice_col_out] = array[:,slice_row_in, slice_col_in]

    return output

# # Example usage
# array = np.random.randint(0, 100, (2, 20, 20))
# position = (19, 0)
# sub_array = get_subsection_of_env_map(array, position, size=(11, 11))

# print(sub_array)

# %% [markdown]
# Cleans up observations by removing unncessary layers, and one hot actions.

# %%
def handle_observations(observation, obs_indices_to_keep, agent_id, env_map, num_actions):
    observation = np.transpose(observation, (2,0,1))
    observation_size = observation.shape[1]
    observation = observation[obs_indices_to_keep,:,:]
    # print(observation.shape)
    position = np.where(env_map[0,:,:] == agent_id)
    # print("Position", position)

    sub_env_map = get_subsection_of_env_map(env_map, position, size=(observation_size, observation_size))
    one_hot_actions_arr = one_hot_actions(sub_env_map[1,:,:], num_actions)
    observation = np.concatenate((observation, one_hot_actions_arr), axis=0, dtype=np.float32)
    return observation

# %% [markdown]
# ## Train Model
# ### Make Models and Loggers

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

deer_save_dir = Path("deer_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
deer_save_dir.mkdir(parents=True)

tiger_save_dir = Path("tiger_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
tiger_save_dir.mkdir(parents=True)



deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

# deer.load("deer_checkpoints\\2023-04-26T22-43-08\\animal_net_8.chkpt")
# tiger.load("tiger_checkpoints\\2023-04-26T22-43-08\\animal_net_2.chkpt")

deer_logger = MetricLogger(deer_save_dir, animal='deer')
tiger_logger = MetricLogger(tiger_save_dir, animal='tiger')


# active training flags
activeDeer = True
activeTiger = False


# Switch the training set
switching = True
steps_to_switch_at_deer = 15000
steps_to_switch_at_tiger = int((steps_to_switch_at_deer*2)//5)
total_steps_deer = 800000000
total_steps_tiger = int((total_steps_deer//3))

# divide steps to switch at to actually switch at the proper requested switching steps
# steps_to_switch_at = steps_to_switch_at//2
# if switching enabled, make sure no equivalence between active variables
if switching:
    if activeDeer == activeTiger:
        activeTiger = not activeTiger
# Out:
# Using CUDA: True
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# ### Train Basic Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            # prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            prev_observation, prev_action, prev_done, prev_actual_action = agents_prev_data[agent][0:4]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                # animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                animal.cache(prev_observation, observation, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward, info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)

#4604 basic with adv reward
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_0.chkpt at step 0
# Episode 0 - deer - Step 28615 - Epsilon 0.9928717762727763 - Mean Reward -94.575 - Mean Length 28615.0 - Mean Loss 0.002 - Mean Q Value 0.066 - Time Delta 45.704 - Time 2023-04-29T16:21:49
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_0.chkpt at step 0
# Episode 1 - tiger - Step 2207 - Epsilon 0.9994484021170325 - Mean Reward 15.0 - Mean Length 1103.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 62.04 - Time 2023-04-29T16:22:06
# Episode 2 - tiger - Step 4772 - Epsilon 0.9988077111924818 - Mean Reward 26.333 - Mean Length 1590.667 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.941 - Time 2023-04-29T16:22:21
# Episode 3 - tiger - Step 7113 - Epsilon 0.998223329927623 - Mean Reward 29.0 - Mean Length 1778.25 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 16.12 - Time 2023-04-29T16:22:37
# Episode 4 - tiger - Step 9226 - Epsilon 0.9976961576392559 - Mean Reward 29.2 - Mean Length 1845.2 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 16.008 - Time 2023-04-29T16:22:53
# Episode 5 - tiger - Step 11838 - Epsilon 0.9970448746338613 - Mean Reward 33.0 - Mean Length 1973.0 - Mean Loss 0.002 - Mean Q Value 0.001 - Time Delta 17.926 - Time 2023-04-29T16:23:11
# Episode 6 - tiger - Step 14256 - Epsilon 0.9964423430652586 - Mean Reward 34.286 - Mean Length 2036.571 - Mean Loss 0.003 - Mean Q Value -0.001 - Time Delta 19.518 - Time 2023-04-29T16:23:30
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_1.chkpt at step 50000
# Episode 7 - deer - Step 58724 - Epsilon 0.9854262386296999 - Mean Reward -21.769 - Mean Length 7340.5 - Mean Loss 0.0 - Mean Q Value 0.016 - Time Delta 161.259 - Time 2023-04-29T16:24:31
# Episode 8 - tiger - Step 16387 - Epsilon 0.9959116297218966 - Mean Reward 30.222 - Mean Length 1820.778 - Mean Loss 0.003 - Mean Q Value -0.001 - Time Delta 80.401 - Time 2023-04-29T16:24:51
# Episode 9 - tiger - Step 18917 - Epsilon 0.9952819147056623 - Mean Reward 31.7 - Mean Length 1891.7 - Mean Loss 0.004 - Mean Q Value -0.003 - Time Delta 19.846 - Time 2023-04-29T16:25:10
# Episode 10 - tiger - Step 21812 - Epsilon 0.9945618399382725 - Mean Reward 34.455 - Mean Length 1982.909 - Mean Loss 0.004 - Mean Q Value -0.005 - Time Delta 20.055 - Time 2023-04-29T16:25:30
# Episode 11 - tiger - Step 24484 - Epsilon 0.9938976943953893 - Mean Reward 35.5 - Mean Length 2040.333 - Mean Loss 0.005 - Mean Q Value -0.008 - Time Delta 20.636 - Time 2023-04-29T16:25:51
# Episode 12 - deer - Step 87229 - Epsilon 0.9784288063596578 - Mean Reward -19.217 - Mean Length 6709.923 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 141.689 - Time 2023-04-29T16:26:52
# Episode 13 - tiger - Step 26901 - Epsilon 0.9932973130469022 - Mean Reward 34.071 - Mean Length 1921.5 - Mean Loss 0.005 - Mean Q Value -0.01 - Time Delta 82.136 - Time 2023-04-29T16:27:13
# Episode 14 - tiger - Step 29615 - Epsilon 0.9926235893223117 - Mean Reward 35.2 - Mean Length 1974.333 - Mean Loss 0.005 - Mean Q Value -0.011 - Time Delta 21.819 - Time 2023-04-29T16:27:35
# Episode 15 - tiger - Step 32227 - Epsilon 0.9919756176231803 - Mean Reward 35.938 - Mean Length 2014.188 - Mean Loss 0.005 - Mean Q Value -0.009 - Time Delta 21.507 - Time 2023-04-29T16:27:57
# Episode 16 - tiger - Step 34532 - Epsilon 0.9914041562701279 - Mean Reward 36.294 - Mean Length 2031.294 - Mean Loss 0.006 - Mean Q Value -0.005 - Time Delta 21.502 - Time 2023-04-29T16:28:18
# Episode 17 - tiger - Step 36941 - Epsilon 0.9908072627999015 - Mean Reward 36.444 - Mean Length 2052.278 - Mean Loss 0.006 - Mean Q Value -0.002 - Time Delta 23.03 - Time 2023-04-29T16:28:41
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_2.chkpt at step 100000
# Episode 18 - deer - Step 115065 - Epsilon 0.971643556108162 - Mean Reward -17.684 - Mean Length 6056.053 - Mean Loss 0.0 - Mean Q Value 0.011 - Time Delta 170.612 - Time 2023-04-29T16:29:43
# Episode 19 - tiger - Step 39561 - Epsilon 0.990158496455754 - Mean Reward 34.75 - Mean Length 1978.05 - Mean Loss 0.006 - Mean Q Value 0.0 - Time Delta 85.166 - Time 2023-04-29T16:30:06
# Episode 20 - tiger - Step 41384 - Epsilon 0.9897073344808796 - Mean Reward 34.19 - Mean Length 1970.667 - Mean Loss 0.007 - Mean Q Value 0.005 - Time Delta 21.75 - Time 2023-04-29T16:30:28
# Episode 21 - tiger - Step 44355 - Epsilon 0.9889725021983552 - Mean Reward 35.227 - Mean Length 2016.136 - Mean Loss 0.007 - Mean Q Value 0.009 - Time Delta 21.541 - Time 2023-04-29T16:30:50
# Episode 22 - tiger - Step 46972 - Epsilon 0.9883256784731335 - Mean Reward 35.696 - Mean Length 2042.261 - Mean Loss 0.007 - Mean Q Value 0.014 - Time Delta 21.058 - Time 2023-04-29T16:31:11
# Episode 23 - tiger - Step 49614 - Epsilon 0.9876731048170132 - Mean Reward 36.375 - Mean Length 2067.25 - Mean Loss 0.008 - Mean Q Value 0.018 - Time Delta 21.842 - Time 2023-04-29T16:31:32
# Episode 24 - deer - Step 140241 - Epsilon 0.9655472360475286 - Mean Reward -16.467 - Mean Length 5609.64 - Mean Loss 0.0 - Mean Q Value 0.009 - Time Delta 161.89 - Time 2023-04-29T16:32:25
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_1.chkpt at step 50000
# Episode 25 - tiger - Step 52441 - Epsilon 0.9869753133739608 - Mean Reward 35.5 - Mean Length 2016.962 - Mean Loss 0.008 - Mean Q Value 0.024 - Time Delta 74.479 - Time 2023-04-29T16:32:47
# Episode 26 - tiger - Step 54785 - Epsilon 0.9863971151965794 - Mean Reward 35.556 - Mean Length 2029.074 - Mean Loss 0.008 - Mean Q Value 0.031 - Time Delta 20.837 - Time 2023-04-29T16:33:08
# Episode 27 - tiger - Step 57148 - Epsilon 0.9858145731131863 - Mean Reward 35.821 - Mean Length 2041.0 - Mean Loss 0.009 - Mean Q Value 0.037 - Time Delta 21.644 - Time 2023-04-29T16:33:29
# Episode 28 - tiger - Step 59580 - Epsilon 0.9852153799509302 - Mean Reward 35.931 - Mean Length 2054.483 - Mean Loss 0.009 - Mean Q Value 0.043 - Time Delta 21.4 - Time 2023-04-29T16:33:51
# Episode 29 - tiger - Step 61545 - Epsilon 0.98473151169485 - Mean Reward 35.633 - Mean Length 2051.5 - Mean Loss 0.009 - Mean Q Value 0.051 - Time Delta 18.647 - Time 2023-04-29T16:34:09
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_3.chkpt at step 150000
# Episode 30 - deer - Step 169016 - Epsilon 0.9586262535079269 - Mean Reward -16.419 - Mean Length 5452.129 - Mean Loss 0.0 - Mean Q Value 0.008 - Time Delta 166.471 - Time 2023-04-29T16:35:11
# Episode 31 - tiger - Step 64226 - Epsilon 0.9840717164551521 - Mean Reward 34.875 - Mean Length 2007.062 - Mean Loss 0.009 - Mean Q Value 0.058 - Time Delta 84.514 - Time 2023-04-29T16:35:34
# Episode 32 - tiger - Step 67261 - Epsilon 0.983325335141109 - Mean Reward 35.606 - Mean Length 2038.212 - Mean Loss 0.01 - Mean Q Value 0.065 - Time Delta 21.702 - Time 2023-04-29T16:35:56
# Episode 33 - tiger - Step 69460 - Epsilon 0.9827849005360595 - Mean Reward 35.735 - Mean Length 2042.941 - Mean Loss 0.01 - Mean Q Value 0.072 - Time Delta 20.863 - Time 2023-04-29T16:36:17
# Episode 34 - tiger - Step 71613 - Epsilon 0.9822560588344591 - Mean Reward 35.771 - Mean Length 2046.086 - Mean Loss 0.01 - Mean Q Value 0.081 - Time Delta 21.506 - Time 2023-04-29T16:36:38
# Episode 35 - tiger - Step 74730 - Epsilon 0.9814909338554021 - Mean Reward 36.417 - Mean Length 2075.833 - Mean Loss 0.01 - Mean Q Value 0.089 - Time Delta 21.871 - Time 2023-04-29T16:37:00
# Episode 36 - deer - Step 196092 - Epsilon 0.9521592239431269 - Mean Reward -15.278 - Mean Length 5299.784 - Mean Loss 0.0 - Mean Q Value 0.007 - Time Delta 164.649 - Time 2023-04-29T16:37:56
# Episode 37 - tiger - Step 77620 - Epsilon 0.9807820626775322 - Mean Reward 36.0 - Mean Length 2042.632 - Mean Loss 0.01 - Mean Q Value 0.095 - Time Delta 78.674 - Time 2023-04-29T16:38:19
# Episode 38 - tiger - Step 80066 - Epsilon 0.9801824977068483 - Mean Reward 36.026 - Mean Length 2052.974 - Mean Loss 0.011 - Mean Q Value 0.102 - Time Delta 22.803 - Time 2023-04-29T16:38:41
# Episode 39 - tiger - Step 82186 - Epsilon 0.9796631385604024 - Mean Reward 35.85 - Mean Length 2054.65 - Mean Loss 0.011 - Mean Q Value 0.112 - Time Delta 21.705 - Time 2023-04-29T16:39:03
# Episode 40 - tiger - Step 84258 - Epsilon 0.9791558044020311 - Mean Reward 35.902 - Mean Length 2055.073 - Mean Loss 0.011 - Mean Q Value 0.121 - Time Delta 21.246 - Time 2023-04-29T16:39:24
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_4.chkpt at step 200000
# Episode 41 - deer - Step 225306 - Epsilon 0.9452304610927003 - Mean Reward -15.653 - Mean Length 5364.429 - Mean Loss 0.0 - Mean Q Value 0.006 - Time Delta 150.537 - Time 2023-04-29T16:40:26
# Episode 42 - tiger - Step 87363 - Epsilon 0.9783960295395581 - Mean Reward 35.837 - Mean Length 2031.698 - Mean Loss 0.011 - Mean Q Value 0.127 - Time Delta 83.796 - Time 2023-04-29T16:40:48
# Episode 43 - tiger - Step 89893 - Epsilon 0.977777389638951 - Mean Reward 36.045 - Mean Length 2043.023 - Mean Loss 0.011 - Mean Q Value 0.135 - Time Delta 22.181 - Time 2023-04-29T16:41:10
# Episode 44 - tiger - Step 92188 - Epsilon 0.9772165506975178 - Mean Reward 36.133 - Mean Length 2048.622 - Mean Loss 0.012 - Mean Q Value 0.144 - Time Delta 23.011 - Time 2023-04-29T16:41:33
# Episode 45 - tiger - Step 94636 - Epsilon 0.9766186770616693 - Mean Reward 36.348 - Mean Length 2057.304 - Mean Loss 0.012 - Mean Q Value 0.153 - Time Delta 22.203 - Time 2023-04-29T16:41:56
# Episode 46 - tiger - Step 97083 - Epsilon 0.9760214132179391 - Mean Reward 36.596 - Mean Length 2065.596 - Mean Loss 0.012 - Mean Q Value 0.161 - Time Delta 21.796 - Time 2023-04-29T16:42:17
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_5.chkpt at step 250000
# Episode 47 - deer - Step 250884 - Epsilon 0.9392054680941131 - Mean Reward -15.132 - Mean Length 5226.75 - Mean Loss 0.0 - Mean Q Value 0.006 - Time Delta 168.289 - Time 2023-04-29T16:43:15
# Episode 48 - deer - Step 277379 - Epsilon 0.9330049630665838 - Mean Reward -16.081 - Mean Length 5660.796 - Mean Loss 0.0 - Mean Q Value 0.006 - Time Delta 59.757 - Time 2023-04-29T16:44:14
# Episode 49 - tiger - Step 99996 - Epsilon 0.9753108842875964 - Mean Reward 35.6 - Mean Length 1999.92 - Mean Loss 0.012 - Mean Q Value 0.162 - Time Delta 140.096 - Time 2023-04-29T16:44:37
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_2.chkpt at step 100000
# Episode 50 - tiger - Step 102410 - Epsilon 0.9747224616696806 - Mean Reward 35.725 - Mean Length 2008.039 - Mean Loss 0.012 - Mean Q Value 0.171 - Time Delta 22.849 - Time 2023-04-29T16:45:00
# Episode 51 - tiger - Step 105117 - Epsilon 0.974063041317754 - Mean Reward 36.25 - Mean Length 2021.481 - Mean Loss 0.012 - Mean Q Value 0.179 - Time Delta 21.964 - Time 2023-04-29T16:45:22
# Episode 52 - tiger - Step 107429 - Epsilon 0.9735001954875542 - Mean Reward 36.453 - Mean Length 2026.962 - Mean Loss 0.012 - Mean Q Value 0.187 - Time Delta 21.985 - Time 2023-04-29T16:45:44
# Episode 53 - tiger - Step 110071 - Epsilon 0.9728574108309991 - Mean Reward 36.741 - Mean Length 2038.352 - Mean Loss 0.012 - Mean Q Value 0.195 - Time Delta 22.481 - Time 2023-04-29T16:46:07
# Episode 54 - tiger - Step 112969 - Epsilon 0.9721528308136108 - Mean Reward 36.982 - Mean Length 2053.982 - Mean Loss 0.012 - Mean Q Value 0.203 - Time Delta 23.252 - Time 2023-04-29T16:46:30
# Episode 55 - tiger - Step 115724 - Epsilon 0.9714834909979884 - Mean Reward 37.357 - Mean Length 2066.5 - Mean Loss 0.012 - Mean Q Value 0.212 - Time Delta 22.789 - Time 2023-04-29T16:46:53
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_6.chkpt at step 300000
# Episode 56 - deer - Step 303207 - Epsilon 0.9269999572935356 - Mean Reward -15.114 - Mean Length 5319.421 - Mean Loss 0.0 - Mean Q Value 0.005 - Time Delta 216.793 - Time 2023-04-29T16:47:51
# Episode 57 - tiger - Step 118198 - Epsilon 0.9708828141620972 - Mean Reward 36.776 - Mean Length 2037.897 - Mean Loss 0.012 - Mean Q Value 0.216 - Time Delta 82.065 - Time 2023-04-29T16:48:15
# Episode 58 - tiger - Step 120959 - Epsilon 0.9702128934487734 - Mean Reward 37.186 - Mean Length 2050.153 - Mean Loss 0.012 - Mean Q Value 0.224 - Time Delta 23.058 - Time 2023-04-29T16:48:38
# Episode 59 - tiger - Step 123160 - Epsilon 0.9696791805885776 - Mean Reward 37.133 - Mean Length 2052.667 - Mean Loss 0.013 - Mean Q Value 0.232 - Time Delta 23.927 - Time 2023-04-29T16:49:02
# Episode 60 - tiger - Step 125739 - Epsilon 0.9690541813644568 - Mean Reward 37.344 - Mean Length 2061.295 - Mean Loss 0.013 - Mean Q Value 0.24 - Time Delta 22.456 - Time 2023-04-29T16:49:24
# Episode 61 - tiger - Step 128110 - Epsilon 0.9684799446328184 - Mean Reward 37.452 - Mean Length 2066.29 - Mean Loss 0.013 - Mean Q Value 0.248 - Time Delta 23.006 - Time 2023-04-29T16:49:47
# Episode 62 - deer - Step 329355 - Epsilon 0.9209599211836247 - Mean Reward -14.682 - Mean Length 5227.857 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 172.799 - Time 2023-04-29T16:50:44
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_7.chkpt at step 350000
# Episode 63 - deer - Step 356727 - Epsilon 0.9146793052926075 - Mean Reward -15.56 - Mean Length 5573.859 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 58.584 - Time 2023-04-29T16:51:43
# Episode 64 - tiger - Step 130947 - Epsilon 0.9677932936785382 - Mean Reward 36.615 - Mean Length 2014.569 - Mean Loss 0.012 - Mean Q Value 0.248 - Time Delta 138.925 - Time 2023-04-29T16:52:06
# Episode 65 - tiger - Step 133654 - Epsilon 0.9671385610552476 - Mean Reward 36.818 - Mean Length 2025.061 - Mean Loss 0.013 - Mean Q Value 0.257 - Time Delta 23.062 - Time 2023-04-29T16:52:29
# Episode 66 - tiger - Step 136495 - Epsilon 0.96645189468759 - Mean Reward 37.06 - Mean Length 2037.239 - Mean Loss 0.013 - Mean Q Value 0.265 - Time Delta 23.031 - Time 2023-04-29T16:52:52
# Episode 67 - tiger - Step 138865 - Epsilon 0.965879441474359 - Mean Reward 37.221 - Mean Length 2042.132 - Mean Loss 0.013 - Mean Q Value 0.273 - Time Delta 22.332 - Time 2023-04-29T16:53:15
# Episode 68 - tiger - Step 141094 - Epsilon 0.9653413550265214 - Mean Reward 37.232 - Mean Length 2044.841 - Mean Loss 0.013 - Mean Q Value 0.281 - Time Delta 23.427 - Time 2023-04-29T16:53:38
# Episode 69 - tiger - Step 143670 - Epsilon 0.9647198752540777 - Mean Reward 37.5 - Mean Length 2052.429 - Mean Loss 0.013 - Mean Q Value 0.289 - Time Delta 22.592 - Time 2023-04-29T16:54:01
# Episode 70 - tiger - Step 145920 - Epsilon 0.9641773728494643 - Mean Reward 37.676 - Mean Length 2055.211 - Mean Loss 0.013 - Mean Q Value 0.297 - Time Delta 22.215 - Time 2023-04-29T16:54:23
# Episode 71 - deer - Step 385691 - Epsilon 0.9080800331165191 - Mean Reward -14.639 - Mean Length 5356.819 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 224.074 - Time 2023-04-29T16:55:27
# Episode 72 - tiger - Step 148200 - Epsilon 0.9636279482790643 - Mean Reward 37.274 - Mean Length 2030.137 - Mean Loss 0.013 - Mean Q Value 0.301 - Time Delta 86.509 - Time 2023-04-29T16:55:49
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_3.chkpt at step 150000
# Episode 73 - tiger - Step 150714 - Epsilon 0.963022498320384 - Mean Reward 37.514 - Mean Length 2036.676 - Mean Loss 0.013 - Mean Q Value 0.309 - Time Delta 22.504 - Time 2023-04-29T16:56:12
# Episode 74 - tiger - Step 153498 - Epsilon 0.9623524677753822 - Mean Reward 37.667 - Mean Length 2046.64 - Mean Loss 0.013 - Mean Q Value 0.317 - Time Delta 23.885 - Time 2023-04-29T16:56:36
# Episode 75 - tiger - Step 156370 - Epsilon 0.9616617466156525 - Mean Reward 37.961 - Mean Length 2057.5 - Mean Loss 0.013 - Mean Q Value 0.324 - Time Delta 22.859 - Time 2023-04-29T16:56:59
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_8.chkpt at step 400000
# Episode 76 - deer - Step 413174 - Epsilon 0.9018622264090358 - Mean Reward -14.501 - Mean Length 5365.896 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 152.266 - Time 2023-04-29T16:57:59
# Episode 77 - tiger - Step 159096 - Epsilon 0.9610065973208285 - Mean Reward 37.654 - Mean Length 2039.692 - Mean Loss 0.013 - Mean Q Value 0.327 - Time Delta 85.152 - Time 2023-04-29T16:58:24
# Episode 78 - tiger - Step 162293 - Epsilon 0.9602388195658977 - Mean Reward 38.0 - Mean Length 2054.342 - Mean Loss 0.013 - Mean Q Value 0.335 - Time Delta 22.916 - Time 2023-04-29T16:58:47
# Episode 79 - tiger - Step 165060 - Epsilon 0.9595748039722388 - Mean Reward 38.175 - Mean Length 2063.25 - Mean Loss 0.013 - Mean Q Value 0.343 - Time Delta 22.865 - Time 2023-04-29T16:59:10
# Episode 80 - tiger - Step 167951 - Epsilon 0.9588815217609455 - Mean Reward 38.407 - Mean Length 2073.469 - Mean Loss 0.013 - Mean Q Value 0.351 - Time Delta 23.163 - Time 2023-04-29T16:59:33
# Episode 81 - tiger - Step 170266 - Epsilon 0.9583267295692747 - Mean Reward 38.524 - Mean Length 2076.415 - Mean Loss 0.013 - Mean Q Value 0.358 - Time Delta 23.028 - Time 2023-04-29T16:59:56
# Episode 82 - deer - Step 441882 - Epsilon 0.8954127320974288 - Mean Reward -14.18 - Mean Length 5323.88 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 178.07 - Time 2023-04-29T17:00:57
# Episode 83 - tiger - Step 172713 - Epsilon 0.9577406524037504 - Mean Reward 38.131 - Mean Length 2056.107 - Mean Loss 0.013 - Mean Q Value 0.361 - Time Delta 84.009 - Time 2023-04-29T17:01:20
# Episode 84 - tiger - Step 175239 - Epsilon 0.9571360300357007 - Mean Reward 38.212 - Mean Length 2061.635 - Mean Loss 0.013 - Mean Q Value 0.369 - Time Delta 24.341 - Time 2023-04-29T17:01:44
# Episode 85 - tiger - Step 177825 - Epsilon 0.9565174414951654 - Mean Reward 38.395 - Mean Length 2067.733 - Mean Loss 0.014 - Mean Q Value 0.376 - Time Delta 21.598 - Time 2023-04-29T17:02:06
# Episode 86 - tiger - Step 180454 - Epsilon 0.9558889768799047 - Mean Reward 38.598 - Mean Length 2074.184 - Mean Loss 0.014 - Mean Q Value 0.383 - Time Delta 22.057 - Time 2023-04-29T17:02:28
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_9.chkpt at step 450000
# Episode 87 - deer - Step 468634 - Epsilon 0.8894441920435885 - Mean Reward -14.037 - Mean Length 5325.386 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 148.401 - Time 2023-04-29T17:03:25
# Episode 88 - tiger - Step 182707 - Epsilon 0.9553507239460326 - Mean Reward 38.191 - Mean Length 2052.888 - Mean Loss 0.013 - Mean Q Value 0.386 - Time Delta 80.613 - Time 2023-04-29T17:03:48
# Episode 89 - tiger - Step 185004 - Epsilon 0.9548022712137368 - Mean Reward 38.256 - Mean Length 2055.6 - Mean Loss 0.014 - Mean Q Value 0.393 - Time Delta 23.204 - Time 2023-04-29T17:04:12
# Episode 90 - tiger - Step 188097 - Epsilon 0.95406425563721 - Mean Reward 38.582 - Mean Length 2067.0 - Mean Loss 0.014 - Mean Q Value 0.4 - Time Delta 22.705 - Time 2023-04-29T17:04:34
# Episode 91 - tiger - Step 190606 - Epsilon 0.9534660064035291 - Mean Reward 38.707 - Mean Length 2071.804 - Mean Loss 0.014 - Mean Q Value 0.406 - Time Delta 23.84 - Time 2023-04-29T17:04:58
# Episode 92 - tiger - Step 193504 - Epsilon 0.9527754703723581 - Mean Reward 38.978 - Mean Length 2080.688 - Mean Loss 0.014 - Mean Q Value 0.413 - Time Delta 22.635 - Time 2023-04-29T17:05:21
# Episode 93 - deer - Step 495059 - Epsilon 0.883587666751579 - Mean Reward -13.721 - Mean Length 5266.585 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 172.495 - Time 2023-04-29T17:06:18
# Episode 94 - tiger - Step 195926 - Epsilon 0.9521987393758053 - Mean Reward 38.579 - Mean Length 2062.379 - Mean Loss 0.014 - Mean Q Value 0.415 - Time Delta 82.086 - Time 2023-04-29T17:06:43
# Episode 95 - tiger - Step 198196 - Epsilon 0.9516585198254053 - Mean Reward 38.573 - Mean Length 2064.542 - Mean Loss 0.014 - Mean Q Value 0.422 - Time Delta 24.582 - Time 2023-04-29T17:07:07
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_4.chkpt at step 200000
# Episode 96 - tiger - Step 200944 - Epsilon 0.9510049548657664 - Mean Reward 38.784 - Mean Length 2071.588 - Mean Loss 0.014 - Mean Q Value 0.428 - Time Delta 24.209 - Time 2023-04-29T17:07:32
# Episode 97 - tiger - Step 203485 - Epsilon 0.9504010207374982 - Mean Reward 38.929 - Mean Length 2076.378 - Mean Loss 0.014 - Mean Q Value 0.434 - Time Delta 23.459 - Time 2023-04-29T17:07:55
# Episode 98 - tiger - Step 206184 - Epsilon 0.9497599538727864 - Mean Reward 38.949 - Mean Length 2082.667 - Mean Loss 0.014 - Mean Q Value 0.44 - Time Delta 25.026 - Time 2023-04-29T17:08:20
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_10.chkpt at step 500000
# Episode 99 - deer - Step 523827 - Epsilon 0.8772557005038576 - Mean Reward -13.57 - Mean Length 5238.27 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 184.502 - Time 2023-04-29T17:09:22
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_11.chkpt at step 550000
# Episode 100 - deer - Step 550559 - Epsilon 0.8714125465725099 - Mean Reward -13.277 - Mean Length 5219.44 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 58.221 - Time 2023-04-29T17:10:21
# Episode 101 - tiger - Step 208562 - Epsilon 0.9491954893132867 - Mean Reward 38.7 - Mean Length 2063.55 - Mean Loss 0.014 - Mean Q Value 0.446 - Time Delta 145.409 - Time 2023-04-29T17:10:45
# Episode 102 - tiger - Step 211117 - Epsilon 0.9485893842140642 - Mean Reward 38.7 - Mean Length 2063.45 - Mean Loss 0.014 - Mean Q Value 0.457 - Time Delta 24.189 - Time 2023-04-29T17:11:10
# Episode 103 - tiger - Step 213558 - Epsilon 0.9480106840637686 - Mean Reward 38.82 - Mean Length 2064.45 - Mean Loss 0.014 - Mean Q Value 0.467 - Time Delta 23.275 - Time 2023-04-29T17:11:33
# Episode 104 - tiger - Step 216338 - Epsilon 0.9473520454593477 - Mean Reward 39.07 - Mean Length 2071.12 - Mean Loss 0.014 - Mean Q Value 0.478 - Time Delta 23.856 - Time 2023-04-29T17:11:57
# Episode 105 - tiger - Step 218517 - Epsilon 0.9468361159070912 - Mean Reward 38.93 - Mean Length 2066.79 - Mean Loss 0.015 - Mean Q Value 0.489 - Time Delta 24.84 - Time 2023-04-29T17:12:22
# Episode 106 - tiger - Step 220846 - Epsilon 0.9462849809743638 - Mean Reward 38.85 - Mean Length 2065.9 - Mean Loss 0.015 - Mean Q Value 0.499 - Time Delta 26.415 - Time 2023-04-29T17:12:48
# Episode 107 - tiger - Step 223579 - Epsilon 0.9456386525073397 - Mean Reward 39.39 - Mean Length 2093.23 - Mean Loss 0.015 - Mean Q Value 0.51 - Time Delta 24.397 - Time 2023-04-29T17:13:12
# Episode 108 - deer - Step 579828 - Epsilon 0.8650594741769891 - Mean Reward -13.088 - Mean Length 5211.04 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 233.705 - Time 2023-04-29T17:14:14
# Episode 109 - tiger - Step 226430 - Epsilon 0.9449648886145757 - Mean Reward 39.2 - Mean Length 2075.13 - Mean Loss 0.015 - Mean Q Value 0.52 - Time Delta 86.219 - Time 2023-04-29T17:14:39
# Episode 110 - tiger - Step 228632 - Epsilon 0.9444448285379828 - Mean Reward 39.02 - Mean Length 2068.2 - Mean Loss 0.015 - Mean Q Value 0.531 - Time Delta 24.283 - Time 2023-04-29T17:15:03
# Episode 111 - tiger - Step 230944 - Epsilon 0.9438990970903776 - Mean Reward 39.0 - Mean Length 2064.6 - Mean Loss 0.015 - Mean Q Value 0.542 - Time Delta 23.603 - Time 2023-04-29T17:15:27
# Episode 112 - tiger - Step 233453 - Epsilon 0.9433072219539076 - Mean Reward 39.55 - Mean Length 2089.69 - Mean Loss 0.015 - Mean Q Value 0.553 - Time Delta 23.193 - Time 2023-04-29T17:15:50
# Episode 113 - tiger - Step 235788 - Epsilon 0.9427567269855559 - Mean Reward 39.6 - Mean Length 2088.87 - Mean Loss 0.015 - Mean Q Value 0.564 - Time Delta 23.388 - Time 2023-04-29T17:16:13
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_12.chkpt at step 600000
# Episode 114 - deer - Step 608282 - Epsilon 0.8589277078565165 - Mean Reward -12.949 - Mean Length 5210.53 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 180.489 - Time 2023-04-29T17:17:15
# Episode 115 - tiger - Step 238246 - Epsilon 0.9421775808652206 - Mean Reward 39.11 - Mean Length 2060.19 - Mean Loss 0.015 - Mean Q Value 0.574 - Time Delta 86.464 - Time 2023-04-29T17:17:40
# Episode 116 - tiger - Step 240792 - Epsilon 0.941578075572777 - Mean Reward 39.15 - Mean Length 2062.6 - Mean Loss 0.015 - Mean Q Value 0.584 - Time Delta 24.446 - Time 2023-04-29T17:18:04
# Episode 117 - tiger - Step 243414 - Epsilon 0.9409610733116143 - Mean Reward 39.33 - Mean Length 2064.73 - Mean Loss 0.015 - Mean Q Value 0.594 - Time Delta 23.355 - Time 2023-04-29T17:18:27
# Episode 118 - tiger - Step 245914 - Epsilon 0.9403731563104246 - Mean Reward 39.82 - Mean Length 2089.73 - Mean Loss 0.015 - Mean Q Value 0.605 - Time Delta 24.381 - Time 2023-04-29T17:18:52
# Episode 119 - tiger - Step 248394 - Epsilon 0.9397903055829703 - Mean Reward 39.94 - Mean Length 2088.33 - Mean Loss 0.015 - Mean Q Value 0.615 - Time Delta 23.877 - Time 2023-04-29T17:19:16
# Episode 120 - deer - Step 635158 - Epsilon 0.8531759166489008 - Mean Reward -12.733 - Mean Length 5200.93 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 176.782 - Time 2023-04-29T17:20:12
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_5.chkpt at step 250000
# Episode 121 - tiger - Step 250979 - Epsilon 0.9391831622263379 - Mean Reward 39.7 - Mean Length 2066.24 - Mean Loss 0.015 - Mean Q Value 0.623 - Time Delta 80.722 - Time 2023-04-29T17:20:36
# Episode 122 - tiger - Step 253446 - Epsilon 0.9386040995253847 - Mean Reward 39.86 - Mean Length 2064.74 - Mean Loss 0.015 - Mean Q Value 0.633 - Time Delta 23.445 - Time 2023-04-29T17:21:00
# Episode 123 - tiger - Step 255866 - Epsilon 0.9380364157158012 - Mean Reward 39.8 - Mean Length 2062.52 - Mean Loss 0.015 - Mean Q Value 0.642 - Time Delta 24.236 - Time 2023-04-29T17:21:24
# Episode 124 - tiger - Step 258452 - Epsilon 0.9374301710868689 - Mean Reward 40.37 - Mean Length 2088.38 - Mean Loss 0.016 - Mean Q Value 0.653 - Time Delta 22.128 - Time 2023-04-29T17:21:46
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_13.chkpt at step 650000
# Episode 125 - deer - Step 659793 - Epsilon 0.8479375662196996 - Mean Reward -12.418 - Mean Length 5195.52 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 147.972 - Time 2023-04-29T17:22:40
# Episode 126 - deer - Step 686927 - Epsilon 0.8422050462786164 - Mean Reward -12.883 - Mean Length 5466.86 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 58.573 - Time 2023-04-29T17:23:38
# Episode 127 - tiger - Step 260938 - Epsilon 0.9368477391721193 - Mean Reward 39.63 - Mean Length 2037.9 - Mean Loss 0.015 - Mean Q Value 0.657 - Time Delta 135.296 - Time 2023-04-29T17:24:01
# Episode 128 - tiger - Step 263347 - Epsilon 0.9362836924162478 - Mean Reward 39.75 - Mean Length 2037.67 - Mean Loss 0.015 - Mean Q Value 0.666 - Time Delta 22.822 - Time 2023-04-29T17:24:24
# Episode 129 - tiger - Step 265803 - Epsilon 0.9357089906086915 - Mean Reward 40.01 - Mean Length 2042.58 - Mean Loss 0.015 - Mean Q Value 0.674 - Time Delta 23.778 - Time 2023-04-29T17:24:48
# Episode 130 - tiger - Step 268207 - Epsilon 0.9351467983906673 - Mean Reward 40.54 - Mean Length 2066.62 - Mean Loss 0.015 - Mean Q Value 0.684 - Time Delta 23.257 - Time 2023-04-29T17:25:11
# Episode 131 - tiger - Step 270867 - Epsilon 0.934525132418788 - Mean Reward 40.69 - Mean Length 2066.41 - Mean Loss 0.015 - Mean Q Value 0.692 - Time Delta 22.593 - Time 2023-04-29T17:25:34
# Episode 132 - tiger - Step 273357 - Epsilon 0.9339435714807033 - Mean Reward 40.64 - Mean Length 2060.96 - Mean Loss 0.015 - Mean Q Value 0.699 - Time Delta 24.657 - Time 2023-04-29T17:25:59
# Episode 133 - tiger - Step 275913 - Epsilon 0.9333469720976723 - Mean Reward 40.74 - Mean Length 2064.53 - Mean Loss 0.015 - Mean Q Value 0.707 - Time Delta 25.673 - Time 2023-04-29T17:26:24
# Episode 134 - tiger - Step 278577 - Epsilon 0.9327255698863998 - Mean Reward 40.89 - Mean Length 2069.64 - Mean Loss 0.015 - Mean Q Value 0.714 - Time Delta 24.993 - Time 2023-04-29T17:26:49
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_14.chkpt at step 700000
# Episode 135 - deer - Step 711605 - Epsilon 0.8370250569996717 - Mean Reward -12.355 - Mean Length 5425.89 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 243.706 - Time 2023-04-29T17:27:42
# Episode 136 - tiger - Step 281365 - Epsilon 0.9320756865934985 - Mean Reward 40.85 - Mean Length 2066.35 - Mean Loss 0.015 - Mean Q Value 0.721 - Time Delta 78.627 - Time 2023-04-29T17:28:08
# Episode 137 - tiger - Step 283553 - Epsilon 0.9315659805464606 - Mean Reward 40.67 - Mean Length 2059.33 - Mean Loss 0.015 - Mean Q Value 0.728 - Time Delta 25.124 - Time 2023-04-29T17:28:33
# Episode 138 - tiger - Step 286663 - Epsilon 0.930841969401788 - Mean Reward 40.97 - Mean Length 2065.97 - Mean Loss 0.015 - Mean Q Value 0.735 - Time Delta 23.847 - Time 2023-04-29T17:28:57
# Episode 139 - tiger - Step 289551 - Epsilon 0.9301701439739735 - Mean Reward 41.31 - Mean Length 2073.65 - Mean Loss 0.015 - Mean Q Value 0.741 - Time Delta 23.177 - Time 2023-04-29T17:29:20
# Episode 140 - deer - Step 738890 - Epsilon 0.8313349280767158 - Mean Reward -12.225 - Mean Length 5427.98 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 157.64 - Time 2023-04-29T17:30:20
# Episode 141 - tiger - Step 292030 - Epsilon 0.9295938495528066 - Mean Reward 41.5 - Mean Length 2077.72 - Mean Loss 0.015 - Mean Q Value 0.748 - Time Delta 83.444 - Time 2023-04-29T17:30:43
# Episode 142 - tiger - Step 294557 - Epsilon 0.9290067640300451 - Mean Reward 41.37 - Mean Length 2071.94 - Mean Loss 0.015 - Mean Q Value 0.754 - Time Delta 24.447 - Time 2023-04-29T17:31:08
# Episode 143 - tiger - Step 296931 - Epsilon 0.9284555620319888 - Mean Reward 41.45 - Mean Length 2070.38 - Mean Loss 0.015 - Mean Q Value 0.76 - Time Delta 24.216 - Time 2023-04-29T17:31:32
# Episode 144 - tiger - Step 299780 - Epsilon 0.9277945049221161 - Mean Reward 41.68 - Mean Length 2075.92 - Mean Loss 0.015 - Mean Q Value 0.766 - Time Delta 23.617 - Time 2023-04-29T17:31:56
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_6.chkpt at step 300000
# Episode 145 - tiger - Step 302579 - Epsilon 0.9271455077304551 - Mean Reward 41.9 - Mean Length 2079.43 - Mean Loss 0.015 - Mean Q Value 0.772 - Time Delta 23.102 - Time 2023-04-29T17:32:19
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_15.chkpt at step 750000
# Episode 146 - deer - Step 765576 - Epsilon 0.8258071362468892 - Mean Reward -11.648 - Mean Length 5402.7 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 176.662 - Time 2023-04-29T17:33:16
# Episode 147 - tiger - Step 304866 - Epsilon 0.9266155637322706 - Mean Reward 41.84 - Mean Length 2077.83 - Mean Loss 0.015 - Mean Q Value 0.777 - Time Delta 83.247 - Time 2023-04-29T17:33:42
# Episode 148 - tiger - Step 307770 - Epsilon 0.925943084888205 - Mean Reward 42.56 - Mean Length 2106.87 - Mean Loss 0.015 - Mean Q Value 0.788 - Time Delta 22.24 - Time 2023-04-29T17:34:04
# Episode 149 - tiger - Step 310080 - Epsilon 0.9254085070639841 - Mean Reward 42.38 - Mean Length 2100.84 - Mean Loss 0.015 - Mean Q Value 0.794 - Time Delta 25.637 - Time 2023-04-29T17:34:30
# Episode 150 - tiger - Step 312654 - Epsilon 0.9248131981763672 - Mean Reward 42.51 - Mean Length 2102.44 - Mean Loss 0.015 - Mean Q Value 0.799 - Time Delta 24.22 - Time 2023-04-29T17:34:54
# Episode 151 - deer - Step 791736 - Epsilon 0.8204239790135122 - Mean Reward -10.871 - Mean Length 5143.57 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 155.356 - Time 2023-04-29T17:35:52
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_16.chkpt at step 800000
# Episode 152 - deer - Step 816624 - Epsilon 0.8153351481491976 - Mean Reward -11.261 - Mean Length 5392.45 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 53.645 - Time 2023-04-29T17:36:45
# Episode 153 - tiger - Step 314750 - Epsilon 0.9243287229434923 - Mean Reward 41.38 - Mean Length 2046.79 - Mean Loss 0.015 - Mean Q Value 0.792 - Time Delta 135.593 - Time 2023-04-29T17:37:10
# Episode 154 - tiger - Step 317133 - Epsilon 0.9237782180358387 - Mean Reward 41.36 - Mean Length 2041.64 - Mean Loss 0.015 - Mean Q Value 0.797 - Time Delta 25.966 - Time 2023-04-29T17:37:36
# Episode 155 - tiger - Step 320010 - Epsilon 0.9231140293568904 - Mean Reward 41.35 - Mean Length 2042.86 - Mean Loss 0.015 - Mean Q Value 0.801 - Time Delta 25.171 - Time 2023-04-29T17:38:01
# Episode 156 - tiger - Step 322419 - Epsilon 0.9225582512386438 - Mean Reward 41.78 - Mean Length 2066.95 - Mean Loss 0.015 - Mean Q Value 0.813 - Time Delta 26.5 - Time 2023-04-29T17:38:27
# Episode 157 - tiger - Step 324654 - Epsilon 0.9220429157365385 - Mean Reward 41.86 - Mean Length 2064.56 - Mean Loss 0.015 - Mean Q Value 0.817 - Time Delta 25.476 - Time 2023-04-29T17:38:53
# Episode 158 - tiger - Step 327630 - Epsilon 0.9213571708501489 - Mean Reward 41.88 - Mean Length 2066.71 - Mean Loss 0.015 - Mean Q Value 0.821 - Time Delta 24.664 - Time 2023-04-29T17:39:18
# Episode 159 - tiger - Step 330479 - Epsilon 0.9207011677699488 - Mean Reward 42.1 - Mean Length 2073.19 - Mean Loss 0.015 - Mean Q Value 0.825 - Time Delta 25.154 - Time 2023-04-29T17:39:43
# Episode 160 - deer - Step 841157 - Epsilon 0.8103497970579614 - Mean Reward -11.101 - Mean Length 5379.5 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 232.453 - Time 2023-04-29T17:40:38
# Episode 161 - tiger - Step 332739 - Epsilon 0.9201811184728398 - Mean Reward 41.64 - Mean Length 2046.29 - Mean Loss 0.015 - Mean Q Value 0.822 - Time Delta 80.575 - Time 2023-04-29T17:41:03
# Episode 162 - tiger - Step 335197 - Epsilon 0.9196158408041514 - Mean Reward 42.18 - Mean Length 2070.87 - Mean Loss 0.015 - Mean Q Value 0.833 - Time Delta 25.636 - Time 2023-04-29T17:41:29
# Episode 163 - tiger - Step 337812 - Epsilon 0.9190148383470997 - Mean Reward 42.68 - Mean Length 2097.02 - Mean Loss 0.015 - Mean Q Value 0.844 - Time Delta 25.928 - Time 2023-04-29T17:41:55
# Episode 164 - tiger - Step 340238 - Epsilon 0.9184576247700108 - Mean Reward 42.67 - Mean Length 2092.91 - Mean Loss 0.015 - Mean Q Value 0.848 - Time Delta 24.32 - Time 2023-04-29T17:42:19
# Episode 165 - tiger - Step 342583 - Epsilon 0.9179193367212249 - Mean Reward 42.7 - Mean Length 2089.29 - Mean Loss 0.015 - Mean Q Value 0.85 - Time Delta 24.833 - Time 2023-04-29T17:42:44
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_17.chkpt at step 850000
# Episode 166 - deer - Step 865942 - Epsilon 0.8053441905115486 - Mean Reward -10.11 - Mean Length 5092.15 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 180.277 - Time 2023-04-29T17:43:38
# Episode 167 - deer - Step 890700 - Epsilon 0.8003749065783732 - Mean Reward -10.552 - Mean Length 5339.73 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 54.338 - Time 2023-04-29T17:44:32
# Episode 168 - tiger - Step 345118 - Epsilon 0.9173377895660223 - Mean Reward 41.96 - Mean Length 2040.24 - Mean Loss 0.015 - Mean Q Value 0.837 - Time Delta 131.576 - Time 2023-04-29T17:44:56
# Episode 169 - tiger - Step 347296 - Epsilon 0.9168384350387209 - Mean Reward 41.81 - Mean Length 2036.26 - Mean Loss 0.015 - Mean Q Value 0.839 - Time Delta 26.672 - Time 2023-04-29T17:45:22
# Episode 170 - tiger - Step 349552 - Epsilon 0.9163214838905924 - Mean Reward 41.85 - Mean Length 2036.32 - Mean Loss 0.015 - Mean Q Value 0.841 - Time Delta 24.528 - Time 2023-04-29T17:45:47
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_7.chkpt at step 350000
# Episode 171 - tiger - Step 352294 - Epsilon 0.915693560680077 - Mean Reward 42.49 - Mean Length 2063.74 - Mean Loss 0.015 - Mean Q Value 0.852 - Time Delta 25.259 - Time 2023-04-29T17:46:12
# Episode 172 - tiger - Step 355180 - Epsilon 0.9150331259738703 - Mean Reward 42.72 - Mean Length 2069.8 - Mean Loss 0.015 - Mean Q Value 0.855 - Time Delta 24.51 - Time 2023-04-29T17:46:37
# Episode 173 - tiger - Step 357318 - Epsilon 0.9145441713916022 - Mean Reward 42.71 - Mean Length 2066.04 - Mean Loss 0.015 - Mean Q Value 0.857 - Time Delta 25.936 - Time 2023-04-29T17:47:03
# Episode 174 - tiger - Step 359525 - Epsilon 0.9140397107627836 - Mean Reward 42.67 - Mean Length 2060.27 - Mean Loss 0.015 - Mean Q Value 0.859 - Time Delta 26.241 - Time 2023-04-29T17:47:29
# Episode 175 - tiger - Step 362340 - Epsilon 0.9133966815283172 - Mean Reward 42.75 - Mean Length 2059.7 - Mean Loss 0.015 - Mean Q Value 0.861 - Time Delta 24.148 - Time 2023-04-29T17:47:53
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_18.chkpt at step 900000
# Episode 176 - deer - Step 917350 - Epsilon 0.795060132598757 - Mean Reward -9.692 - Mean Length 5041.76 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 259.17 - Time 2023-04-29T17:48:51
# Episode 177 - tiger - Step 364779 - Epsilon 0.9128399075957863 - Mean Reward 42.75 - Mean Length 2056.83 - Mean Loss 0.015 - Mean Q Value 0.863 - Time Delta 83.987 - Time 2023-04-29T17:49:17
# Episode 178 - tiger - Step 367352 - Epsilon 0.912252912064446 - Mean Reward 42.64 - Mean Length 2050.59 - Mean Loss 0.015 - Mean Q Value 0.864 - Time Delta 24.558 - Time 2023-04-29T17:49:41
# Episode 179 - tiger - Step 369746 - Epsilon 0.9117070919812262 - Mean Reward 42.69 - Mean Length 2046.86 - Mean Loss 0.015 - Mean Q Value 0.866 - Time Delta 25.097 - Time 2023-04-29T17:50:07
# Episode 180 - tiger - Step 372327 - Epsilon 0.9111190026592558 - Mean Reward 42.66 - Mean Length 2043.76 - Mean Loss 0.015 - Mean Q Value 0.867 - Time Delta 26.539 - Time 2023-04-29T17:50:33
# Episode 181 - deer - Step 943242 - Epsilon 0.7899303282417413 - Mean Reward -10.043 - Mean Length 5300.68 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 160.627 - Time 2023-04-29T17:51:32
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_19.chkpt at step 950000
# Episode 182 - deer - Step 968998 - Epsilon 0.7848603066753753 - Mean Reward -9.843 - Mean Length 5271.16 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 58.745 - Time 2023-04-29T17:52:31
# Episode 183 - tiger - Step 374606 - Epsilon 0.9106000403959611 - Mean Reward 42.23 - Mean Length 2018.93 - Mean Loss 0.015 - Mean Q Value 0.858 - Time Delta 143.478 - Time 2023-04-29T17:52:57
# Episode 184 - tiger - Step 377330 - Epsilon 0.9099801327933736 - Mean Reward 42.43 - Mean Length 2020.91 - Mean Loss 0.015 - Mean Q Value 0.859 - Time Delta 26.58 - Time 2023-04-29T17:53:23
# Episode 185 - tiger - Step 380132 - Epsilon 0.9093429148422572 - Mean Reward 42.59 - Mean Length 2023.07 - Mean Loss 0.015 - Mean Q Value 0.861 - Time Delta 24.59 - Time 2023-04-29T17:53:48
# Episode 186 - tiger - Step 382577 - Epsilon 0.9087872487587718 - Mean Reward 42.56 - Mean Length 2021.23 - Mean Loss 0.015 - Mean Q Value 0.862 - Time Delta 24.368 - Time 2023-04-29T17:54:12
# Episode 187 - tiger - Step 385648 - Epsilon 0.908089795030567 - Mean Reward 43.25 - Mean Length 2051.94 - Mean Loss 0.015 - Mean Q Value 0.872 - Time Delta 25.644 - Time 2023-04-29T17:54:38
# Episode 188 - tiger - Step 388056 - Epsilon 0.9075432894202643 - Mean Reward 43.36 - Mean Length 2053.49 - Mean Loss 0.015 - Mean Q Value 0.873 - Time Delta 25.969 - Time 2023-04-29T17:55:04
# Episode 189 - tiger - Step 390485 - Epsilon 0.9069923509844332 - Mean Reward 43.53 - Mean Length 2054.81 - Mean Loss 0.015 - Mean Q Value 0.874 - Time Delta 24.282 - Time 2023-04-29T17:55:28
# Episode 190 - deer - Step 996535 - Epsilon 0.7794756872345523 - Mean Reward -9.682 - Mean Length 5279.01 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 238.072 - Time 2023-04-29T17:56:29
# Episode 191 - tiger - Step 393188 - Epsilon 0.9063796578635863 - Mean Reward 42.97 - Mean Length 2025.82 - Mean Loss 0.014 - Mean Q Value 0.864 - Time Delta 86.459 - Time 2023-04-29T17:56:54
# Episode 192 - tiger - Step 395851 - Epsilon 0.9057764363505173 - Mean Reward 42.99 - Mean Length 2023.47 - Mean Loss 0.014 - Mean Q Value 0.865 - Time Delta 24.115 - Time 2023-04-29T17:57:19
# Episode 193 - tiger - Step 397844 - Epsilon 0.9053252455968731 - Mean Reward 43.38 - Mean Length 2043.4 - Mean Loss 0.015 - Mean Q Value 0.875 - Time Delta 26.095 - Time 2023-04-29T17:57:45
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_8.chkpt at step 400000
# Episode 194 - tiger - Step 400370 - Epsilon 0.9047537131131335 - Mean Reward 43.41 - Mean Length 2044.44 - Mean Loss 0.015 - Mean Q Value 0.876 - Time Delta 27.744 - Time 2023-04-29T17:58:12
# Episode 195 - tiger - Step 403132 - Epsilon 0.9041291962353437 - Mean Reward 43.61 - Mean Length 2049.36 - Mean Loss 0.015 - Mean Q Value 0.876 - Time Delta 26.661 - Time 2023-04-29T17:58:39
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_20.chkpt at step 1000000
# Episode 196 - deer - Step 1019262 - Epsilon 0.775059458530164 - Mean Reward -9.459 - Mean Length 5242.03 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 181.687 - Time 2023-04-29T17:59:31
# Episode 197 - deer - Step 1047313 - Epsilon 0.7696431733586041 - Mean Reward -9.881 - Mean Length 5522.54 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 62.506 - Time 2023-04-29T18:00:33
# Episode 198 - tiger - Step 405464 - Epsilon 0.9036022424699439 - Mean Reward 42.56 - Mean Length 1992.8 - Mean Loss 0.014 - Mean Q Value 0.856 - Time Delta 140.278 - Time 2023-04-29T18:00:59
# Episode 199 - tiger - Step 408215 - Epsilon 0.9029810036029461 - Mean Reward 43.16 - Mean Length 2020.31 - Mean Loss 0.014 - Mean Q Value 0.867 - Time Delta 26.211 - Time 2023-04-29T18:01:26
# Episode 200 - tiger - Step 410813 - Epsilon 0.9023947077879145 - Mean Reward 43.82 - Mean Length 2046.29 - Mean Loss 0.015 - Mean Q Value 0.877 - Time Delta 24.898 - Time 2023-04-29T18:01:50
# Episode 201 - tiger - Step 413047 - Epsilon 0.9018908609928793 - Mean Reward 43.87 - Mean Length 2044.85 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 26.019 - Time 2023-04-29T18:02:16
# Episode 202 - tiger - Step 415751 - Epsilon 0.9012813887194177 - Mean Reward 44.04 - Mean Length 2046.34 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 24.83 - Time 2023-04-29T18:02:41
# Episode 203 - tiger - Step 418827 - Epsilon 0.9005885696678609 - Mean Reward 44.27 - Mean Length 2052.69 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 25.974 - Time 2023-04-29T18:03:07
# Episode 204 - tiger - Step 421086 - Epsilon 0.9000801058005099 - Mean Reward 44.21 - Mean Length 2047.48 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 25.943 - Time 2023-04-29T18:03:33
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_21.chkpt at step 1050000
# Episode 205 - deer - Step 1074272 - Epsilon 0.7644734111557767 - Mean Reward -8.904 - Mean Length 5237.13 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 241.496 - Time 2023-04-29T18:04:35
# Episode 206 - tiger - Step 423416 - Epsilon 0.8995559617450676 - Mean Reward 43.94 - Mean Length 2025.7 - Mean Loss 0.015 - Mean Q Value 0.868 - Time Delta 87.832 - Time 2023-04-29T18:05:01
# Episode 207 - tiger - Step 425920 - Epsilon 0.8989930158630136 - Mean Reward 43.97 - Mean Length 2023.41 - Mean Loss 0.015 - Mean Q Value 0.868 - Time Delta 25.223 - Time 2023-04-29T18:05:26
# Episode 208 - tiger - Step 428571 - Epsilon 0.8983974055593842 - Mean Reward 44.51 - Mean Length 2049.92 - Mean Loss 0.015 - Mean Q Value 0.879 - Time Delta 26.118 - Time 2023-04-29T18:05:52
# Episode 209 - tiger - Step 431076 - Epsilon 0.8978349602478406 - Mean Reward 44.48 - Mean Length 2046.46 - Mean Loss 0.015 - Mean Q Value 0.879 - Time Delta 26.735 - Time 2023-04-29T18:06:19
# Episode 210 - tiger - Step 433685 - Epsilon 0.8972495382632584 - Mean Reward 44.63 - Mean Length 2050.53 - Mean Loss 0.015 - Mean Q Value 0.879 - Time Delta 25.382 - Time 2023-04-29T18:06:45
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_22.chkpt at step 1100000
# Episode 211 - deer - Step 1102018 - Epsilon 0.759188989561521 - Mean Reward -8.61 - Mean Length 5221.9 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 192.897 - Time 2023-04-29T18:07:47
# Episode 212 - tiger - Step 436042 - Epsilon 0.8967209896456263 - Mean Reward 44.13 - Mean Length 2025.89 - Mean Loss 0.015 - Mean Q Value 0.868 - Time Delta 89.577 - Time 2023-04-29T18:08:14
# Episode 213 - tiger - Step 438105 - Epsilon 0.8962586249798941 - Mean Reward 43.9 - Mean Length 2023.17 - Mean Loss 0.015 - Mean Q Value 0.868 - Time Delta 29.05 - Time 2023-04-29T18:08:43
# Episode 214 - tiger - Step 440822 - Epsilon 0.8956500479440926 - Mean Reward 44.51 - Mean Length 2050.34 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 26.547 - Time 2023-04-29T18:09:10
# Episode 215 - tiger - Step 443685 - Epsilon 0.895009215707276 - Mean Reward 44.52 - Mean Length 2054.39 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 28.693 - Time 2023-04-29T18:09:38
# Episode 216 - tiger - Step 446221 - Epsilon 0.8944419596327073 - Mean Reward 44.72 - Mean Length 2054.29 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 25.477 - Time 2023-04-29T18:10:04
# Episode 217 - deer - Step 1127399 - Epsilon 0.7543869960607783 - Mean Reward -8.356 - Mean Length 5191.17 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 194.582 - Time 2023-04-29T18:11:02
# Episode 218 - tiger - Step 449368 - Epsilon 0.8937385340792506 - Mean Reward 44.47 - Mean Length 2034.54 - Mean Loss 0.015 - Mean Q Value 0.867 - Time Delta 81.722 - Time 2023-04-29T18:11:26
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_9.chkpt at step 450000
# Episode 219 - tiger - Step 451567 - Epsilon 0.8932473362890324 - Mean Reward 44.31 - Mean Length 2031.73 - Mean Loss 0.015 - Mean Q Value 0.867 - Time Delta 28.797 - Time 2023-04-29T18:11:54
# Episode 220 - tiger - Step 454080 - Epsilon 0.8926863298244117 - Mean Reward 44.86 - Mean Length 2056.86 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 26.394 - Time 2023-04-29T18:12:21
# Episode 221 - tiger - Step 456990 - Epsilon 0.8920371366108899 - Mean Reward 45.0 - Mean Length 2060.11 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 24.453 - Time 2023-04-29T18:12:45
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_23.chkpt at step 1150000
# Episode 222 - deer - Step 1154708 - Epsilon 0.7492541483542419 - Mean Reward -7.998 - Mean Length 5195.5 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 164.079 - Time 2023-04-29T18:13:46
# Episode 223 - deer - Step 1180416 - Epsilon 0.7444541327149261 - Mean Reward -8.29 - Mean Length 5452.58 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 58.809 - Time 2023-04-29T18:14:45
# Episode 224 - tiger - Step 459845 - Epsilon 0.8914006721902475 - Mean Reward 44.11 - Mean Length 2013.93 - Mean Loss 0.015 - Mean Q Value 0.857 - Time Delta 143.055 - Time 2023-04-29T18:15:08
# Episode 225 - tiger - Step 462302 - Epsilon 0.8908532973885533 - Mean Reward 44.58 - Mean Length 2038.5 - Mean Loss 0.015 - Mean Q Value 0.867 - Time Delta 27.536 - Time 2023-04-29T18:15:36
# Episode 226 - tiger - Step 464607 - Epsilon 0.8903400909935056 - Mean Reward 45.17 - Mean Length 2061.55 - Mean Loss 0.015 - Mean Q Value 0.878 - Time Delta 24.625 - Time 2023-04-29T18:16:00
# Episode 227 - tiger - Step 467321 - Epsilon 0.8897362000593627 - Mean Reward 45.35 - Mean Length 2063.83 - Mean Loss 0.015 - Mean Q Value 0.877 - Time Delta 22.955 - Time 2023-04-29T18:16:23
# Episode 228 - tiger - Step 470385 - Epsilon 0.8890549230072838 - Mean Reward 45.6 - Mean Length 2070.38 - Mean Loss 0.015 - Mean Q Value 0.877 - Time Delta 25.272 - Time 2023-04-29T18:16:49
# Episode 229 - tiger - Step 473046 - Epsilon 0.888463675831162 - Mean Reward 45.69 - Mean Length 2072.43 - Mean Loss 0.015 - Mean Q Value 0.877 - Time Delta 25.629 - Time 2023-04-29T18:17:14
# Episode 230 - tiger - Step 475510 - Epsilon 0.8879165506702321 - Mean Reward 45.87 - Mean Length 2073.03 - Mean Loss 0.015 - Mean Q Value 0.877 - Time Delta 21.641 - Time 2023-04-29T18:17:36
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_24.chkpt at step 1200000
# Episode 231 - deer - Step 1204492 - Epsilon 0.7399867208941745 - Mean Reward -7.705 - Mean Length 5175.65 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 225.535 - Time 2023-04-29T18:18:30
# Episode 232 - tiger - Step 477548 - Epsilon 0.8874642723587508 - Mean Reward 45.07 - Mean Length 2041.91 - Mean Loss 0.015 - Mean Q Value 0.866 - Time Delta 82.413 - Time 2023-04-29T18:18:58
# Episode 233 - tiger - Step 480217 - Epsilon 0.8868723092645922 - Mean Reward 45.27 - Mean Length 2043.04 - Mean Loss 0.015 - Mean Q Value 0.866 - Time Delta 25.106 - Time 2023-04-29T18:19:23
# Episode 234 - tiger - Step 483216 - Epsilon 0.886207625871869 - Mean Reward 45.57 - Mean Length 2046.39 - Mean Loss 0.015 - Mean Q Value 0.865 - Time Delta 24.286 - Time 2023-04-29T18:19:48
# Episode 235 - tiger - Step 485624 - Epsilon 0.8856742893647488 - Mean Reward 46.1 - Mean Length 2070.47 - Mean Loss 0.015 - Mean Q Value 0.876 - Time Delta 27.629 - Time 2023-04-29T18:20:15
# ...
# Episode 2164 - deer - Step 10029198 - Epsilon 0.1 - Mean Reward 20.238 - Mean Length 4466.42 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 43.293 - Time 2023-04-30T14:41:08
# Episode 2165 - tiger - Step 4005203 - Epsilon 0.3674011870340177 - Mean Reward 68.7 - Mean Length 1797.51 - Mean Loss 0.025 - Mean Q Value 0.567 - Time Delta 129.455 - Time 2023-04-30T14:41:44
# Episode 2166 - tiger - Step 4007602 - Epsilon 0.36718090420844257 - Mean Reward 68.97 - Mean Length 1801.63 - Mean Loss 0.025 - Mean Q Value 0.567 - Time Delta 28.582 - Time 2023-04-30T14:42:12
# Episode 2167 - tiger - Step 4010318 - Epsilon 0.3669316729668783 - Mean Reward 68.94 - Mean Length 1802.02 - Mean Loss 0.025 - Mean Q Value 0.567 - Time Delta 28.394 - Time 2023-04-30T14:42:41
# Episode 2168 - tiger - Step 4012849 - Epsilon 0.3666995703609707 - Mean Reward 69.05 - Mean Length 1804.57 - Mean Loss 0.025 - Mean Q Value 0.568 - Time Delta 29.703 - Time 2023-04-30T14:43:10
# Episode 2169 - tiger - Step 4015450 - Epsilon 0.36646120144360755 - Mean Reward 69.39 - Mean Length 1812.21 - Mean Loss 0.025 - Mean Q Value 0.568 - Time Delta 34.246 - Time 2023-04-30T14:43:44
# Episode 2170 - deer - Step 10046811 - Epsilon 0.1 - Mean Reward 20.029 - Mean Length 4409.88 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 209.227 - Time 2023-04-30T14:44:38
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_201.chkpt at step 10050000
# Episode 2171 - deer - Step 10070068 - Epsilon 0.1 - Mean Reward 21.439 - Mean Length 4642.45 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 68.503 - Time 2023-04-30T14:45:46
# Episode 2172 - tiger - Step 4017939 - Epsilon 0.36623324186376227 - Mean Reward 68.31 - Mean Length 1787.27 - Mean Loss 0.025 - Mean Q Value 0.56 - Time Delta 149.971 - Time 2023-04-30T14:46:14
# Episode 2173 - tiger - Step 4020335 - Epsilon 0.3660139338137603 - Mean Reward 68.46 - Mean Length 1790.29 - Mean Loss 0.025 - Mean Q Value 0.56 - Time Delta 26.991 - Time 2023-04-30T14:46:41
# Episode 2174 - tiger - Step 4022787 - Epsilon 0.36578963599856934 - Mean Reward 68.38 - Mean Length 1790.05 - Mean Loss 0.025 - Mean Q Value 0.561 - Time Delta 30.199 - Time 2023-04-30T14:47:12
# Episode 2175 - tiger - Step 4025072 - Epsilon 0.3655807383149456 - Mean Reward 68.43 - Mean Length 1787.06 - Mean Loss 0.024 - Mean Q Value 0.561 - Time Delta 28.871 - Time 2023-04-30T14:47:41
# Episode 2176 - tiger - Step 4027472 - Epsilon 0.3653614556358973 - Mean Reward 69.47 - Mean Length 1811.06 - Mean Loss 0.025 - Mean Q Value 0.568 - Time Delta 29.043 - Time 2023-04-30T14:48:10
# Episode 2177 - tiger - Step 4030043 - Epsilon 0.3651266949851956 - Mean Reward 70.59 - Mean Length 1836.77 - Mean Loss 0.025 - Mean Q Value 0.576 - Time Delta 29.339 - Time 2023-04-30T14:48:39
# Episode 2178 - tiger - Step 4032496 - Epsilon 0.36490284965507286 - Mean Reward 70.82 - Mean Length 1840.33 - Mean Loss 0.025 - Mean Q Value 0.576 - Time Delta 32.899 - Time 2023-04-30T14:49:12
# Episode 2179 - deer - Step 10086281 - Epsilon 0.1 - Mean Reward 19.985 - Mean Length 4437.11 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 255.627 - Time 2023-04-30T14:50:02
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_202.chkpt at step 10100000
# Episode 2180 - deer - Step 10105743 - Epsilon 0.1 - Mean Reward 20.987 - Mean Length 4631.73 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 58.244 - Time 2023-04-30T14:51:00
# Episode 2181 - tiger - Step 4034489 - Epsilon 0.3647210820740948 - Mean Reward 68.41 - Mean Length 1782.51 - Mean Loss 0.024 - Mean Q Value 0.562 - Time Delta 142.19 - Time 2023-04-30T14:51:34
# Episode 2182 - tiger - Step 4036896 - Epsilon 0.36450167715557635 - Mean Reward 68.59 - Mean Length 1785.12 - Mean Loss 0.024 - Mean Q Value 0.562 - Time Delta 29.723 - Time 2023-04-30T14:52:04
# Episode 2183 - tiger - Step 4039889 - Epsilon 0.3642290407543405 - Mean Reward 69.71 - Mean Length 1815.05 - Mean Loss 0.025 - Mean Q Value 0.57 - Time Delta 27.998 - Time 2023-04-30T14:52:32
# Episode 2184 - tiger - Step 4042321 - Epsilon 0.36400765677740643 - Mean Reward 70.8 - Mean Length 1839.37 - Mean Loss 0.025 - Mean Q Value 0.577 - Time Delta 22.748 - Time 2023-04-30T14:52:54
# Episode 2185 - tiger - Step 4044412 - Epsilon 0.3638174214781038 - Mean Reward 70.54 - Mean Length 1835.1 - Mean Loss 0.025 - Mean Q Value 0.578 - Time Delta 39.094 - Time 2023-04-30T14:53:34
# Episode 2186 - deer - Step 10127886 - Epsilon 0.1 - Mean Reward 20.493 - Mean Length 4471.11 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 219.174 - Time 2023-04-30T14:54:39
# Episode 2187 - tiger - Step 4046947 - Epsilon 0.36358692520461977 - Mean Reward 69.49 - Mean Length 1813.79 - Mean Loss 0.025 - Mean Q Value 0.57 - Time Delta 95.237 - Time 2023-04-30T14:55:09
# Episode 2188 - tiger - Step 4049513 - Epsilon 0.3633537589589922 - Mean Reward 69.48 - Mean Length 1813.59 - Mean Loss 0.025 - Mean Q Value 0.57 - Time Delta 25.988 - Time 2023-04-30T14:55:35
# Animal saved to tiger_checkpoints\2023-04-29T16-21-03\animal_net_81.chkpt at step 4050000
# Episode 2189 - tiger - Step 4052038 - Epsilon 0.3631244642487119 - Mean Reward 69.83 - Mean Length 1818.65 - Mean Loss 0.025 - Mean Q Value 0.57 - Time Delta 25.474 - Time 2023-04-30T14:56:00
# Episode 2190 - tiger - Step 4054342 - Epsilon 0.3629153647575728 - Mean Reward 69.81 - Mean Length 1814.77 - Mean Loss 0.024 - Mean Q Value 0.57 - Time Delta 31.968 - Time 2023-04-30T14:56:32
# Episode 2191 - tiger - Step 4056955 - Epsilon 0.3626783676834842 - Mean Reward 69.82 - Mean Length 1817.3 - Mean Loss 0.024 - Mean Q Value 0.57 - Time Delta 28.135 - Time 2023-04-30T14:57:00
# Episode 2192 - deer - Step 10145040 - Epsilon 0.1 - Mean Reward 20.945 - Mean Length 4642.65 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 193.469 - Time 2023-04-30T14:57:53
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_203.chkpt at step 10150000
# Episode 2193 - deer - Step 10163621 - Epsilon 0.1 - Mean Reward 20.893 - Mean Length 4637.87 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 56.663 - Time 2023-04-30T14:58:49
# Episode 2194 - tiger - Step 4059244 - Epsilon 0.3624708843334485 - Mean Reward 69.7 - Mean Length 1817.72 - Mean Loss 0.024 - Mean Q Value 0.57 - Time Delta 139.239 - Time 2023-04-30T14:59:20
# Episode 2195 - tiger - Step 4061813 - Epsilon 0.3622381621197828 - Mean Reward 69.77 - Mean Length 1816.22 - Mean Loss 0.024 - Mean Q Value 0.57 - Time Delta 24.805 - Time 2023-04-30T14:59:44
# Episode 2196 - tiger - Step 4063772 - Epsilon 0.36206079939293295 - Mean Reward 69.82 - Mean Length 1810.19 - Mean Loss 0.024 - Mean Q Value 0.57 - Time Delta 22.799 - Time 2023-04-30T15:00:07
# Episode 2197 - tiger - Step 4066024 - Epsilon 0.36185701650763874 - Mean Reward 69.69 - Mean Length 1806.49 - Mean Loss 0.024 - Mean Q Value 0.571 - Time Delta 25.512 - Time 2023-04-30T15:00:33
# Episode 2198 - tiger - Step 4068563 - Epsilon 0.3616274006197278 - Mean Reward 70.18 - Mean Length 1810.21 - Mean Loss 0.024 - Mean Q Value 0.571 - Time Delta 24.555 - Time 2023-04-30T15:00:57
# Episode 2199 - deer - Step 10182764 - Epsilon 0.1 - Mean Reward 21.209 - Mean Length 4669.27 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 187.263 - Time 2023-04-30T15:01:57
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_204.chkpt at step 10200000
# Episode 2200 - deer - Step 10203537 - Epsilon 0.1 - Mean Reward 21.662 - Mean Length 4656.33 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 62.739 - Time 2023-04-30T15:02:59
# Episode 2201 - tiger - Step 4071060 - Epsilon 0.36140172513294005 - Mean Reward 69.51 - Mean Length 1791.56 - Mean Loss 0.024 - Mean Q Value 0.564 - Time Delta 152.267 - Time 2023-04-30T15:03:30
# Episode 2202 - tiger - Step 4073602 - Epsilon 0.36117212727033426 - Mean Reward 69.36 - Mean Length 1793.63 - Mean Loss 0.024 - Mean Q Value 0.564 - Time Delta 32.992 - Time 2023-04-30T15:04:03
# Episode 2203 - tiger - Step 4076314 - Epsilon 0.3609273355311894 - Mean Reward 69.29 - Mean Length 1795.53 - Mean Loss 0.024 - Mean Q Value 0.564 - Time Delta 29.141 - Time 2023-04-30T15:04:32
# Episode 2204 - tiger - Step 4078783 - Epsilon 0.36070462184754437 - Mean Reward 69.1 - Mean Length 1792.79 - Mean Loss 0.024 - Mean Q Value 0.565 - Time Delta 31.918 - Time 2023-04-30T15:05:04
# Episode 2205 - tiger - Step 4081505 - Epsilon 0.3604592458203339 - Mean Reward 69.17 - Mean Length 1792.79 - Mean Loss 0.024 - Mean Q Value 0.565 - Time Delta 30.337 - Time 2023-04-30T15:05:34
# Episode 2206 - tiger - Step 4083621 - Epsilon 0.3602686132821911 - Mean Reward 69.84 - Mean Length 1813.95 - Mean Loss 0.024 - Mean Q Value 0.572 - Time Delta 32.303 - Time 2023-04-30T15:06:06
# Episode 2207 - tiger - Step 4085772 - Epsilon 0.36007493089218107 - Mean Reward 70.75 - Mean Length 1835.46 - Mean Loss 0.025 - Mean Q Value 0.58 - Time Delta 33.607 - Time 2023-04-30T15:06:40
# Episode 2208 - tiger - Step 4088478 - Epsilon 0.3598314225469447 - Mean Reward 71.27 - Mean Length 1840.37 - Mean Loss 0.025 - Mean Q Value 0.58 - Time Delta 25.761 - Time 2023-04-30T15:07:06
# Episode 2209 - deer - Step 10222695 - Epsilon 0.1 - Mean Reward 21.232 - Mean Length 4485.52 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 304.805 - Time 2023-04-30T15:08:04
# Episode 2210 - deer - Step 10238892 - Epsilon 0.1 - Mean Reward 21.772 - Mean Length 4647.49 - Mean Loss 0.0 - Mean Q Value 0.015 - Time Delta 52.149 - Time 2023-04-30T15:08:56
# Episode 2211 - tiger - Step 4091201 - Epsilon 0.359586550633137 - Mean Reward 69.58 - Mean Length 1795.1 - Mean Loss 0.024 - Mean Q Value 0.565 - Time Delta 136.42 - Time 2023-04-30T15:09:22
# Episode 2212 - tiger - Step 4093482 - Epsilon 0.3593815548319678 - Mean Reward 69.52 - Mean Length 1791.96 - Mean Loss 0.024 - Mean Q Value 0.564 - Time Delta 33.842 - Time 2023-04-30T15:09:56
# Episode 2213 - tiger - Step 4095936 - Epsilon 0.3591611418390937 - Mean Reward 70.39 - Mean Length 1816.5 - Mean Loss 0.024 - Mean Q Value 0.572 - Time Delta 33.455 - Time 2023-04-30T15:10:29
# Episode 2214 - tiger - Step 4098510 - Epsilon 0.3589300959623899 - Mean Reward 71.42 - Mean Length 1842.24 - Mean Loss 0.025 - Mean Q Value 0.579 - Time Delta 26.888 - Time 2023-04-30T15:10:56
# Animal saved to deer_checkpoints\2023-04-29T16-21-03\animal_net_205.chkpt at step 10250000
# Episode 2215 - deer - Step 10257122 - Epsilon 0.1 - Mean Reward 20.944 - Mean Length 4500.8 - Mean Loss 0.0 - Mean Q Value 0.014 - Time Delta 177.295 - Time 2023-04-30T15:11:54
# Episode 2216 - deer - Step 10279017 - Epsilon 0.1 - Mean Reward 22.168 - Mean Length 4719.75 - Mean Loss 0.0 - Mean Q Value 0.015 - Time Delta 70.116 - Time 2023-04-30T15:13:04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm.ipynb Cell 20 in <cell line: 11>()
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X25sZmlsZQ%3D%3D?line=112'>113</a>         animal_logger.log_step(reward, loss, q)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X25sZmlsZQ%3D%3D?line=113'>114</a>     # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
# --> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X25sZmlsZQ%3D%3D?line=114'>115</a>     action = animal.act(observation, activeAnimal)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X25sZmlsZQ%3D%3D?line=115'>116</a>     actual_action = action_mapper(action, prev_actual_action)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X25sZmlsZQ%3D%3D?line=117'>118</a> # update previous agent
#
# File d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\Animal.py:59, in Animal.act(self, state, active)
#      55 # EXPLOIT
#      56 else:
#      57     # state = state[0].__array__() if isinstance(state, tuple) else state.__array__()
#      58     state = torch.tensor(state, device=self.device).unsqueeze(0)
# ---> 59     action_values = self.net(state, model="online")
#      60     action_idx = torch.argmax(action_values, axis=1).item()
#      62 if active:
#      63     # decrease exploration_rate
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\dqn_net.py:42, in DQN_NET.forward(self, input, model)
#      40 def forward(self, input, model):
#      41     if model == "online":
# ---> 42         return self.online(input)
#      43     elif model == "target":
#      44         return self.target(input)
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
tiger.save_dir=Path("tiger_checkpoints") / "Basic_With_AdvReward2"
tiger.save()
deer.save_dir=Path("deer_checkpoints") / "Basic_With_AdvReward2"
deer.save()
# Out:
# Animal saved to tiger_checkpoints\Basic_With_AdvReward2\animal_net_64.chkpt at step 3219036
# Animal saved to deer_checkpoints\Basic_With_AdvReward2\animal_net_161.chkpt at step 8056211

# %% [markdown]
# ### Train LSTM Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)

# %% [markdown]
# ### Visualize Trained Model

# %%
map_size=50
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 20
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# Episode:  1
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3406: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# deer_save_dir=
# tiger_save_dir=
deer2 = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger2 = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

deer2.load("deer_checkpoints\\Basic_With_AdvReward2\\animal_net_161.chkpt")
tiger2.load("tiger_checkpoints\\Basic_With_AdvReward2\\animal_net_64.chkpt")
# tiger2.net.eval()
# deer2.net.eval()
# Out:
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
map_size=50
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 3
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger2
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer2
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
