# %%
from magent2.environments import battle_v4, adversarial_pursuit_v4, tiger_deer_v4
from pettingzoo.utils import random_demo
import torch
import time
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from dqn_basic import DQN_Basic
from collections import namedtuple, deque
import numpy as np
# import matplotlib.pyplot as plt
# from AnimalLSTM import Animal
from Animal import Animal
from pathlib import Path
from collections import deque
import datetime, os
from metric_logger import MetricLogger
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
def convert_numpy_binary_to_integer(arr):
    assert len(arr.shape) == 3
    assert arr.shape[0] <= 8
    arr = arr.astype(np.int32)
    input_array_transposed = np.transpose(arr, (1, 2, 0))
    packed_array = np.packbits(input_array_transposed, axis=-1, bitorder='little').squeeze(-1)
    return packed_array

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# frame_size = (128, 128)
max_cycles = 300
# total_episodes = 50
# map_size = 30
map_size = 50

# env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', tiger_step_recover=-0.1, deer_attacked=-0.1, max_cycles=max_cycles, extra_features=False)
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='rgb_array', max_cycles=max_cycles, extra_features=True)
env.reset(seed=None)
obs_indices_to_keep = [0,1,3]

# get number of deer and tigers
number_of_deer = len([x for x in env.agents if 'deer' in x])
number_of_tigers = len([x for x in env.agents if 'tiger' in x])


# set deer data
deer_observation_shape = env.observation_spaces['deer_0'].shape
deer_observation_shape = tuple(np.roll(deer_observation_shape,1))
# deer_action_space = env.action_spaces['deer_0'].n
deer_action_space = 3
deer_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['deer_0'].n, deer_observation_shape[1], deer_observation_shape[2])


# set tiger data
tiger_observation_shape = env.observation_spaces['tiger_0'].shape
tiger_observation_shape = tuple(np.roll(tiger_observation_shape,1))
# tiger_action_space = env.action_spaces['tiger_0'].n
tiger_action_space = 6
tiger_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['tiger_0'].n, tiger_observation_shape[1], tiger_observation_shape[2])

# print outputs
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)
print("Deer Observations:", deer_observation_shape, "Tiger Observations:",tiger_observation_shape)
assert deer_observation_shape != None
assert tiger_observation_shape != None
# 'rgb_array' or 'human'
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Deer Observations: (8, 7, 7) Tiger Observations: (16, 10, 10)

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# ### Action Mapping
# Takes the limited actions (forward, left, right) and maps to the true actions (up, left, down, right,...)

# %%
deer_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
}
def deer_action_mapper(new_unmapped_action, prev_actual_action, size_of_actions=5):
    global deer_action_mapping
    return deer_action_mapping.get(new_unmapped_action, {}).get(prev_actual_action, np.random.choice(np.delete(np.arange(0, size_of_actions), 2)))

tiger_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
    3: {0: 5, 1: 6, 3: 7, 4: 8},
    4: {0: 6, 1: 8, 3: 5, 4: 7},
    5: {0: 7, 1: 5, 3: 8, 4: 6},
}

tiger_direction_mapping = {
    0: 0,
    1: 1,
    3: 3,
    4: 4,
    5: 0,
    6: 1,
    7: 3,
    8: 4,
}

def tiger_action_mapper(new_action, prev_action, size_of_actions=5): # slower
    global tiger_action_mapping, tiger_direction_mapping
    direction = tiger_direction_mapping.get(prev_action, 0)
    return tiger_action_mapping.get(new_action, {}).get(direction, 0)

def mask_observations(observations, prev_actual_action):
    current_position = (observations.shape[1] // 2, observations.shape[2] // 2)
    direction = tiger_direction_mapping.get(prev_actual_action, 0)
    # print(observations)
    if direction == 1:  # Up
        observations[:, current_position[0]:, :] = 0 # actually_left
    elif direction == 0:  # Left
        observations[:, :, current_position[1]:] = 0
    elif direction == 4:  # Right
        observations[:, :, :current_position[1]] = 0
    elif direction == 3:  # Down
        observations[:, :current_position[0]+1, :] = 0 # actually right
    else:
        raise ValueError("Direction mapping issue for mask observations")
    # print("direction: ", direction, " observations: ", observations)

# %%
def get_agent_type_from_agent_name(agent):
    if 'tiger' in agent:
        return 'tiger'
    return 'deer'

# %%
def generate_first_action(agentType):
    if 'tiger' in agentType:
        # action = np.random.randint(0,tiger_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 6))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 9), 2))
        actual_action = tiger_action_mapper(action, previous_actual_action)
    else:
        # action = np.random.randint(0,deer_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 3))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 5), 2))
        actual_action = deer_action_mapper(action, previous_actual_action)
    
    return action, actual_action, previous_actual_action

# %%
def change_active_model(activeDeer, activeTiger, deerCurrentSteps, tigerCurrentSteps, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger):
    if deerCurrentSteps >= total_steps_deer:
        return False, True
    if tigerCurrentSteps >= total_steps_tiger:
        return True, False
    if deerCurrentSteps//steps_to_switch_at_deer < tigerCurrentSteps//steps_to_switch_at_tiger:
        # if not activeDeer:
        #     print("Switching to Deer")
        return True, False
    if tigerCurrentSteps//steps_to_switch_at_tiger < deerCurrentSteps//steps_to_switch_at_deer:
        # if not activeTiger:
        #     print("Switching to Tiger")
        return False, True
    return activeDeer, activeTiger

# %%
def custom_reward_modifier(agentType, observation, prev_actual_action, reward, start_index_one_hot=3):
    return reward
    if 'deer' not in agentType:
        return reward
    
    #############################################################
    # alignment reward
    alignment_reward = 0.005
    action_array = observation[prev_actual_action+start_index_one_hot]
    _, K, _ = observation.shape
    center = K//2
    # Assuming 'center' is the index of the center of the (K,K) section
    center_coords = np.array([center // K, center % K])
    coords = np.indices((K,K)).reshape(2,-1).T
    distances = np.linalg.norm(coords - center_coords, axis=1)
    # distances = distances
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    # Sum the values and print the result
    alignement_result = np.sum(values[np.isfinite(values)])
    alignement_result *= alignment_reward
    #############################################################
    # wall_penalty
    wall_penalty = -0.01
    action_array = observation[0]
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    wall_result = np.sum(values[np.isfinite(values)])
    wall_result *= wall_penalty

    return reward + alignement_result + wall_result

# %%
agent_name_to_id_dict = {str(name): index for index,name in enumerate(env.agents)}
agent_id_to_name_list = [x for x in env.agents]
def agent_name_to_id(agent_name):
    global agent_name_to_id_dict
    return agent_name_to_id_dict[agent_name]

def agent_id_to_name(id):
    global agent_id_to_name_list
    return agent_id_to_name_list[id]

# %% [markdown]
# One hot actions takes the observed actions of nearby agents and converts them to one hot actions in the observed numpy array

# %%
import numpy as np

def one_hot_actions(array, num_actions):
    # Get the shape of the input array
    K, K = array.shape

    # Create an empty output array filled with zeros
    output = np.zeros((num_actions, K, K))

    # Iterate over the range of num_actions
    for action in range(num_actions):
        # Set the corresponding elements to 1 based on the original array
        output[action, :, :] = (array == action)

    return output

# %%
import numpy as np

def get_subsection_of_env_map(array, position, size=(13, 13)):
    # Get the shape of the input array
    array_shape = array.shape

    # Create an empty output array filled with -1
    output_size = [array.shape[0]]
    output_size.extend(list(size))
    output = np.full(tuple(output_size), -1)

    # Calculate the start and end indices for the subsection
    start_row = int(position[0] - size[0] // 2)
    end_row = int(start_row + size[0])
    start_col = int(position[1] - size[1] // 2)
    end_col = int(start_col + size[1])

    # Calculate the slices for the input array and output array
    slice_row_in = slice(max(start_row, 0), min(end_row, array_shape[1]))
    slice_col_in = slice(max(start_col, 0), min(end_col, array_shape[2]))

    slice_row_out = slice(max(-start_row, 0), min(array_shape[1] - start_row, size[0]))
    slice_col_out = slice(max(-start_col, 0), min(array_shape[2] - start_col, size[1]))

    # Copy the subsection from the input array to the output array
    output[:,slice_row_out, slice_col_out] = array[:,slice_row_in, slice_col_in]

    return output

# # Example usage
# array = np.random.randint(0, 100, (2, 20, 20))
# position = (19, 0)
# sub_array = get_subsection_of_env_map(array, position, size=(11, 11))

# print(sub_array)

# %% [markdown]
# Cleans up observations by removing unncessary layers, and one hot actions.

# %%
def handle_observations(observation, obs_indices_to_keep, agent_id, env_map, num_actions):
    observation = np.transpose(observation, (2,0,1))
    observation_size = observation.shape[1]
    observation = observation[obs_indices_to_keep,:,:]
    # print(observation.shape)
    position = np.where(env_map[0,:,:] == agent_id)
    # print("Position", position)

    sub_env_map = get_subsection_of_env_map(env_map, position, size=(observation_size, observation_size))
    one_hot_actions_arr = one_hot_actions(sub_env_map[1,:,:], num_actions)
    observation = np.concatenate((observation, one_hot_actions_arr), axis=0, dtype=np.float32)
    return observation

# %% [markdown]
# ## Train Model
# ### Make Models and Loggers

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

deer_save_dir = Path("deer_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
deer_save_dir.mkdir(parents=True)

tiger_save_dir = Path("tiger_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
tiger_save_dir.mkdir(parents=True)



deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

# deer.load("deer_checkpoints\\2023-04-26T22-43-08\\animal_net_8.chkpt")
# tiger.load("tiger_checkpoints\\2023-04-26T22-43-08\\animal_net_2.chkpt")

deer_logger = MetricLogger(deer_save_dir, animal='deer')
tiger_logger = MetricLogger(tiger_save_dir, animal='tiger')


# active training flags
activeDeer = True
activeTiger = False


# Switch the training set
switching = True
steps_to_switch_at_deer = 15000
steps_to_switch_at_tiger = int((steps_to_switch_at_deer*2)//5)
total_steps_deer = 800000000
total_steps_tiger = int((total_steps_deer//3))

# divide steps to switch at to actually switch at the proper requested switching steps
# steps_to_switch_at = steps_to_switch_at//2
# if switching enabled, make sure no equivalence between active variables
if switching:
    if activeDeer == activeTiger:
        activeTiger = not activeTiger
# Out:
# Using CUDA: True

# %% [markdown]
# ### Train Basic Model Basic With no ADV reward 3643

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            # prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            prev_observation, prev_action, prev_done, prev_actual_action = agents_prev_data[agent][0:4]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                # animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                animal.cache(prev_observation, observation, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward, info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)

#4604 basic with adv reward
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_0.chkpt at step 0
# Episode 0 - deer - Step 27733 - Epsilon 0.993090728665457 - Mean Reward 0.0 - Mean Length 27733.0 - Mean Loss 0.0 - Mean Q Value 0.023 - Time Delta 45.332 - Time 2023-04-28T12:37:28
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_0.chkpt at step 0
# Episode 1 - tiger - Step 2828 - Epsilon 0.9992932497771998 - Mean Reward 29.0 - Mean Length 1414.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 58.83 - Time 2023-04-28T12:37:42
# Episode 2 - tiger - Step 5362 - Epsilon 0.9986603979012686 - Mean Reward 35.0 - Mean Length 1787.333 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.167 - Time 2023-04-28T12:37:56
# Episode 3 - tiger - Step 7938 - Epsilon 0.9980174675703487 - Mean Reward 39.5 - Mean Length 1984.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.087 - Time 2023-04-28T12:38:10
# Episode 4 - tiger - Step 10755 - Epsilon 0.9973148611152246 - Mean Reward 43.0 - Mean Length 2151.0 - Mean Loss 0.003 - Mean Q Value 0.003 - Time Delta 15.453 - Time 2023-04-28T12:38:26
# Episode 5 - tiger - Step 13424 - Epsilon 0.9966496246550932 - Mean Reward 44.0 - Mean Length 2237.333 - Mean Loss 0.005 - Mean Q Value 0.009 - Time Delta 19.385 - Time 2023-04-28T12:38:45
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_1.chkpt at step 50000
# Episode 6 - deer - Step 57309 - Epsilon 0.985774894870183 - Mean Reward 0.0 - Mean Length 8187.0 - Mean Loss 0.0 - Mean Q Value 0.005 - Time Delta 139.2 - Time 2023-04-28T12:39:48
# Episode 7 - tiger - Step 16301 - Epsilon 0.995933042054797 - Mean Reward 40.625 - Mean Length 2037.625 - Mean Loss 0.005 - Mean Q Value 0.008 - Time Delta 80.6 - Time 2023-04-28T12:40:06
# Episode 8 - tiger - Step 19081 - Epsilon 0.9952411089785763 - Mean Reward 42.444 - Mean Length 2120.111 - Mean Loss 0.006 - Mean Q Value 0.008 - Time Delta 19.706 - Time 2023-04-28T12:40:25
# Episode 9 - tiger - Step 21663 - Epsilon 0.9945988880614636 - Mean Reward 42.9 - Mean Length 2166.3 - Mean Loss 0.007 - Mean Q Value 0.014 - Time Delta 18.646 - Time 2023-04-28T12:40:44
# Episode 10 - tiger - Step 24295 - Epsilon 0.9939446571768134 - Mean Reward 43.455 - Mean Length 2208.636 - Mean Loss 0.007 - Mean Q Value 0.019 - Time Delta 20.227 - Time 2023-04-28T12:41:04
# Episode 11 - deer - Step 82390 - Epsilon 0.979613177008114 - Mean Reward 0.0 - Mean Length 6865.833 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 127.774 - Time 2023-04-28T12:41:55
# Episode 12 - tiger - Step 26469 - Epsilon 0.9934045949632554 - Mean Reward 39.538 - Mean Length 2036.077 - Mean Loss 0.006 - Mean Q Value 0.022 - Time Delta 71.16 - Time 2023-04-28T12:42:15
# Episode 13 - tiger - Step 28865 - Epsilon 0.9928097237181565 - Mean Reward 40.0 - Mean Length 2061.786 - Mean Loss 0.006 - Mean Q Value 0.026 - Time Delta 19.525 - Time 2023-04-28T12:42:35
# Episode 14 - tiger - Step 31240 - Epsilon 0.9922204178384492 - Mean Reward 39.867 - Mean Length 2082.667 - Mean Loss 0.007 - Mean Q Value 0.031 - Time Delta 19.969 - Time 2023-04-28T12:42:55
# Episode 15 - tiger - Step 34157 - Epsilon 0.9914971047783029 - Mean Reward 40.5 - Mean Length 2134.812 - Mean Loss 0.007 - Mean Q Value 0.037 - Time Delta 21.17 - Time 2023-04-28T12:43:16
# Episode 16 - tiger - Step 36384 - Epsilon 0.9909452423351155 - Mean Reward 40.529 - Mean Length 2140.235 - Mean Loss 0.008 - Mean Q Value 0.042 - Time Delta 19.509 - Time 2023-04-28T12:43:35
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_2.chkpt at step 100000
# Episode 17 - deer - Step 109444 - Epsilon 0.973009918201684 - Mean Reward 0.0 - Mean Length 6080.222 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 157.468 - Time 2023-04-28T12:44:33
# Episode 18 - tiger - Step 38957 - Epsilon 0.990308021696302 - Mean Reward 38.789 - Mean Length 2050.368 - Mean Loss 0.008 - Mean Q Value 0.045 - Time Delta 77.878 - Time 2023-04-28T12:44:53
# Episode 19 - tiger - Step 41289 - Epsilon 0.9897308403121454 - Mean Reward 38.9 - Mean Length 2064.45 - Mean Loss 0.008 - Mean Q Value 0.051 - Time Delta 21.8 - Time 2023-04-28T12:45:15
# Episode 20 - tiger - Step 43679 - Epsilon 0.989139652695963 - Mean Reward 39.238 - Mean Length 2079.952 - Mean Loss 0.009 - Mean Q Value 0.058 - Time Delta 21.797 - Time 2023-04-28T12:45:37
# Episode 21 - tiger - Step 46005 - Epsilon 0.9885646351185268 - Mean Reward 39.227 - Mean Length 2091.136 - Mean Loss 0.009 - Mean Q Value 0.065 - Time Delta 21.037 - Time 2023-04-28T12:45:58
# Episode 22 - tiger - Step 48590 - Epsilon 0.9879259815303298 - Mean Reward 39.348 - Mean Length 2112.609 - Mean Loss 0.009 - Mean Q Value 0.071 - Time Delta 21.846 - Time 2023-04-28T12:46:20
# Episode 23 - deer - Step 137261 - Epsilon 0.9662668368464492 - Mean Reward 0.0 - Mean Length 5719.208 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 163.989 - Time 2023-04-28T12:47:17
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_1.chkpt at step 50000
# Episode 24 - tiger - Step 51711 - Epsilon 0.9871554528284198 - Mean Reward 38.52 - Mean Length 2068.44 - Mean Loss 0.009 - Mean Q Value 0.075 - Time Delta 78.7 - Time 2023-04-28T12:47:39
# Episode 25 - tiger - Step 54260 - Epsilon 0.9865265883306396 - Mean Reward 39.038 - Mean Length 2086.923 - Mean Loss 0.009 - Mean Q Value 0.082 - Time Delta 20.811 - Time 2023-04-28T12:47:59
# Episode 26 - tiger - Step 56339 - Epsilon 0.9860139742993174 - Mean Reward 38.852 - Mean Length 2086.63 - Mean Loss 0.01 - Mean Q Value 0.089 - Time Delta 20.932 - Time 2023-04-28T12:48:20
# Episode 27 - tiger - Step 58873 - Epsilon 0.9853895321813794 - Mean Reward 39.286 - Mean Length 2102.607 - Mean Loss 0.01 - Mean Q Value 0.096 - Time Delta 20.818 - Time 2023-04-28T12:48:41
# Episode 28 - tiger - Step 61402 - Epsilon 0.9847667164800804 - Mean Reward 39.552 - Mean Length 2117.31 - Mean Loss 0.01 - Mean Q Value 0.103 - Time Delta 20.72 - Time 2023-04-28T12:49:02
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_3.chkpt at step 150000
# Episode 29 - deer - Step 164947 - Epsilon 0.9596019123467477 - Mean Reward 0.0 - Mean Length 5498.233 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 162.451 - Time 2023-04-28T12:49:59
# Episode 30 - deer - Step 194363 - Epsilon 0.9525708837827646 - Mean Reward 0.0 - Mean Length 6269.774 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 61.041 - Time 2023-04-28T12:51:00
# Episode 31 - tiger - Step 64068 - Epsilon 0.9841105880605245 - Mean Reward 37.219 - Mean Length 2002.125 - Mean Loss 0.01 - Mean Q Value 0.105 - Time Delta 140.484 - Time 2023-04-28T12:51:22
# Episode 32 - tiger - Step 66212 - Epsilon 0.9835832460596152 - Mean Reward 37.061 - Mean Length 2006.424 - Mean Loss 0.01 - Mean Q Value 0.112 - Time Delta 21.886 - Time 2023-04-28T12:51:44
# Episode 33 - tiger - Step 69071 - Epsilon 0.9828804810271233 - Mean Reward 37.824 - Mean Length 2031.5 - Mean Loss 0.01 - Mean Q Value 0.119 - Time Delta 20.169 - Time 2023-04-28T12:52:04
# Episode 34 - tiger - Step 71560 - Epsilon 0.9822690738150913 - Mean Reward 38.086 - Mean Length 2044.571 - Mean Loss 0.011 - Mean Q Value 0.127 - Time Delta 21.305 - Time 2023-04-28T12:52:26
# Episode 35 - tiger - Step 73888 - Epsilon 0.9816975594694187 - Mean Reward 37.972 - Mean Length 2052.444 - Mean Loss 0.011 - Mean Q Value 0.136 - Time Delta 22.549 - Time 2023-04-28T12:52:48
# Episode 36 - tiger - Step 76312 - Epsilon 0.9811028308949146 - Mean Reward 38.297 - Mean Length 2062.486 - Mean Loss 0.011 - Mean Q Value 0.144 - Time Delta 20.565 - Time 2023-04-28T12:53:09
# Episode 37 - tiger - Step 78780 - Epsilon 0.9804976770816726 - Mean Reward 38.474 - Mean Length 2073.158 - Mean Loss 0.011 - Mean Q Value 0.152 - Time Delta 21.264 - Time 2023-04-28T12:53:30
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_4.chkpt at step 200000
# Episode 38 - deer - Step 222249 - Epsilon 0.9459531296775834 - Mean Reward 0.0 - Mean Length 5698.692 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 208.311 - Time 2023-04-28T12:54:29
# Episode 39 - tiger - Step 81322 - Epsilon 0.9798747686800452 - Mean Reward 37.65 - Mean Length 2033.05 - Mean Loss 0.011 - Mean Q Value 0.156 - Time Delta 80.556 - Time 2023-04-28T12:54:51
# Episode 40 - tiger - Step 83801 - Epsilon 0.9792676793574192 - Mean Reward 37.927 - Mean Length 2043.927 - Mean Loss 0.012 - Mean Q Value 0.165 - Time Delta 20.552 - Time 2023-04-28T12:55:11
# Episode 41 - tiger - Step 86162 - Epsilon 0.9786898370898452 - Mean Reward 38.024 - Mean Length 2051.476 - Mean Loss 0.012 - Mean Q Value 0.174 - Time Delta 21.482 - Time 2023-04-28T12:55:33
# Episode 42 - tiger - Step 88625 - Epsilon 0.9780873942433937 - Mean Reward 38.163 - Mean Length 2061.047 - Mean Loss 0.012 - Mean Q Value 0.181 - Time Delta 20.616 - Time 2023-04-28T12:55:53
# Episode 43 - tiger - Step 91189 - Epsilon 0.9774606410411131 - Mean Reward 38.409 - Mean Length 2072.477 - Mean Loss 0.012 - Mean Q Value 0.19 - Time Delta 21.06 - Time 2023-04-28T12:56:14
# Episode 44 - deer - Step 249945 - Epsilon 0.9394259724860324 - Mean Reward 0.0 - Mean Length 5554.333 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 163.765 - Time 2023-04-28T12:57:12
# Episode 45 - tiger - Step 93749 - Epsilon 0.9768352662938552 - Mean Reward 37.848 - Mean Length 2038.022 - Mean Loss 0.012 - Mean Q Value 0.194 - Time Delta 79.454 - Time 2023-04-28T12:57:34
# Episode 46 - tiger - Step 96084 - Epsilon 0.9762652050386357 - Mean Reward 37.979 - Mean Length 2044.34 - Mean Loss 0.012 - Mean Q Value 0.202 - Time Delta 21.671 - Time 2023-04-28T12:57:55
# Episode 47 - tiger - Step 98612 - Epsilon 0.9756484002826971 - Mean Reward 38.146 - Mean Length 2054.417 - Mean Loss 0.012 - Mean Q Value 0.21 - Time Delta 22.392 - Time 2023-04-28T12:58:18
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_2.chkpt at step 100000
# Episode 48 - tiger - Step 101473 - Epsilon 0.9749508171799979 - Mean Reward 38.51 - Mean Length 2070.878 - Mean Loss 0.013 - Mean Q Value 0.218 - Time Delta 21.338 - Time 2023-04-28T12:58:39
# Episode 49 - tiger - Step 104132 - Epsilon 0.974302933907262 - Mean Reward 38.76 - Mean Length 2082.64 - Mean Loss 0.013 - Mean Q Value 0.226 - Time Delta 20.474 - Time 2023-04-28T12:59:00
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_5.chkpt at step 250000
# Episode 50 - deer - Step 278384 - Epsilon 0.9327705749865183 - Mean Reward 0.0 - Mean Length 5458.51 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 168.682 - Time 2023-04-28T13:00:01
# Episode 51 - tiger - Step 106504 - Epsilon 0.9737253434676673 - Mean Reward 38.231 - Mean Length 2048.154 - Mean Loss 0.013 - Mean Q Value 0.23 - Time Delta 83.468 - Time 2023-04-28T13:00:23
# Episode 52 - tiger - Step 109023 - Epsilon 0.9731123328978698 - Mean Reward 38.415 - Mean Length 2057.038 - Mean Loss 0.013 - Mean Q Value 0.238 - Time Delta 21.86 - Time 2023-04-28T13:00:45
# Episode 53 - tiger - Step 112166 - Epsilon 0.9723480101092883 - Mean Reward 39.0 - Mean Length 2077.148 - Mean Loss 0.013 - Mean Q Value 0.246 - Time Delta 21.868 - Time 2023-04-28T13:01:07
# Episode 54 - tiger - Step 115188 - Epsilon 0.9716136785244435 - Mean Reward 39.291 - Mean Length 2094.327 - Mean Loss 0.013 - Mean Q Value 0.254 - Time Delta 22.955 - Time 2023-04-28T13:01:30
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_6.chkpt at step 300000
# Episode 55 - deer - Step 307240 - Epsilon 0.9260657804907105 - Mean Reward 0.0 - Mean Length 5486.429 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 149.778 - Time 2023-04-28T13:02:31
# Episode 56 - tiger - Step 117786 - Epsilon 0.9709828202546958 - Mean Reward 38.772 - Mean Length 2066.421 - Mean Loss 0.013 - Mean Q Value 0.258 - Time Delta 83.382 - Time 2023-04-28T13:02:53
# Episode 57 - tiger - Step 119956 - Epsilon 0.9704562048661481 - Mean Reward 38.69 - Mean Length 2068.207 - Mean Loss 0.013 - Mean Q Value 0.266 - Time Delta 22.883 - Time 2023-04-28T13:03:16
# Episode 58 - tiger - Step 122596 - Epsilon 0.9698159150097012 - Mean Reward 38.966 - Mean Length 2077.898 - Mean Loss 0.013 - Mean Q Value 0.274 - Time Delta 21.434 - Time 2023-04-28T13:03:37
# Episode 59 - tiger - Step 125471 - Epsilon 0.9691191101778242 - Mean Reward 39.25 - Mean Length 2091.183 - Mean Loss 0.013 - Mean Q Value 0.282 - Time Delta 22.821 - Time 2023-04-28T13:04:00
# Episode 60 - tiger - Step 128356 - Epsilon 0.9684203849402495 - Mean Reward 39.426 - Mean Length 2104.197 - Mean Loss 0.013 - Mean Q Value 0.29 - Time Delta 23.213 - Time 2023-04-28T13:04:23
# Episode 61 - deer - Step 336315 - Epsilon 0.9193588440614536 - Mean Reward 0.0 - Mean Length 5424.435 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 174.458 - Time 2023-04-28T13:05:25
# Episode 62 - tiger - Step 131094 - Epsilon 0.9677577279240693 - Mean Reward 39.032 - Mean Length 2080.857 - Mean Loss 0.013 - Mean Q Value 0.293 - Time Delta 83.27 - Time 2023-04-28T13:05:47
# Episode 63 - tiger - Step 133301 - Epsilon 0.967223914810121 - Mean Reward 39.062 - Mean Length 2082.828 - Mean Loss 0.013 - Mean Q Value 0.301 - Time Delta 22.661 - Time 2023-04-28T13:06:09
# Episode 64 - tiger - Step 136126 - Epsilon 0.9665410539984423 - Mean Reward 39.292 - Mean Length 2094.246 - Mean Loss 0.013 - Mean Q Value 0.309 - Time Delta 22.773 - Time 2023-04-28T13:06:32
# Episode 65 - tiger - Step 138812 - Epsilon 0.9658922394633465 - Mean Reward 39.439 - Mean Length 2103.212 - Mean Loss 0.013 - Mean Q Value 0.316 - Time Delta 22.225 - Time 2023-04-28T13:06:54
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_7.chkpt at step 350000
# Episode 66 - deer - Step 364116 - Epsilon 0.9129912233693542 - Mean Reward 0.0 - Mean Length 5434.567 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 147.858 - Time 2023-04-28T13:07:53
# Episode 67 - tiger - Step 141459 - Epsilon 0.965253271635718 - Mean Reward 39.044 - Mean Length 2080.279 - Mean Loss 0.013 - Mean Q Value 0.319 - Time Delta 81.413 - Time 2023-04-28T13:08:16
# Episode 68 - tiger - Step 144156 - Epsilon 0.9646026688949972 - Mean Reward 39.188 - Mean Length 2089.217 - Mean Loss 0.013 - Mean Q Value 0.327 - Time Delta 23.012 - Time 2023-04-28T13:08:39
# Episode 69 - tiger - Step 146920 - Epsilon 0.9639363586041281 - Mean Reward 39.3 - Mean Length 2098.857 - Mean Loss 0.013 - Mean Q Value 0.335 - Time Delta 22.967 - Time 2023-04-28T13:09:02
# Episode 70 - tiger - Step 149481 - Epsilon 0.9633193957996182 - Mean Reward 39.437 - Mean Length 2105.366 - Mean Loss 0.013 - Mean Q Value 0.342 - Time Delta 22.284 - Time 2023-04-28T13:09:24
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_3.chkpt at step 150000
# Episode 71 - tiger - Step 151810 - Epsilon 0.9627586662694696 - Mean Reward 39.528 - Mean Length 2108.472 - Mean Loss 0.013 - Mean Q Value 0.35 - Time Delta 22.578 - Time 2023-04-28T13:09:47
# Episode 72 - deer - Step 388412 - Epsilon 0.9074625216516178 - Mean Reward 0.0 - Mean Length 5320.712 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 165.029 - Time 2023-04-28T13:10:38
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_8.chkpt at step 400000
# Episode 73 - deer - Step 417916 - Epsilon 0.9007937020988407 - Mean Reward 0.0 - Mean Length 5647.514 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 62.514 - Time 2023-04-28T13:11:41
# Episode 74 - tiger - Step 154458 - Epsilon 0.9621215308677536 - Mean Reward 38.627 - Mean Length 2059.44 - Mean Loss 0.013 - Mean Q Value 0.348 - Time Delta 135.959 - Time 2023-04-28T13:12:03
# Episode 75 - tiger - Step 157313 - Epsilon 0.9614350615520719 - Mean Reward 38.934 - Mean Length 2069.908 - Mean Loss 0.013 - Mean Q Value 0.355 - Time Delta 22.085 - Time 2023-04-28T13:12:25
# Episode 76 - tiger - Step 159941 - Epsilon 0.9608036060934463 - Mean Reward 39.026 - Mean Length 2077.156 - Mean Loss 0.013 - Mean Q Value 0.362 - Time Delta 23.262 - Time 2023-04-28T13:12:48
# Episode 77 - tiger - Step 162469 - Epsilon 0.9601965699820474 - Mean Reward 39.077 - Mean Length 2082.936 - Mean Loss 0.013 - Mean Q Value 0.37 - Time Delta 22.928 - Time 2023-04-28T13:13:11
# Episode 78 - tiger - Step 165353 - Epsilon 0.9595045176833192 - Mean Reward 39.228 - Mean Length 2093.076 - Mean Loss 0.013 - Mean Q Value 0.377 - Time Delta 22.857 - Time 2023-04-28T13:13:34
# Episode 79 - tiger - Step 167998 - Epsilon 0.9588702549678472 - Mean Reward 39.425 - Mean Length 2099.975 - Mean Loss 0.013 - Mean Q Value 0.384 - Time Delta 22.126 - Time 2023-04-28T13:13:56
# Episode 80 - tiger - Step 170654 - Epsilon 0.9582337763731772 - Mean Reward 39.568 - Mean Length 2106.84 - Mean Loss 0.013 - Mean Q Value 0.391 - Time Delta 21.994 - Time 2023-04-28T13:14:18
# Episode 81 - deer - Step 443660 - Epsilon 0.8950148095330549 - Mean Reward 0.0 - Mean Length 5410.488 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 212.379 - Time 2023-04-28T13:15:13
# Episode 82 - tiger - Step 173077 - Epsilon 0.9576535019588812 - Mean Reward 39.181 - Mean Length 2085.265 - Mean Loss 0.013 - Mean Q Value 0.393 - Time Delta 77.848 - Time 2023-04-28T13:15:36
# Episode 83 - tiger - Step 175700 - Epsilon 0.957025726450802 - Mean Reward 39.286 - Mean Length 2091.667 - Mean Loss 0.013 - Mean Q Value 0.4 - Time Delta 23.321 - Time 2023-04-28T13:15:59
# Episode 84 - tiger - Step 178180 - Epsilon 0.956432554328534 - Mean Reward 39.376 - Mean Length 2096.235 - Mean Loss 0.013 - Mean Q Value 0.407 - Time Delta 22.875 - Time 2023-04-28T13:16:22
# Episode 85 - tiger - Step 180397 - Epsilon 0.955902598396583 - Mean Reward 39.372 - Mean Length 2097.64 - Mean Loss 0.013 - Mean Q Value 0.414 - Time Delta 24.128 - Time 2023-04-28T13:16:46
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_9.chkpt at step 450000
# Episode 86 - deer - Step 473580 - Epsilon 0.8883450738324562 - Mean Reward 0.0 - Mean Length 5443.448 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 157.347 - Time 2023-04-28T13:17:50
# Episode 87 - tiger - Step 183087 - Epsilon 0.9552599699267851 - Mean Reward 39.136 - Mean Length 2080.534 - Mean Loss 0.013 - Mean Q Value 0.416 - Time Delta 87.148 - Time 2023-04-28T13:18:13
# Episode 88 - tiger - Step 186029 - Epsilon 0.9545576344465484 - Mean Reward 39.337 - Mean Length 2090.213 - Mean Loss 0.013 - Mean Q Value 0.422 - Time Delta 23.362 - Time 2023-04-28T13:18:37
# Episode 89 - tiger - Step 188462 - Epsilon 0.9539772012349069 - Mean Reward 39.444 - Mean Length 2094.022 - Mean Loss 0.013 - Mean Q Value 0.429 - Time Delta 23.564 - Time 2023-04-28T13:19:00
# Episode 90 - tiger - Step 190925 - Epsilon 0.9533899705119745 - Mean Reward 39.538 - Mean Length 2098.077 - Mean Loss 0.013 - Mean Q Value 0.435 - Time Delta 23.027 - Time 2023-04-28T13:19:23
# Episode 91 - tiger - Step 193916 - Epsilon 0.9526773395404539 - Mean Reward 39.75 - Mean Length 2107.783 - Mean Loss 0.013 - Mean Q Value 0.442 - Time Delta 23.479 - Time 2023-04-28T13:19:47
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_10.chkpt at step 500000
# Episode 92 - deer - Step 501581 - Epsilon 0.882148150765122 - Mean Reward 0.0 - Mean Length 5393.344 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 176.839 - Time 2023-04-28T13:20:47
# Episode 93 - tiger - Step 196205 - Epsilon 0.9521323258216232 - Mean Reward 39.404 - Mean Length 2087.287 - Mean Loss 0.013 - Mean Q Value 0.443 - Time Delta 82.892 - Time 2023-04-28T13:21:10
# Episode 94 - tiger - Step 198605 - Epsilon 0.9515612177042326 - Mean Reward 39.537 - Mean Length 2090.579 - Mean Loss 0.013 - Mean Q Value 0.449 - Time Delta 22.5 - Time 2023-04-28T13:21:32
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_4.chkpt at step 200000
# Episode 95 - tiger - Step 201040 - Epsilon 0.9509821310178808 - Mean Reward 39.615 - Mean Length 2094.167 - Mean Loss 0.013 - Mean Q Value 0.455 - Time Delta 23.293 - Time 2023-04-28T13:21:55
# Episode 96 - tiger - Step 203738 - Epsilon 0.9503409097664419 - Mean Reward 39.856 - Mean Length 2100.392 - Mean Loss 0.013 - Mean Q Value 0.461 - Time Delta 22.349 - Time 2023-04-28T13:22:18
# Episode 97 - tiger - Step 206641 - Epsilon 0.9496514499828808 - Mean Reward 40.01 - Mean Length 2108.582 - Mean Loss 0.013 - Mean Q Value 0.467 - Time Delta 25.394 - Time 2023-04-28T13:22:43
# Episode 98 - deer - Step 530358 - Epsilon 0.8758245297697156 - Mean Reward 0.0 - Mean Length 5357.152 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 177.896 - Time 2023-04-28T13:23:45
# Episode 99 - tiger - Step 209790 - Epsilon 0.948904130987399 - Mean Reward 39.84 - Mean Length 2097.9 - Mean Loss 0.013 - Mean Q Value 0.468 - Time Delta 86.391 - Time 2023-04-28T13:24:09
# Episode 100 - tiger - Step 212180 - Epsilon 0.948337330046845 - Mean Reward 40.38 - Mean Length 2121.8 - Mean Loss 0.013 - Mean Q Value 0.479 - Time Delta 22.452 - Time 2023-04-28T13:24:32
# Episode 101 - tiger - Step 214275 - Epsilon 0.9478407683565382 - Mean Reward 40.16 - Mean Length 2114.47 - Mean Loss 0.013 - Mean Q Value 0.489 - Time Delta 24.634 - Time 2023-04-28T13:24:57
# Episode 102 - tiger - Step 217014 - Epsilon 0.9471919564715325 - Mean Reward 40.15 - Mean Length 2116.52 - Mean Loss 0.014 - Mean Q Value 0.5 - Time Delta 24.935 - Time 2023-04-28T13:25:21
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_11.chkpt at step 550000
# Episode 103 - deer - Step 562358 - Epsilon 0.8688458844589007 - Mean Reward 0.0 - Mean Length 5346.25 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 165.262 - Time 2023-04-28T13:26:30
# Episode 104 - tiger - Step 220023 - Epsilon 0.9464796991645137 - Mean Reward 39.62 - Mean Length 2092.68 - Mean Loss 0.014 - Mean Q Value 0.51 - Time Delta 92.902 - Time 2023-04-28T13:26:54
# Episode 105 - tiger - Step 222822 - Epsilon 0.9458176315800844 - Mean Reward 39.75 - Mean Length 2093.98 - Mean Loss 0.014 - Mean Q Value 0.521 - Time Delta 21.657 - Time 2023-04-28T13:27:16
# Episode 106 - tiger - Step 225189 - Epsilon 0.9452581094915032 - Mean Reward 40.26 - Mean Length 2117.65 - Mean Loss 0.014 - Mean Q Value 0.531 - Time Delta 22.544 - Time 2023-04-28T13:27:39
# Episode 107 - tiger - Step 227427 - Epsilon 0.9447293854374198 - Mean Reward 40.02 - Mean Length 2111.26 - Mean Loss 0.014 - Mean Q Value 0.542 - Time Delta 25.152 - Time 2023-04-28T13:28:04
# Episode 108 - tiger - Step 230167 - Epsilon 0.9440824673221913 - Mean Reward 40.07 - Mean Length 2110.86 - Mean Loss 0.014 - Mean Q Value 0.553 - Time Delta 23.21 - Time 2023-04-28T13:28:27
# Episode 109 - deer - Step 589483 - Epsilon 0.8629739545842219 - Mean Reward 0.0 - Mean Length 5321.74 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 175.032 - Time 2023-04-28T13:29:25
# Episode 110 - tiger - Step 232826 - Epsilon 0.943455096968855 - Mean Reward 39.68 - Mean Length 2085.31 - Mean Loss 0.014 - Mean Q Value 0.563 - Time Delta 81.851 - Time 2023-04-28T13:29:49
# Episode 111 - tiger - Step 235079 - Epsilon 0.9429238454467631 - Mean Reward 40.03 - Mean Length 2107.84 - Mean Loss 0.014 - Mean Q Value 0.574 - Time Delta 23.468 - Time 2023-04-28T13:30:12
# Episode 112 - tiger - Step 237590 - Epsilon 0.9423321106789188 - Mean Reward 40.17 - Mean Length 2111.21 - Mean Loss 0.014 - Mean Q Value 0.584 - Time Delta 23.962 - Time 2023-04-28T13:30:36
# Episode 113 - tiger - Step 240131 - Epsilon 0.9417336842260493 - Mean Reward 40.14 - Mean Length 2112.66 - Mean Loss 0.014 - Mean Q Value 0.594 - Time Delta 25.472 - Time 2023-04-28T13:31:02
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_12.chkpt at step 600000
# Episode 114 - deer - Step 615662 - Epsilon 0.8573444470446109 - Mean Reward 0.0 - Mean Length 5332.72 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 153.142 - Time 2023-04-28T13:31:59
# Episode 115 - tiger - Step 242795 - Epsilon 0.9411066983233776 - Mean Reward 39.82 - Mean Length 2086.38 - Mean Loss 0.014 - Mean Q Value 0.603 - Time Delta 80.65 - Time 2023-04-28T13:32:22
# Episode 116 - tiger - Step 245843 - Epsilon 0.940389848084177 - Mean Reward 40.02 - Mean Length 2094.59 - Mean Loss 0.014 - Mean Q Value 0.613 - Time Delta 23.811 - Time 2023-04-28T13:32:46
# Episode 117 - tiger - Step 248100 - Epsilon 0.9398593827176286 - Mean Reward 40.47 - Mean Length 2117.16 - Mean Loss 0.014 - Mean Q Value 0.624 - Time Delta 24.225 - Time 2023-04-28T13:33:10
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_5.chkpt at step 250000
# Episode 118 - tiger - Step 250737 - Epsilon 0.9392399845336206 - Mean Reward 40.46 - Mean Length 2117.8 - Mean Loss 0.014 - Mean Q Value 0.634 - Time Delta 24.997 - Time 2023-04-28T13:33:35
# Episode 119 - tiger - Step 253157 - Epsilon 0.9386719161299079 - Mean Reward 40.54 - Mean Length 2118.68 - Mean Loss 0.014 - Mean Q Value 0.644 - Time Delta 23.839 - Time 2023-04-28T13:33:59
# Episode 120 - deer - Step 640650 - Epsilon 0.8520053097743656 - Mean Reward 0.0 - Mean Length 5312.06 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 175.542 - Time 2023-04-28T13:34:54
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_13.chkpt at step 650000
# Episode 121 - deer - Step 667359 - Epsilon 0.8463352080206817 - Mean Reward 0.0 - Mean Length 5579.15 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 58.233 - Time 2023-04-28T13:35:52
# Episode 122 - tiger - Step 255715 - Epsilon 0.938071827263315 - Mean Reward 39.74 - Mean Length 2071.25 - Mean Loss 0.014 - Mean Q Value 0.649 - Time Delta 138.683 - Time 2023-04-28T13:36:18
# Episode 123 - tiger - Step 258606 - Epsilon 0.9373940807155099 - Mean Reward 40.33 - Mean Length 2100.16 - Mean Loss 0.014 - Mean Q Value 0.66 - Time Delta 23.877 - Time 2023-04-28T13:36:42
# Episode 124 - tiger - Step 261322 - Epsilon 0.9367578060947617 - Mean Reward 40.27 - Mean Length 2096.11 - Mean Loss 0.014 - Mean Q Value 0.669 - Time Delta 25.083 - Time 2023-04-28T13:37:07
# Episode 125 - tiger - Step 263862 - Epsilon 0.9361631536356156 - Mean Reward 40.18 - Mean Length 2096.02 - Mean Loss 0.014 - Mean Q Value 0.678 - Time Delta 25.369 - Time 2023-04-28T13:37:32
# Episode 126 - tiger - Step 266434 - Epsilon 0.9355613941389301 - Mean Reward 40.39 - Mean Length 2100.95 - Mean Loss 0.014 - Mean Q Value 0.686 - Time Delta 25.215 - Time 2023-04-28T13:37:57
# Episode 127 - tiger - Step 269212 - Epsilon 0.9349118722420062 - Mean Reward 40.44 - Mean Length 2103.39 - Mean Loss 0.014 - Mean Q Value 0.695 - Time Delta 24.509 - Time 2023-04-28T13:38:22
# Episode 128 - tiger - Step 271472 - Epsilon 0.9343837961636463 - Mean Reward 40.37 - Mean Length 2100.7 - Mean Loss 0.014 - Mean Q Value 0.703 - Time Delta 25.2 - Time 2023-04-28T13:38:47
# Episode 129 - deer - Step 694974 - Epsilon 0.8405124431829379 - Mean Reward 0.0 - Mean Length 5300.27 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 235.105 - Time 2023-04-28T13:39:47
# Episode 130 - tiger - Step 274094 - Epsilon 0.933771508207942 - Mean Reward 40.98 - Mean Length 2126.92 - Mean Loss 0.014 - Mean Q Value 0.715 - Time Delta 83.006 - Time 2023-04-28T13:40:10
# Episode 131 - tiger - Step 277140 - Epsilon 0.9330607117855794 - Mean Reward 41.23 - Mean Length 2130.72 - Mean Loss 0.014 - Mean Q Value 0.722 - Time Delta 23.823 - Time 2023-04-28T13:40:34
# Episode 132 - tiger - Step 280058 - Epsilon 0.9323802921244287 - Mean Reward 41.46 - Mean Length 2138.46 - Mean Loss 0.014 - Mean Q Value 0.73 - Time Delta 25.871 - Time 2023-04-28T13:41:00
# Episode 133 - tiger - Step 282865 - Epsilon 0.9317262236956828 - Mean Reward 41.44 - Mean Length 2137.94 - Mean Loss 0.014 - Mean Q Value 0.738 - Time Delta 24.536 - Time 2023-04-28T13:41:24
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_14.chkpt at step 700000
# Episode 134 - deer - Step 723203 - Epsilon 0.8346016176227169 - Mean Reward 0.0 - Mean Length 5288.4 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 158.483 - Time 2023-04-28T13:42:26
# Episode 135 - tiger - Step 285342 - Epsilon 0.9311494307674217 - Mean Reward 41.13 - Mean Length 2114.54 - Mean Loss 0.014 - Mean Q Value 0.741 - Time Delta 85.698 - Time 2023-04-28T13:42:50
# Episode 136 - tiger - Step 287729 - Epsilon 0.9305939330382179 - Mean Reward 41.12 - Mean Length 2114.17 - Mean Loss 0.014 - Mean Q Value 0.748 - Time Delta 24.012 - Time 2023-04-28T13:43:14
# Episode 137 - tiger - Step 290030 - Epsilon 0.9300587627543783 - Mean Reward 41.12 - Mean Length 2112.5 - Mean Loss 0.014 - Mean Q Value 0.755 - Time Delta 23.846 - Time 2023-04-28T13:43:38
# Episode 138 - tiger - Step 292713 - Epsilon 0.9294351349337806 - Mean Reward 41.61 - Mean Length 2139.33 - Mean Loss 0.014 - Mean Q Value 0.766 - Time Delta 24.851 - Time 2023-04-28T13:44:03
# Episode 139 - tiger - Step 295070 - Epsilon 0.9288876265375046 - Mean Reward 41.62 - Mean Length 2137.48 - Mean Loss 0.014 - Mean Q Value 0.773 - Time Delta 25.801 - Time 2023-04-28T13:44:29
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_15.chkpt at step 750000
# Episode 140 - deer - Step 751749 - Epsilon 0.8286666849480152 - Mean Reward 0.0 - Mean Length 5295.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 185.251 - Time 2023-04-28T13:45:31
# Episode 141 - tiger - Step 297577 - Epsilon 0.9283056285474132 - Mean Reward 41.22 - Mean Length 2114.15 - Mean Loss 0.014 - Mean Q Value 0.774 - Time Delta 86.267 - Time 2023-04-28T13:45:55
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_6.chkpt at step 300000
# Episode 142 - tiger - Step 300382 - Epsilon 0.9276548823385157 - Mean Reward 41.31 - Mean Length 2117.57 - Mean Loss 0.014 - Mean Q Value 0.78 - Time Delta 25.463 - Time 2023-04-28T13:46:20
# Episode 143 - tiger - Step 302830 - Epsilon 0.9270873311678736 - Mean Reward 41.39 - Mean Length 2116.41 - Mean Loss 0.014 - Mean Q Value 0.786 - Time Delta 22.803 - Time 2023-04-28T13:46:43
# Episode 144 - tiger - Step 305495 - Epsilon 0.9264698648725136 - Mean Reward 41.9 - Mean Length 2143.06 - Mean Loss 0.014 - Mean Q Value 0.797 - Time Delta 25.501 - Time 2023-04-28T13:47:09
# Episode 145 - tiger - Step 307908 - Epsilon 0.9259111403988246 - Mean Reward 41.84 - Mean Length 2141.59 - Mean Loss 0.014 - Mean Q Value 0.803 - Time Delta 24.794 - Time 2023-04-28T13:47:33
# Episode 146 - deer - Step 777815 - Epsilon 0.8232842342390533 - Mean Reward 0.0 - Mean Length 5278.7 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 179.557 - Time 2023-04-28T13:48:31
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_16.chkpt at step 800000
# Episode 147 - deer - Step 806914 - Epsilon 0.8173167787002852 - Mean Reward 0.0 - Mean Length 5569.69 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 63.275 - Time 2023-04-28T13:49:34
# Episode 148 - tiger - Step 310628 - Epsilon 0.925281734766753 - Mean Reward 40.97 - Mean Length 2091.55 - Mean Loss 0.013 - Mean Q Value 0.797 - Time Delta 144.86 - Time 2023-04-28T13:49:58
# Episode 149 - tiger - Step 313017 - Epsilon 0.9247292751761942 - Mean Reward 40.86 - Mean Length 2088.85 - Mean Loss 0.013 - Mean Q Value 0.802 - Time Delta 26.422 - Time 2023-04-28T13:50:25
# Episode 150 - tiger - Step 315594 - Epsilon 0.9241337101331214 - Mean Reward 41.37 - Mean Length 2114.62 - Mean Loss 0.014 - Mean Q Value 0.813 - Time Delta 25.157 - Time 2023-04-28T13:50:50
# Episode 151 - tiger - Step 317971 - Epsilon 0.9235847067459622 - Mean Reward 41.33 - Mean Length 2114.67 - Mean Loss 0.014 - Mean Q Value 0.818 - Time Delta 25.28 - Time 2023-04-28T13:51:15
# Episode 152 - tiger - Step 320344 - Epsilon 0.9230369525437954 - Mean Reward 41.23 - Mean Length 2113.21 - Mean Loss 0.013 - Mean Q Value 0.823 - Time Delta 26.413 - Time 2023-04-28T13:51:42
# Episode 153 - tiger - Step 322962 - Epsilon 0.9224330224404635 - Mean Reward 41.08 - Mean Length 2107.96 - Mean Loss 0.013 - Mean Q Value 0.827 - Time Delta 24.29 - Time 2023-04-28T13:52:06
# Episode 154 - tiger - Step 325659 - Epsilon 0.9218112815252414 - Mean Reward 41.06 - Mean Length 2104.71 - Mean Loss 0.013 - Mean Q Value 0.831 - Time Delta 25.667 - Time 2023-04-28T13:52:32
# Episode 155 - deer - Step 834714 - Epsilon 0.8116561199544068 - Mean Reward 0.0 - Mean Length 5274.74 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 238.614 - Time 2023-04-28T13:53:33
# Episode 156 - tiger - Step 328494 - Epsilon 0.9211581791682195 - Mean Reward 41.11 - Mean Length 2107.08 - Mean Loss 0.013 - Mean Q Value 0.836 - Time Delta 86.169 - Time 2023-04-28T13:53:58
# Episode 157 - tiger - Step 331220 - Epsilon 0.9205306236544135 - Mean Reward 41.31 - Mean Length 2112.64 - Mean Loss 0.013 - Mean Q Value 0.84 - Time Delta 24.854 - Time 2023-04-28T13:54:23
# Episode 158 - tiger - Step 333735 - Epsilon 0.919952021869382 - Mean Reward 41.25 - Mean Length 2111.39 - Mean Loss 0.013 - Mean Q Value 0.844 - Time Delta 25.136 - Time 2023-04-28T13:54:48
# Episode 159 - tiger - Step 336229 - Epsilon 0.9193786104915628 - Mean Reward 41.11 - Mean Length 2107.58 - Mean Loss 0.013 - Mean Q Value 0.847 - Time Delta 25.939 - Time 2023-04-28T13:55:14
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_17.chkpt at step 850000
# Episode 160 - deer - Step 861747 - Epsilon 0.8061892383816185 - Mean Reward 0.0 - Mean Length 5545.07 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 160.743 - Time 2023-04-28T13:56:13
# Episode 161 - tiger - Step 339130 - Epsilon 0.9187120728033389 - Mean Reward 41.16 - Mean Length 2107.74 - Mean Loss 0.013 - Mean Q Value 0.851 - Time Delta 84.815 - Time 2023-04-28T13:56:38
# Episode 162 - tiger - Step 341941 - Epsilon 0.9180666746167562 - Mean Reward 41.19 - Mean Length 2108.47 - Mean Loss 0.013 - Mean Q Value 0.854 - Time Delta 25.473 - Time 2023-04-28T13:57:04
# Episode 163 - tiger - Step 344364 - Epsilon 0.917510724059561 - Mean Reward 41.22 - Mean Length 2110.63 - Mean Loss 0.013 - Mean Q Value 0.858 - Time Delta 26.572 - Time 2023-04-28T13:57:30
# Episode 164 - tiger - Step 347182 - Epsilon 0.916864565309744 - Mean Reward 41.34 - Mean Length 2110.56 - Mean Loss 0.013 - Mean Q Value 0.861 - Time Delta 25.207 - Time 2023-04-28T13:57:56
# Episode 165 - tiger - Step 349479 - Epsilon 0.9163382069123632 - Mean Reward 41.26 - Mean Length 2106.67 - Mean Loss 0.013 - Mean Q Value 0.864 - Time Delta 26.239 - Time 2023-04-28T13:58:22
# Episode 166 - deer - Step 890299 - Epsilon 0.8004551481948426 - Mean Reward 0.0 - Mean Length 5261.83 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 191.534 - Time 2023-04-28T13:59:25
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_7.chkpt at step 350000
# Episode 167 - tiger - Step 352041 - Epsilon 0.9157514801367214 - Mean Reward 41.2 - Mean Length 2105.82 - Mean Loss 0.013 - Mean Q Value 0.867 - Time Delta 89.212 - Time 2023-04-28T13:59:51
# Episode 168 - tiger - Step 354462 - Epsilon 0.9151973891827203 - Mean Reward 41.18 - Mean Length 2103.06 - Mean Loss 0.013 - Mean Q Value 0.87 - Time Delta 25.198 - Time 2023-04-28T14:00:16
# Episode 169 - tiger - Step 357069 - Epsilon 0.9146011035453909 - Mean Reward 41.15 - Mean Length 2101.49 - Mean Loss 0.013 - Mean Q Value 0.872 - Time Delta 26.545 - Time 2023-04-28T14:00:43
# Episode 170 - tiger - Step 359688 - Epsilon 0.914002464398809 - Mean Reward 41.12 - Mean Length 2102.07 - Mean Loss 0.013 - Mean Q Value 0.875 - Time Delta 26.362 - Time 2023-04-28T14:01:09
# Episode 171 - tiger - Step 362296 - Epsilon 0.9134067289483323 - Mean Reward 41.1 - Mean Length 2104.86 - Mean Loss 0.013 - Mean Q Value 0.877 - Time Delta 26.919 - Time 2023-04-28T14:01:36
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_18.chkpt at step 900000
# Episode 172 - deer - Step 918588 - Epsilon 0.7948140995325109 - Mean Reward 0.0 - Mean Length 5301.76 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 194.291 - Time 2023-04-28T14:02:39
# Episode 173 - tiger - Step 364932 - Epsilon 0.912804992132714 - Mean Reward 41.62 - Mean Length 2131.22 - Mean Loss 0.014 - Mean Q Value 0.889 - Time Delta 88.35 - Time 2023-04-28T14:03:04
# Episode 174 - tiger - Step 367602 - Epsilon 0.9121958980320141 - Mean Reward 41.53 - Mean Length 2131.44 - Mean Loss 0.014 - Mean Q Value 0.891 - Time Delta 27.23 - Time 2023-04-28T14:03:32
# Episode 175 - tiger - Step 370306 - Epsilon 0.9115794619066909 - Mean Reward 41.39 - Mean Length 2129.93 - Mean Loss 0.014 - Mean Q Value 0.893 - Time Delta 26.114 - Time 2023-04-28T14:03:58
# Episode 176 - tiger - Step 372638 - Epsilon 0.9110481659017489 - Mean Reward 41.33 - Mean Length 2126.97 - Mean Loss 0.014 - Mean Q Value 0.895 - Time Delta 26.452 - Time 2023-04-28T14:04:24
# Episode 177 - deer - Step 946957 - Epsilon 0.7891970209399094 - Mean Reward 0.0 - Mean Length 5290.41 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 167.832 - Time 2023-04-28T14:05:27
# Episode 178 - tiger - Step 375200 - Epsilon 0.9104648263129361 - Mean Reward 40.81 - Mean Length 2098.47 - Mean Loss 0.013 - Mean Q Value 0.888 - Time Delta 89.55 - Time 2023-04-28T14:05:54
# Episode 179 - tiger - Step 377858 - Epsilon 0.9098600233282138 - Mean Reward 40.73 - Mean Length 2098.6 - Mean Loss 0.013 - Mean Q Value 0.89 - Time Delta 26.625 - Time 2023-04-28T14:06:20
# Episode 180 - tiger - Step 380445 - Epsilon 0.9092717615341762 - Mean Reward 40.77 - Mean Length 2097.91 - Mean Loss 0.013 - Mean Q Value 0.891 - Time Delta 25.635 - Time 2023-04-28T14:06:46
# Episode 181 - tiger - Step 383043 - Epsilon 0.9086813811979483 - Mean Reward 41.19 - Mean Length 2123.89 - Mean Loss 0.014 - Mean Q Value 0.902 - Time Delta 26.925 - Time 2023-04-28T14:07:13
# Episode 182 - tiger - Step 385107 - Epsilon 0.908212622496736 - Mean Reward 41.12 - Mean Length 2120.3 - Mean Loss 0.014 - Mean Q Value 0.903 - Time Delta 26.399 - Time 2023-04-28T14:07:39
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_19.chkpt at step 950000
# Episode 183 - deer - Step 973287 - Epsilon 0.7840191911299439 - Mean Reward 0.0 - Mean Length 5296.27 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 191.083 - Time 2023-04-28T14:08:38
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_20.chkpt at step 1000000
# Episode 184 - deer - Step 1000500 - Epsilon 0.7787034146837541 - Mean Reward 0.0 - Mean Length 5568.4 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 60.891 - Time 2023-04-28T14:09:39
# Episode 185 - tiger - Step 387565 - Epsilon 0.9076546972104955 - Mean Reward 40.31 - Mean Length 2071.68 - Mean Loss 0.013 - Mean Q Value 0.885 - Time Delta 144.485 - Time 2023-04-28T14:10:04
# Episode 186 - tiger - Step 389870 - Epsilon 0.907131811796624 - Mean Reward 40.7 - Mean Length 2094.73 - Mean Loss 0.013 - Mean Q Value 0.896 - Time Delta 27.583 - Time 2023-04-28T14:10:31
# Episode 187 - tiger - Step 392554 - Epsilon 0.9065233304430875 - Mean Reward 40.62 - Mean Length 2094.67 - Mean Loss 0.013 - Mean Q Value 0.897 - Time Delta 27.049 - Time 2023-04-28T14:10:59
# Episode 188 - tiger - Step 395492 - Epsilon 0.9058577334440059 - Mean Reward 40.55 - Mean Length 2094.63 - Mean Loss 0.013 - Mean Q Value 0.898 - Time Delta 27.354 - Time 2023-04-28T14:11:26
# Episode 189 - tiger - Step 398057 - Epsilon 0.905277038305043 - Mean Reward 40.51 - Mean Length 2095.95 - Mean Loss 0.013 - Mean Q Value 0.898 - Time Delta 26.871 - Time 2023-04-28T14:11:53
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_8.chkpt at step 400000
# Episode 190 - tiger - Step 400526 - Epsilon 0.9047184284019627 - Mean Reward 40.53 - Mean Length 2096.01 - Mean Loss 0.013 - Mean Q Value 0.899 - Time Delta 25.813 - Time 2023-04-28T14:12:19
# Episode 191 - tiger - Step 403372 - Epsilon 0.9040749501041818 - Mean Reward 40.54 - Mean Length 2094.56 - Mean Loss 0.013 - Mean Q Value 0.899 - Time Delta 24.842 - Time 2023-04-28T14:12:43
# Episode 192 - deer - Step 1028674 - Epsilon 0.7732378873152689 - Mean Reward 0.0 - Mean Length 5270.93 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 246.551 - Time 2023-04-28T14:13:46
# Episode 193 - tiger - Step 405742 - Epsilon 0.9035394442884956 - Mean Reward 40.57 - Mean Length 2095.37 - Mean Loss 0.014 - Mean Q Value 0.9 - Time Delta 88.392 - Time 2023-04-28T14:14:12
# Episode 194 - tiger - Step 408335 - Epsilon 0.9029539145757857 - Mean Reward 40.65 - Mean Length 2097.3 - Mean Loss 0.014 - Mean Q Value 0.9 - Time Delta 26.031 - Time 2023-04-28T14:14:38
# Episode 195 - tiger - Step 410831 - Epsilon 0.9023906470203583 - Mean Reward 40.67 - Mean Length 2097.91 - Mean Loss 0.014 - Mean Q Value 0.901 - Time Delta 27.071 - Time 2023-04-28T14:15:05
# Episode 196 - tiger - Step 413243 - Epsilon 0.9018466694178628 - Mean Reward 40.48 - Mean Length 2095.05 - Mean Loss 0.014 - Mean Q Value 0.901 - Time Delta 26.301 - Time 2023-04-28T14:15:31
# Episode 197 - tiger - Step 416032 - Epsilon 0.9012180759178257 - Mean Reward 40.49 - Mean Length 2093.91 - Mean Loss 0.014 - Mean Q Value 0.901 - Time Delta 26.619 - Time 2023-04-28T14:15:58
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_21.chkpt at step 1050000
# Episode 198 - deer - Step 1055623 - Epsilon 0.7680458992090797 - Mean Reward 0.0 - Mean Length 5252.65 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 192.957 - Time 2023-04-28T14:16:59
# Episode 199 - tiger - Step 418802 - Epsilon 0.9005941983647154 - Mean Reward 40.49 - Mean Length 2090.12 - Mean Loss 0.014 - Mean Q Value 0.901 - Time Delta 84.927 - Time 2023-04-28T14:17:23
# Episode 200 - tiger - Step 421283 - Epsilon 0.9000357779413344 - Mean Reward 40.43 - Mean Length 2091.03 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 25.934 - Time 2023-04-28T14:17:49
# Episode 201 - tiger - Step 423723 - Epsilon 0.8994869234657422 - Mean Reward 40.64 - Mean Length 2094.48 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 24.663 - Time 2023-04-28T14:18:13
# Episode 202 - tiger - Step 426396 - Epsilon 0.8988860420458075 - Mean Reward 40.66 - Mean Length 2093.82 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 26.722 - Time 2023-04-28T14:18:40
# Episode 203 - deer - Step 1081709 - Epsilon 0.7630533842899175 - Mean Reward 0.0 - Mean Length 5193.51 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 159.784 - Time 2023-04-28T14:19:38
# Episode 204 - tiger - Step 428995 - Epsilon 0.8983021804694978 - Mean Reward 40.66 - Mean Length 2089.72 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 83.55 - Time 2023-04-28T14:20:04
# Episode 205 - tiger - Step 431910 - Epsilon 0.897647781149304 - Mean Reward 40.75 - Mean Length 2090.88 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 24.005 - Time 2023-04-28T14:20:28
# Episode 206 - tiger - Step 434525 - Epsilon 0.8970611356196175 - Mean Reward 40.87 - Mean Length 2093.36 - Mean Loss 0.013 - Mean Q Value 0.9 - Time Delta 23.367 - Time 2023-04-28T14:20:51
# Episode 207 - tiger - Step 437148 - Epsilon 0.8964730805359801 - Mean Reward 41.08 - Mean Length 2097.21 - Mean Loss 0.013 - Mean Q Value 0.9 - Time Delta 26.289 - Time 2023-04-28T14:21:17
# Episode 208 - tiger - Step 439803 - Epsilon 0.8958782438875874 - Mean Reward 41.04 - Mean Length 2096.36 - Mean Loss 0.013 - Mean Q Value 0.9 - Time Delta 25.078 - Time 2023-04-28T14:21:42
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_22.chkpt at step 1100000
# Episode 209 - deer - Step 1106984 - Epsilon 0.7582470411485722 - Mean Reward 0.0 - Mean Length 5175.01 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 180.802 - Time 2023-04-28T14:22:39
# Episode 210 - deer - Step 1133294 - Epsilon 0.7532760369253968 - Mean Reward 0.0 - Mean Length 5438.11 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 58.686 - Time 2023-04-28T14:23:38
# Episode 211 - tiger - Step 442679 - Epsilon 0.895234338861248 - Mean Reward 40.7 - Mean Length 2076.0 - Mean Loss 0.013 - Mean Q Value 0.888 - Time Delta 142.211 - Time 2023-04-28T14:24:05
# Episode 212 - tiger - Step 445365 - Epsilon 0.8946333907184196 - Mean Reward 40.8 - Mean Length 2077.75 - Mean Loss 0.013 - Mean Q Value 0.887 - Time Delta 25.928 - Time 2023-04-28T14:24:31
# Episode 213 - tiger - Step 447917 - Epsilon 0.8940627965826212 - Mean Reward 40.8 - Mean Length 2077.86 - Mean Loss 0.013 - Mean Q Value 0.886 - Time Delta 27.864 - Time 2023-04-28T14:24:58
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_9.chkpt at step 450000
# Episode 214 - tiger - Step 450925 - Epsilon 0.893390714010204 - Mean Reward 41.49 - Mean Length 2107.94 - Mean Loss 0.013 - Mean Q Value 0.897 - Time Delta 24.184 - Time 2023-04-28T14:25:23
# Episode 215 - tiger - Step 453534 - Epsilon 0.8928081898404393 - Mean Reward 41.47 - Mean Length 2107.39 - Mean Loss 0.013 - Mean Q Value 0.896 - Time Delta 26.142 - Time 2023-04-28T14:25:49
# Episode 216 - tiger - Step 456415 - Epsilon 0.8921653761823239 - Mean Reward 41.54 - Mean Length 2105.72 - Mean Loss 0.013 - Mean Q Value 0.894 - Time Delta 24.412 - Time 2023-04-28T14:26:13
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_23.chkpt at step 1150000
# Episode 217 - deer - Step 1159745 - Epsilon 0.7483112437508396 - Mean Reward 0.0 - Mean Length 5440.83 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 214.655 - Time 2023-04-28T14:27:12
# Episode 218 - tiger - Step 459052 - Epsilon 0.8915774099141746 - Mean Reward 41.22 - Mean Length 2083.15 - Mean Loss 0.013 - Mean Q Value 0.882 - Time Delta 84.73 - Time 2023-04-28T14:27:38
# Episode 219 - tiger - Step 461690 - Epsilon 0.8909896083876375 - Mean Reward 41.27 - Mean Length 2085.33 - Mean Loss 0.013 - Mean Q Value 0.881 - Time Delta 25.844 - Time 2023-04-28T14:28:04
# Episode 220 - tiger - Step 464182 - Epsilon 0.8904346946657433 - Mean Reward 41.74 - Mean Length 2110.25 - Mean Loss 0.013 - Mean Q Value 0.891 - Time Delta 28.052 - Time 2023-04-28T14:28:32
# Episode 221 - tiger - Step 466910 - Epsilon 0.8898276251622439 - Mean Reward 42.34 - Mean Length 2137.53 - Mean Loss 0.013 - Mean Q Value 0.901 - Time Delta 26.16 - Time 2023-04-28T14:28:58
# Episode 222 - tiger - Step 469930 - Epsilon 0.8891560587694204 - Mean Reward 42.5 - Mean Length 2142.15 - Mean Loss 0.013 - Mean Q Value 0.899 - Time Delta 28.488 - Time 2023-04-28T14:29:26
# Episode 223 - deer - Step 1184270 - Epsilon 0.7437371965078128 - Mean Reward 0.0 - Mean Length 5169.11 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 188.712 - Time 2023-04-28T14:30:21
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_24.chkpt at step 1200000
# Episode 224 - deer - Step 1212113 - Epsilon 0.7385782032331399 - Mean Reward 0.0 - Mean Length 5447.54 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 62.365 - Time 2023-04-28T14:31:24
# Episode 225 - tiger - Step 472112 - Epsilon 0.8886711563478406 - Mean Reward 41.43 - Mean Length 2082.5 - Mean Loss 0.013 - Mean Q Value 0.875 - Time Delta 141.962 - Time 2023-04-28T14:31:48
# Episode 226 - tiger - Step 474810 - Epsilon 0.8880719496830631 - Mean Reward 41.4 - Mean Length 2083.76 - Mean Loss 0.013 - Mean Q Value 0.873 - Time Delta 27.078 - Time 2023-04-28T14:32:15
# Episode 227 - tiger - Step 477416 - Epsilon 0.8874935591666331 - Mean Reward 41.28 - Mean Length 2082.04 - Mean Loss 0.013 - Mean Q Value 0.872 - Time Delta 27.877 - Time 2023-04-28T14:32:43
# Episode 228 - tiger - Step 479919 - Epsilon 0.8869383837211435 - Mean Reward 41.43 - Mean Length 2084.47 - Mean Loss 0.013 - Mean Q Value 0.87 - Time Delta 25.707 - Time 2023-04-28T14:33:09
# Episode 229 - tiger - Step 482520 - Epsilon 0.8863618394342595 - Mean Reward 41.91 - Mean Length 2110.48 - Mean Loss 0.013 - Mean Q Value 0.88 - Time Delta 27.376 - Time 2023-04-28T14:33:36
# Episode 230 - tiger - Step 485495 - Epsilon 0.8857028528247385 - Mean Reward 41.93 - Mean Length 2114.01 - Mean Loss 0.013 - Mean Q Value 0.879 - Time Delta 27.149 - Time 2023-04-28T14:34:04
# Episode 231 - tiger - Step 488316 - Epsilon 0.8850784310222639 - Mean Reward 41.88 - Mean Length 2111.76 - Mean Loss 0.013 - Mean Q Value 0.877 - Time Delta 26.72 - Time 2023-04-28T14:34:30
# Episode 232 - deer - Step 1238107 - Epsilon 0.7337941137197987 - Mean Reward 0.0 - Mean Length 5431.33 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 245.172 - Time 2023-04-28T14:35:29
# Episode 233 - tiger - Step 491342 - Epsilon 0.8844091223033799 - Mean Reward 41.47 - Mean Length 2084.77 - Mean Loss 0.013 - Mean Q Value 0.864 - Time Delta 83.198 - Time 2023-04-28T14:35:53
# Episode 234 - tiger - Step 494116 - Epsilon 0.8837959971260652 - Mean Reward 42.04 - Mean Length 2112.51 - Mean Loss 0.013 - Mean Q Value 0.874 - Time Delta 26.588 - Time 2023-04-28T14:36:20
# Episode 235 - tiger - Step 496956 - Epsilon 0.8831687245977062 - Mean Reward 42.23 - Mean Length 2116.14 - Mean Loss 0.013 - Mean Q Value 0.873 - Time Delta 24.296 - Time 2023-04-28T14:36:44
# Episode 236 - tiger - Step 499692 - Epsilon 0.882564843665332 - Mean Reward 42.34 - Mean Length 2119.63 - Mean Loss 0.013 - Mean Q Value 0.871 - Time Delta 26.394 - Time 2023-04-28T14:37:11
# ...
# Episode 2189 - tiger - Step 4575694 - Epsilon 0.3185666246883958 - Mean Reward 64.72 - Mean Length 2011.2 - Mean Loss 0.01 - Mean Q Value 0.413 - Time Delta 34.231 - Time 2023-04-29T11:21:54
# Episode 2190 - tiger - Step 4578298 - Epsilon 0.3183593052795697 - Mean Reward 65.51 - Mean Length 2037.24 - Mean Loss 0.011 - Mean Q Value 0.419 - Time Delta 32.564 - Time 2023-04-29T11:22:26
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_229.chkpt at step 11450000
# Episode 2191 - deer - Step 11453129 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 4869.62 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 185.439 - Time 2023-04-29T11:23:21
# Episode 2192 - deer - Step 11469211 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5030.44 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 50.225 - Time 2023-04-29T11:24:11
# Episode 2193 - tiger - Step 4581053 - Epsilon 0.31814011077440096 - Mean Reward 63.78 - Mean Length 1981.87 - Mean Loss 0.01 - Mean Q Value 0.407 - Time Delta 133.372 - Time 2023-04-29T11:24:40
# Episode 2194 - tiger - Step 4584429 - Epsilon 0.3178717137667899 - Mean Reward 64.0 - Mean Length 1985.98 - Mean Loss 0.01 - Mean Q Value 0.407 - Time Delta 27.854 - Time 2023-04-29T11:25:08
# Episode 2195 - tiger - Step 4587268 - Epsilon 0.31764618433394615 - Mean Reward 63.97 - Mean Length 1985.21 - Mean Loss 0.01 - Mean Q Value 0.407 - Time Delta 27.998 - Time 2023-04-29T11:25:36
# Episode 2196 - tiger - Step 4589804 - Epsilon 0.31744486045429887 - Mean Reward 63.86 - Mean Length 1981.65 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 33.134 - Time 2023-04-29T11:26:09
# Episode 2197 - tiger - Step 4592715 - Epsilon 0.3172139239704086 - Mean Reward 63.77 - Mean Length 1982.4 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 28.328 - Time 2023-04-29T11:26:37
# Episode 2198 - deer - Step 11485267 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5009.49 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 195.283 - Time 2023-04-29T11:27:27
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_230.chkpt at step 11500000
# Episode 2199 - deer - Step 11502569 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5036.27 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 52.735 - Time 2023-04-29T11:28:19
# Episode 2200 - tiger - Step 4595624 - Epsilon 0.31698331398106494 - Mean Reward 63.95 - Mean Length 1986.35 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 129.743 - Time 2023-04-29T11:28:47
# Episode 2201 - tiger - Step 4598677 - Epsilon 0.3167414687423341 - Mean Reward 64.01 - Mean Length 1984.1 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 28.732 - Time 2023-04-29T11:29:15
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_92.chkpt at step 4600000
# Episode 2202 - tiger - Step 4601416 - Epsilon 0.31652465423481874 - Mean Reward 64.0 - Mean Length 1982.54 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 30.569 - Time 2023-04-29T11:29:46
# Episode 2203 - tiger - Step 4604581 - Epsilon 0.31627430312904375 - Mean Reward 64.0 - Mean Length 1983.46 - Mean Loss 0.01 - Mean Q Value 0.406 - Time Delta 31.963 - Time 2023-04-29T11:30:18
# Episode 2204 - deer - Step 11520811 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5067.21 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 175.772 - Time 2023-04-29T11:31:15
# Episode 2205 - tiger - Step 4607686 - Epsilon 0.31602889043365545 - Mean Reward 65.0 - Mean Length 2014.51 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 86.857 - Time 2023-04-29T11:31:45
# Episode 2206 - tiger - Step 4610316 - Epsilon 0.31582116970787344 - Mean Reward 64.82 - Mean Length 2012.47 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 31.09 - Time 2023-04-29T11:32:16
# Episode 2207 - tiger - Step 4613344 - Epsilon 0.3155821835201816 - Mean Reward 64.82 - Mean Length 2011.89 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 30.678 - Time 2023-04-29T11:32:47
# Episode 2208 - tiger - Step 4616297 - Epsilon 0.3153492909211116 - Mean Reward 64.6 - Mean Length 2009.68 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 31.908 - Time 2023-04-29T11:33:19
# Episode 2209 - deer - Step 11539208 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5083.92 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 179.09 - Time 2023-04-29T11:34:14
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_231.chkpt at step 11550000
# Episode 2210 - deer - Step 11553799 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5080.07 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 46.629 - Time 2023-04-29T11:35:01
# Episode 2211 - tiger - Step 4618841 - Epsilon 0.31514879251224975 - Mean Reward 64.55 - Mean Length 2007.28 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 135.804 - Time 2023-04-29T11:35:34
# Episode 2212 - tiger - Step 4621604 - Epsilon 0.31493117862363923 - Mean Reward 64.36 - Mean Length 2002.61 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 32.194 - Time 2023-04-29T11:36:07
# Episode 2213 - tiger - Step 4624189 - Epsilon 0.31472772007361854 - Mean Reward 64.25 - Mean Length 2003.01 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 34.107 - Time 2023-04-29T11:36:41
# Episode 2214 - tiger - Step 4626902 - Epsilon 0.3145143283454249 - Mean Reward 63.99 - Mean Length 1998.04 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 33.131 - Time 2023-04-29T11:37:14
# Episode 2215 - deer - Step 11570688 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5063.47 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 184.977 - Time 2023-04-29T11:38:06
# Episode 2216 - deer - Step 11588149 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5053.41 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 54.347 - Time 2023-04-29T11:39:00
# Episode 2217 - tiger - Step 4629747 - Epsilon 0.31429070953527044 - Mean Reward 64.04 - Mean Length 1999.23 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 134.984 - Time 2023-04-29T11:39:29
# Episode 2218 - tiger - Step 4632840 - Epsilon 0.31404777814917345 - Mean Reward 63.99 - Mean Length 1998.95 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 31.522 - Time 2023-04-29T11:40:00
# Episode 2219 - tiger - Step 4635855 - Epsilon 0.3138111537957885 - Mean Reward 64.02 - Mean Length 1999.84 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 32.355 - Time 2023-04-29T11:40:33
# Episode 2220 - tiger - Step 4638763 - Epsilon 0.31358309596750483 - Mean Reward 64.11 - Mean Length 1995.86 - Mean Loss 0.011 - Mean Q Value 0.412 - Time Delta 24.747 - Time 2023-04-29T11:40:57
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_232.chkpt at step 11600000
# Episode 2221 - deer - Step 11602522 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5027.65 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 163.037 - Time 2023-04-29T11:41:43
# Episode 2222 - deer - Step 11619075 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5038.28 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 51.857 - Time 2023-04-29T11:42:35
# Episode 2223 - tiger - Step 4641724 - Epsilon 0.31335105194756496 - Mean Reward 63.45 - Mean Length 1971.39 - Mean Loss 0.011 - Mean Q Value 0.406 - Time Delta 130.255 - Time 2023-04-29T11:43:08
# Episode 2224 - tiger - Step 4644716 - Epsilon 0.3131167529701292 - Mean Reward 63.54 - Mean Length 1975.6 - Mean Loss 0.011 - Mean Q Value 0.406 - Time Delta 33.169 - Time 2023-04-29T11:43:41
# Episode 2225 - tiger - Step 4647625 - Epsilon 0.31288912156554866 - Mean Reward 63.55 - Mean Length 1977.65 - Mean Loss 0.011 - Mean Q Value 0.405 - Time Delta 28.992 - Time 2023-04-29T11:44:10
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_93.chkpt at step 4650000
# Episode 2226 - tiger - Step 4650292 - Epsilon 0.3126805722505013 - Mean Reward 63.56 - Mean Length 1976.14 - Mean Loss 0.011 - Mean Q Value 0.405 - Time Delta 30.074 - Time 2023-04-29T11:44:40
# Episode 2227 - deer - Step 11642827 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5054.51 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 197.93 - Time 2023-04-29T11:45:53
# Episode 2228 - tiger - Step 4652332 - Epsilon 0.3125211457959056 - Mean Reward 64.2 - Mean Length 1996.54 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 103.608 - Time 2023-04-29T11:46:23
# Episode 2229 - tiger - Step 4654946 - Epsilon 0.31231697992004454 - Mean Reward 64.03 - Mean Length 1993.99 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 34.469 - Time 2023-04-29T11:46:58
# Episode 2230 - tiger - Step 4657192 - Epsilon 0.31214166313867303 - Mean Reward 63.8 - Mean Length 1986.82 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 25.687 - Time 2023-04-29T11:47:24
# Episode 2231 - tiger - Step 4660111 - Epsilon 0.31191396082448924 - Mean Reward 63.95 - Mean Length 1989.56 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 29.953 - Time 2023-04-29T11:47:54
# Episode 2232 - tiger - Step 4662404 - Epsilon 0.3117352073641843 - Mean Reward 63.59 - Mean Length 1985.0 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 35.249 - Time 2023-04-29T11:48:29
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_233.chkpt at step 11650000
# Episode 2233 - deer - Step 11662290 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5052.39 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 215.957 - Time 2023-04-29T11:49:29
# Episode 2234 - deer - Step 11681772 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5055.83 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 60.588 - Time 2023-04-29T11:50:30
# Episode 2235 - tiger - Step 4665092 - Epsilon 0.3115257916501895 - Mean Reward 62.57 - Mean Length 1951.82 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 150.126 - Time 2023-04-29T11:50:59
# Episode 2236 - tiger - Step 4667861 - Epsilon 0.31131021251987767 - Mean Reward 62.62 - Mean Length 1952.97 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 33.449 - Time 2023-04-29T11:51:32
# Episode 2237 - tiger - Step 4670485 - Epsilon 0.31110605996427715 - Mean Reward 62.79 - Mean Length 1954.18 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 30.84 - Time 2023-04-29T11:52:03
# Episode 2238 - tiger - Step 4673427 - Epsilon 0.31087732555593955 - Mean Reward 63.26 - Mean Length 1963.2 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 29.914 - Time 2023-04-29T11:52:33
# Episode 2239 - tiger - Step 4676334 - Epsilon 0.3106514775088051 - Mean Reward 64.16 - Mean Length 1992.27 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 30.648 - Time 2023-04-29T11:53:04
# Episode 2240 - deer - Step 11698423 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 4866.98 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 206.126 - Time 2023-04-29T11:53:56
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_234.chkpt at step 11700000
# Episode 2241 - deer - Step 11714770 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5030.45 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 50.94 - Time 2023-04-29T11:54:47
# Episode 2242 - tiger - Step 4678952 - Epsilon 0.3104482226137601 - Mean Reward 63.41 - Mean Length 1967.12 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 134.659 - Time 2023-04-29T11:55:18
# Episode 2243 - tiger - Step 4681526 - Epsilon 0.3102485134208408 - Mean Reward 63.59 - Mean Length 1967.24 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 27.02 - Time 2023-04-29T11:55:45
# Episode 2244 - tiger - Step 4683798 - Epsilon 0.31007234228051217 - Mean Reward 63.67 - Mean Length 1967.53 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 34.211 - Time 2023-04-29T11:56:20
# Episode 2245 - tiger - Step 4686615 - Epsilon 0.3098540506810958 - Mean Reward 63.71 - Mean Length 1969.92 - Mean Loss 0.011 - Mean Q Value 0.403 - Time Delta 34.314 - Time 2023-04-29T11:56:54
# Episode 2246 - deer - Step 11732340 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5020.24 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 181.139 - Time 2023-04-29T11:57:48
# Episode 2247 - tiger - Step 4689326 - Epsilon 0.30964411822087384 - Mean Reward 64.65 - Mean Length 1997.03 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 82.664 - Time 2023-04-29T11:58:17
# Episode 2248 - tiger - Step 4692033 - Epsilon 0.30943463742871163 - Mean Reward 64.44 - Mean Length 1996.19 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 34.167 - Time 2023-04-29T11:58:51
# Episode 2249 - tiger - Step 4694776 - Epsilon 0.30922251533922357 - Mean Reward 64.4 - Mean Length 1994.48 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 30.048 - Time 2023-04-29T11:59:21
# Episode 2250 - tiger - Step 4697444 - Epsilon 0.30901633266525674 - Mean Reward 64.37 - Mean Length 1992.74 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 31.314 - Time 2023-04-29T11:59:52
# Episode 2251 - tiger - Step 4699548 - Epsilon 0.3088538327951523 - Mean Reward 64.16 - Mean Length 1982.19 - Mean Loss 0.011 - Mean Q Value 0.409 - Time Delta 30.877 - Time 2023-04-29T12:00:23
# Episode 2252 - deer - Step 11747975 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 4962.92 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 204.506 - Time 2023-04-29T12:01:12
# Animal saved to deer_checkpoints\2023-04-28T12-36-43\animal_net_235.chkpt at step 11750000
# Episode 2253 - deer - Step 11765349 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5136.66 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 56.001 - Time 2023-04-29T12:02:08
# Animal saved to tiger_checkpoints\2023-04-28T12-36-43\animal_net_94.chkpt at step 4700000
# Episode 2254 - tiger - Step 4702194 - Epsilon 0.3086495935187884 - Mean Reward 62.93 - Mean Length 1948.6 - Mean Loss 0.011 - Mean Q Value 0.404 - Time Delta 139.963 - Time 2023-04-29T12:02:43
# Episode 2255 - tiger - Step 4704981 - Epsilon 0.30843461678881745 - Mean Reward 63.77 - Mean Length 1976.47 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 34.214 - Time 2023-04-29T12:03:17
# Episode 2256 - tiger - Step 4707504 - Epsilon 0.30824013297172226 - Mean Reward 63.74 - Mean Length 1974.21 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 34.744 - Time 2023-04-29T12:03:52
# Episode 2257 - tiger - Step 4710494 - Epsilon 0.3080098095376136 - Mean Reward 63.7 - Mean Length 1976.32 - Mean Loss 0.011 - Mean Q Value 0.41 - Time Delta 33.455 - Time 2023-04-29T12:04:25
# Episode 2258 - deer - Step 11782034 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 4902.25 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 191.689 - Time 2023-04-29T12:05:20
# Episode 2259 - deer - Step 11797502 - Epsilon 0.1 - Mean Reward 0.0 - Mean Length 5056.93 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 49.521 - Time 2023-04-29T12:06:10
# Episode 2260 - tiger - Step 4713286 - Epsilon 0.30779489367802304 - Mean Reward 62.65 - Mean Length 1951.03 - Mean Loss 0.011 - Mean Q Value 0.405 - Time Delta 136.597 - Time 2023-04-29T12:06:42
# Episode 2261 - tiger - Step 4716302 - Epsilon 0.30756290377034495 - Mean Reward 62.96 - Mean Length 1958.71 - Mean Loss 0.011 - Mean Q Value 0.405 - Time Delta 31.425 - Time 2023-04-29T12:07:13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm3.ipynb Cell 20 in <cell line: 11>()
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X25sZmlsZQ%3D%3D?line=112'>113</a>         animal_logger.log_step(reward, loss, q)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X25sZmlsZQ%3D%3D?line=113'>114</a>     # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
# --> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X25sZmlsZQ%3D%3D?line=114'>115</a>     action = animal.act(observation, activeAnimal)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X25sZmlsZQ%3D%3D?line=115'>116</a>     actual_action = action_mapper(action, prev_actual_action)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X25sZmlsZQ%3D%3D?line=117'>118</a> # update previous agent
#
# KeyboardInterrupt:

# %%
tiger.save_dir=Path("tiger_checkpoints") / "Basic_With_AdvReward2"
tiger.save()
deer.save_dir=Path("deer_checkpoints") / "Basic_With_AdvReward2"
deer.save()

# %% [markdown]
# ### Train LSTM Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm3.ipynb Cell 23 in <cell line: 11>()
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=104'>105</a> # if not prev_done:
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=105'>106</a> if activeAnimal:
# --> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=106'>107</a>     animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=107'>108</a>     #learn
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm3.ipynb#X31sZmlsZQ%3D%3D?line=108'>109</a>     q, loss = animal.learn()
#
# TypeError: Animal.cache() takes from 6 to 7 positional arguments but 8 were given

# %% [markdown]
# ### Visualize Trained Model

# %%
map_size=50
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 20
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# deer_save_dir=
# tiger_save_dir=
deer2 = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger2 = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

deer2.load("deer_checkpoints\\Basic_With_AdvReward2\\animal_net_161.chkpt")
tiger2.load("tiger_checkpoints\\Basic_With_AdvReward2\\animal_net_64.chkpt")
# tiger2.net.eval()
# deer2.net.eval()
# Out:
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %%
map_size=50
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 3
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger2
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer2
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation,activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm.ipynb Cell 27 in <cell line: 4>()
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=14'>15</a> for agent in env.agent_iter():
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=16'>17</a>     agentType = get_agent_type_from_agent_name(agent)
# ---> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=17'>18</a>     agent_id = agent_name_to_id(agent)
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=18'>19</a>     # print("Agent id: ", agent_id)
#      <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=20'>21</a>     observation, reward, termination, truncation, info = env.last()
#
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm.ipynb Cell 27 in agent_name_to_id(agent_name)
#       <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> def agent_name_to_id(agent_name):
#       <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a>     global agent_name_to_id_dict
# ----> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a>     return agent_name_to_id_dict[agent_name]
#
# KeyError: 'deer_125'
