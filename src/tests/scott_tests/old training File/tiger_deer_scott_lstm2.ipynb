# %%
from magent2.environments import battle_v4, adversarial_pursuit_v4, tiger_deer_v4
from pettingzoo.utils import random_demo
import torch
import time
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F
# from dqn_basic import DQN_Basic
from collections import namedtuple, deque
import numpy as np
# import matplotlib.pyplot as plt
from AnimalLSTM import Animal
# from Animal import Animal
from pathlib import Path
from collections import deque
import datetime, os
from metric_logger import MetricLogger
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
def convert_numpy_binary_to_integer(arr):
    assert len(arr.shape) == 3
    assert arr.shape[0] <= 8
    arr = arr.astype(np.int32)
    input_array_transposed = np.transpose(arr, (1, 2, 0))
    packed_array = np.packbits(input_array_transposed, axis=-1, bitorder='little').squeeze(-1)
    return packed_array

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# frame_size = (128, 128)
max_cycles = 300
# total_episodes = 50
# map_size = 30
map_size = 50

# env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', tiger_step_recover=-0.1, deer_attacked=-0.1, max_cycles=max_cycles, extra_features=False)
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='rgb_array', max_cycles=max_cycles, extra_features=True)
env.reset(seed=None)
obs_indices_to_keep = [0,1,3]

# get number of deer and tigers
number_of_deer = len([x for x in env.agents if 'deer' in x])
number_of_tigers = len([x for x in env.agents if 'tiger' in x])

UseAdventageAward=False

# set deer data
deer_observation_shape = env.observation_spaces['deer_0'].shape
deer_observation_shape = tuple(np.roll(deer_observation_shape,1))
# deer_action_space = env.action_spaces['deer_0'].n
deer_action_space = 3
deer_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['deer_0'].n, deer_observation_shape[1], deer_observation_shape[2])


# set tiger data
tiger_observation_shape = env.observation_spaces['tiger_0'].shape
tiger_observation_shape = tuple(np.roll(tiger_observation_shape,1))
# tiger_action_space = env.action_spaces['tiger_0'].n
tiger_action_space = 6
tiger_observation_shape = (len(obs_indices_to_keep)+env.action_spaces['tiger_0'].n, tiger_observation_shape[1], tiger_observation_shape[2])

# print outputs
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)
print("Deer Observations:", deer_observation_shape, "Tiger Observations:",tiger_observation_shape)
assert deer_observation_shape != None
assert tiger_observation_shape != None

# 'rgb_array' or 'human'
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Deer Observations: (8, 7, 7) Tiger Observations: (16, 10, 10)

# %% [markdown]
# ## Utility Functions

# %% [markdown]
# ### Action Mapping
# Takes the limited actions (forward, left, right) and maps to the true actions (up, left, down, right,...)

# %%
deer_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
}
def deer_action_mapper(new_unmapped_action, prev_actual_action, size_of_actions=5):
    global deer_action_mapping
    return deer_action_mapping.get(new_unmapped_action, {}).get(prev_actual_action, np.random.choice(np.delete(np.arange(0, size_of_actions), 2)))

tiger_action_mapping = {
    0: {0: 0, 1: 1, 3: 3, 4: 4},
    1: {0: 1, 1: 4, 3: 0, 4: 3},
    2: {0: 3, 1: 0, 3: 4, 4: 1},
    3: {0: 5, 1: 6, 3: 7, 4: 8},
    4: {0: 6, 1: 8, 3: 5, 4: 7},
    5: {0: 7, 1: 5, 3: 8, 4: 6},
}

tiger_direction_mapping = {
    0: 0,
    1: 1,
    3: 3,
    4: 4,
    5: 0,
    6: 1,
    7: 3,
    8: 4,
}

def tiger_action_mapper(new_action, prev_action, size_of_actions=5): # slower
    global tiger_action_mapping, tiger_direction_mapping
    direction = tiger_direction_mapping.get(prev_action, 0)
    return tiger_action_mapping.get(new_action, {}).get(direction, 0)

def mask_observations(observations, prev_actual_action):
    current_position = (observations.shape[1] // 2, observations.shape[2] // 2)
    direction = tiger_direction_mapping.get(prev_actual_action, 0)
    # print(observations)
    if direction == 1:  # Up
        observations[:, current_position[0]:, :] = 0 # actually_left
    elif direction == 0:  # Left
        observations[:, :, current_position[1]:] = 0
    elif direction == 4:  # Right
        observations[:, :, :current_position[1]] = 0
    elif direction == 3:  # Down
        observations[:, :current_position[0]+1, :] = 0 # actually right
    else:
        raise ValueError("Direction mapping issue for mask observations")
    # print("direction: ", direction, " observations: ", observations)

# %%
def get_agent_type_from_agent_name(agent):
    if 'tiger' in agent:
        return 'tiger'
    return 'deer'

# %%
def generate_first_action(agentType):
    if 'tiger' in agentType:
        # action = np.random.randint(0,tiger_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 6))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 9), 2))
        actual_action = tiger_action_mapper(action, previous_actual_action)
    else:
        # action = np.random.randint(0,deer_action_space,(1,))[0]
        action = np.random.choice(np.arange(0, 3))
        previous_actual_action = np.random.choice(np.delete(np.arange(0, 5), 2))
        actual_action = deer_action_mapper(action, previous_actual_action)
    
    return action, actual_action, previous_actual_action

# %%
def change_active_model(activeDeer, activeTiger, deerCurrentSteps, tigerCurrentSteps, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger):
    if deerCurrentSteps >= total_steps_deer:
        return False, True
    if tigerCurrentSteps >= total_steps_tiger:
        return True, False
    if deerCurrentSteps//steps_to_switch_at_deer < tigerCurrentSteps//steps_to_switch_at_tiger:
        # if not activeDeer:
        #     print("Switching to Deer")
        return True, False
    if tigerCurrentSteps//steps_to_switch_at_tiger < deerCurrentSteps//steps_to_switch_at_deer:
        # if not activeTiger:
        #     print("Switching to Tiger")
        return False, True
    return activeDeer, activeTiger

# %%
def custom_reward_modifier(agentType, observation, prev_actual_action, reward, start_index_one_hot=3):
    global UseAdventageAward
    if not UseAdventageAward:
        return reward
    if 'deer' not in agentType:
        return reward
    
    #############################################################
    # alignment reward
    alignment_reward = 0.005
    action_array = observation[prev_actual_action+start_index_one_hot]
    _, K, _ = observation.shape
    center = K//2
    # Assuming 'center' is the index of the center of the (K,K) section
    center_coords = np.array([center // K, center % K])
    coords = np.indices((K,K)).reshape(2,-1).T
    distances = np.linalg.norm(coords - center_coords, axis=1)
    # distances = distances
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    # Sum the values and print the result
    alignement_result = np.sum(values[np.isfinite(values)])
    alignement_result *= alignment_reward
    #############################################################
    # wall_penalty
    wall_penalty = -0.01
    action_array = observation[0]
    values = action_array.flatten()[distances >= 0.001] / distances[distances >= 0.001]
    wall_result = np.sum(values[np.isfinite(values)])
    wall_result *= wall_penalty

    return reward + alignement_result + wall_result

# %%
agent_name_to_id_dict = {str(name): index for index,name in enumerate(env.agents)}
agent_id_to_name_list = [x for x in env.agents]
def agent_name_to_id(agent_name):
    global agent_name_to_id_dict
    return agent_name_to_id_dict[agent_name]

def agent_id_to_name(id):
    global agent_id_to_name_list
    return agent_id_to_name_list[id]

# %% [markdown]
# One hot actions takes the observed actions of nearby agents and converts them to one hot actions in the observed numpy array

# %%
import numpy as np

def one_hot_actions(array, num_actions):
    # Get the shape of the input array
    K, K = array.shape

    # Create an empty output array filled with zeros
    output = np.zeros((num_actions, K, K))

    # Iterate over the range of num_actions
    for action in range(num_actions):
        # Set the corresponding elements to 1 based on the original array
        output[action, :, :] = (array == action)

    return output

# %%
import numpy as np

def get_subsection_of_env_map(array, position, size=(13, 13)):
    # Get the shape of the input array
    array_shape = array.shape

    # Create an empty output array filled with -1
    output_size = [array.shape[0]]
    output_size.extend(list(size))
    output = np.full(tuple(output_size), -1)

    # Calculate the start and end indices for the subsection
    start_row = int(position[0] - size[0] // 2)
    end_row = int(start_row + size[0])
    start_col = int(position[1] - size[1] // 2)
    end_col = int(start_col + size[1])

    # Calculate the slices for the input array and output array
    slice_row_in = slice(max(start_row, 0), min(end_row, array_shape[1]))
    slice_col_in = slice(max(start_col, 0), min(end_col, array_shape[2]))

    slice_row_out = slice(max(-start_row, 0), min(array_shape[1] - start_row, size[0]))
    slice_col_out = slice(max(-start_col, 0), min(array_shape[2] - start_col, size[1]))

    # Copy the subsection from the input array to the output array
    output[:,slice_row_out, slice_col_out] = array[:,slice_row_in, slice_col_in]

    return output

# # Example usage
# array = np.random.randint(0, 100, (2, 20, 20))
# position = (19, 0)
# sub_array = get_subsection_of_env_map(array, position, size=(11, 11))

# print(sub_array)

# %% [markdown]
# Cleans up observations by removing unncessary layers, and one hot actions.

# %%
def handle_observations(observation, obs_indices_to_keep, agent_id, env_map, num_actions):
    observation = np.transpose(observation, (2,0,1))
    observation_size = observation.shape[1]
    observation = observation[obs_indices_to_keep,:,:]
    # print(observation.shape)
    position = np.where(env_map[0,:,:] == agent_id)
    # print("Position", position)

    sub_env_map = get_subsection_of_env_map(env_map, position, size=(observation_size, observation_size))
    one_hot_actions_arr = one_hot_actions(sub_env_map[1,:,:], num_actions)
    observation = np.concatenate((observation, one_hot_actions_arr), axis=0, dtype=np.float32)
    return observation

# %% [markdown]
# ## Train Model
# ### Make Models and Loggers

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

deer_save_dir = Path("deer_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
deer_save_dir.mkdir(parents=True)

tiger_save_dir = Path("tiger_checkpoints") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
tiger_save_dir.mkdir(parents=True)



deer = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

# deer.load("deer_checkpoints\\2023-04-26T22-43-08\\animal_net_8.chkpt")
# tiger.load("tiger_checkpoints\\2023-04-26T22-43-08\\animal_net_2.chkpt")

deer_logger = MetricLogger(deer_save_dir, animal='deer')
tiger_logger = MetricLogger(tiger_save_dir, animal='tiger')


# active training flags
activeDeer = True
activeTiger = False


# Switch the training set
switching = True
steps_to_switch_at_deer = 15000
steps_to_switch_at_tiger = int((steps_to_switch_at_deer*2)//5)
total_steps_deer = 800000000
total_steps_tiger = int((total_steps_deer//3))

# divide steps to switch at to actually switch at the proper requested switching steps
# steps_to_switch_at = steps_to_switch_at//2
# if switching enabled, make sure no equivalence between active variables
if switching:
    if activeDeer == activeTiger:
        activeTiger = not activeTiger
# Out:
# Using CUDA: True
# c:\Users\mike\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# ### Train Basic Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            # prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            prev_observation, prev_action, prev_done, prev_actual_action = agents_prev_data[agent][0:4]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                # animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                animal.cache(prev_observation, observation, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            # action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            action = animal.act(observation, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        # agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]
        agents_prev_data[agent] = [observation, action, done, actual_action, reward, info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\tiger_deer_scott_lstm2.ipynb Cell 20 in <cell line: 11>()
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=105'>106</a> # if not prev_done:
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=106'>107</a> if activeAnimal:
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=107'>108</a>     # animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
# --> <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=108'>109</a>     animal.cache(prev_observation, observation, prev_action, reward, done)
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=109'>110</a>     #learn
#     <a href='vscode-notebook-cell:/d%3A/TempSync/CS7643/The-Learning-Shoal/src/tests/scott_tests/tiger_deer_scott_lstm2.ipynb#X25sZmlsZQ%3D%3D?line=110'>111</a>     q, loss = animal.learn()
#
# TypeError: Animal.cache() missing 2 required positional arguments: 'reward' and 'done'

# %% [markdown]
# ### Train LSTM Model

# %%
print("Number of Tigers:", number_of_tigers)
print("Number of Deer:",number_of_deer)

env.reset(seed=None)

actual_tiger_actions = env.action_spaces['tiger_0'].n
actual_deer_actions = env.action_spaces['deer_0'].n

indexOfFirstTiger = [index for index, x in enumerate(env.agents) if 'tiger' in x][0]
e = -1
while deer.curr_step < total_steps_deer or tiger.curr_step < total_steps_tiger:
    e = e + 1
# for e in range(total_episodes):
    # print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        animal_logger = None
        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            animal_logger = tiger_logger
            action_mapper = tiger_action_mapper
            activeAnimal = activeTiger
            num_actions = tiger_action_space
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            animal_logger = deer_logger
            action_mapper = deer_action_mapper
            activeAnimal = activeDeer
            num_actions = deer_action_space
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            prev_observation, prev_action, prev_done, prev_actual_action, hidden, cell = agents_prev_data[agent][0:6]
            reward = custom_reward_modifier(agentType, observation, prev_actual_action, reward)
            mask_observations(observation, prev_actual_action)
            
            
            # if not prev_done:
            if activeAnimal:
                animal.cache(prev_observation, observation, hidden, cell, prev_action, reward, done)
                #learn
                q, loss = animal.learn()
                # logging
                animal_logger.log_step(reward, loss, q)
            action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]

        # step the function to next agent
        env.step(actual_action)
        

    deer_logger.log_episode()
    tiger_logger.log_episode()

    # if e % 5 == 0:
    if activeDeer:
        # print("Deer - Min Possible Reward ", -number_of_deer)
        deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
    if activeTiger:
        # print("Tiger - Max Possible Reward ", number_of_deer)
        tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)
    if switching:
        activeDeer, activeTiger = change_active_model(activeDeer, activeTiger, deer.curr_step, tiger.curr_step, steps_to_switch_at_deer, steps_to_switch_at_tiger, total_steps_deer, total_steps_tiger)

# log last episode
deer_logger.record(episode=e, epsilon=deer.exploration_rate, step=deer.curr_step)
tiger_logger.record(episode=e, epsilon=tiger.exploration_rate, step=tiger.curr_step)

#4355 LSTM with no adv reward
# Out:
# Number of Tigers: 12
# Number of Deer: 125
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_0.chkpt at step 0
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\AnimalLSTM.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   hidden = torch.tensor(hidden, device=self.device) #.unsqueeze(0)
# d:\TempSync\CS7643\The-Learning-Shoal\src\tests\scott_tests\AnimalLSTM.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cell = torch.tensor(cell, device=self.device) #.unsqueeze(0)
# Episode 0 - deer - Step 27299 - Epsilon 0.99319848486867 - Mean Reward 0.0 - Mean Length 27299.0 - Mean Loss 0.0 - Mean Q Value 0.038 - Time Delta 98.957 - Time 2023-04-29T20:45:36
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_0.chkpt at step 0
# Episode 1 - tiger - Step 2785 - Epsilon 0.9993039922387199 - Mean Reward 25.5 - Mean Length 1392.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 146.88 - Time 2023-04-29T20:46:24
# Episode 2 - tiger - Step 5262 - Epsilon 0.9986853647264244 - Mean Reward 32.667 - Mean Length 1754.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 48.83 - Time 2023-04-29T20:47:13
# Episode 3 - tiger - Step 7456 - Epsilon 0.9981377359362652 - Mean Reward 32.75 - Mean Length 1864.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 52.733 - Time 2023-04-29T20:48:06
# Episode 4 - tiger - Step 9765 - Epsilon 0.9975617271226509 - Mean Reward 35.0 - Mean Length 1953.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 52.673 - Time 2023-04-29T20:48:59
# Episode 5 - tiger - Step 11997 - Epsilon 0.9970052428828212 - Mean Reward 35.167 - Mean Length 1999.5 - Mean Loss 0.002 - Mean Q Value 0.005 - Time Delta 57.144 - Time 2023-04-29T20:49:56
# Episode 6 - tiger - Step 14193 - Epsilon 0.9964580371577165 - Mean Reward 35.429 - Mean Length 2027.571 - Mean Loss 0.003 - Mean Q Value 0.011 - Time Delta 62.335 - Time 2023-04-29T20:50:58
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_1.chkpt at step 50000
# Episode 7 - deer - Step 57905 - Epsilon 0.9856280253345203 - Mean Reward 0.0 - Mean Length 7238.125 - Mean Loss 0.0 - Mean Q Value 0.01 - Time Delta 459.275 - Time 2023-04-29T20:53:16
# Episode 8 - tiger - Step 17134 - Epsilon 0.9957256605671839 - Mean Reward 33.333 - Mean Length 1903.778 - Mean Loss 0.003 - Mean Q Value 0.011 - Time Delta 193.623 - Time 2023-04-29T20:54:12
# Episode 9 - tiger - Step 19902 - Epsilon 0.9950368566775071 - Mean Reward 34.2 - Mean Length 1990.2 - Mean Loss 0.003 - Mean Q Value 0.013 - Time Delta 58.874 - Time 2023-04-29T20:55:11
# Episode 10 - tiger - Step 22137 - Epsilon 0.9944810350614077 - Mean Reward 34.909 - Mean Length 2012.455 - Mean Loss 0.004 - Mean Q Value 0.019 - Time Delta 55.369 - Time 2023-04-29T20:56:06
# Episode 11 - tiger - Step 24680 - Epsilon 0.9938489945954238 - Mean Reward 36.667 - Mean Length 2056.667 - Mean Loss 0.005 - Mean Q Value 0.025 - Time Delta 53.849 - Time 2023-04-29T20:57:00
# Episode 12 - deer - Step 87093 - Epsilon 0.9784620735087753 - Mean Reward 0.0 - Mean Length 6699.462 - Mean Loss 0.0 - Mean Q Value 0.008 - Time Delta 346.632 - Time 2023-04-29T20:59:02
# Episode 13 - tiger - Step 27426 - Epsilon 0.9931669513134274 - Mean Reward 34.429 - Mean Length 1959.0 - Mean Loss 0.005 - Mean Q Value 0.028 - Time Delta 182.336 - Time 2023-04-29T21:00:02
# Episode 14 - tiger - Step 29777 - Epsilon 0.992583388875978 - Mean Reward 34.467 - Mean Length 1985.133 - Mean Loss 0.006 - Mean Q Value 0.032 - Time Delta 59.495 - Time 2023-04-29T21:01:02
# Episode 15 - tiger - Step 32626 - Epsilon 0.9918766729778868 - Mean Reward 35.375 - Mean Length 2039.125 - Mean Loss 0.006 - Mean Q Value 0.04 - Time Delta 58.818 - Time 2023-04-29T21:02:00
# Episode 16 - tiger - Step 34639 - Epsilon 0.9913776365603318 - Mean Reward 35.176 - Mean Length 2037.588 - Mean Loss 0.007 - Mean Q Value 0.047 - Time Delta 57.969 - Time 2023-04-29T21:02:58
# Episode 17 - tiger - Step 37459 - Epsilon 0.9906789615509987 - Mean Reward 36.278 - Mean Length 2081.056 - Mean Loss 0.007 - Mean Q Value 0.053 - Time Delta 55.061 - Time 2023-04-29T21:03:53
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_2.chkpt at step 100000
# Episode 18 - deer - Step 113004 - Epsilon 0.9721443245124918 - Mean Reward 0.0 - Mean Length 5947.579 - Mean Loss 0.0 - Mean Q Value 0.007 - Time Delta 401.463 - Time 2023-04-29T21:05:44
# Episode 19 - tiger - Step 39984 - Epsilon 0.9900537927179591 - Mean Reward 34.85 - Mean Length 1999.2 - Mean Loss 0.007 - Mean Q Value 0.056 - Time Delta 168.265 - Time 2023-04-29T21:06:42
# Episode 20 - tiger - Step 42553 - Epsilon 0.9894181347375545 - Mean Reward 35.286 - Mean Length 2026.333 - Mean Loss 0.008 - Mean Q Value 0.064 - Time Delta 57.602 - Time 2023-04-29T21:07:39
# Episode 21 - tiger - Step 45165 - Epsilon 0.9887722555172626 - Mean Reward 35.864 - Mean Length 2052.955 - Mean Loss 0.008 - Mean Q Value 0.071 - Time Delta 57.411 - Time 2023-04-29T21:08:37
# Episode 22 - tiger - Step 47930 - Epsilon 0.9880890027865665 - Mean Reward 36.522 - Mean Length 2083.913 - Mean Loss 0.008 - Mean Q Value 0.077 - Time Delta 54.803 - Time 2023-04-29T21:09:32
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_1.chkpt at step 50000
# Episode 23 - tiger - Step 51009 - Epsilon 0.9873287138352814 - Mean Reward 37.667 - Mean Length 2125.375 - Mean Loss 0.009 - Mean Q Value 0.084 - Time Delta 53.865 - Time 2023-04-29T21:10:25
# Episode 24 - deer - Step 137004 - Epsilon 0.9663289214929339 - Mean Reward 0.0 - Mean Length 5480.16 - Mean Loss 0.0 - Mean Q Value 0.006 - Time Delta 384.959 - Time 2023-04-29T21:12:09
# Episode 25 - tiger - Step 53277 - Epsilon 0.98676905706219 - Mean Reward 36.385 - Mean Length 2049.115 - Mean Loss 0.009 - Mean Q Value 0.089 - Time Delta 158.831 - Time 2023-04-29T21:13:04
# Episode 26 - tiger - Step 55952 - Epsilon 0.9861093757782413 - Mean Reward 36.63 - Mean Length 2072.296 - Mean Loss 0.009 - Mean Q Value 0.098 - Time Delta 57.888 - Time 2023-04-29T21:14:02
# Episode 27 - tiger - Step 58499 - Epsilon 0.9854816704215645 - Mean Reward 37.0 - Mean Length 2089.25 - Mean Loss 0.009 - Mean Q Value 0.105 - Time Delta 55.904 - Time 2023-04-29T21:14:58
# Episode 28 - tiger - Step 60894 - Epsilon 0.9848917898107131 - Mean Reward 37.483 - Mean Length 2099.793 - Mean Loss 0.009 - Mean Q Value 0.114 - Time Delta 54.612 - Time 2023-04-29T21:15:53
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_3.chkpt at step 150000
# Episode 29 - deer - Step 164052 - Epsilon 0.9598166473240866 - Mean Reward 0.0 - Mean Length 5468.4 - Mean Loss 0.0 - Mean Q Value 0.005 - Time Delta 335.434 - Time 2023-04-29T21:17:44
# Episode 30 - deer - Step 192474 - Epsilon 0.9530208416768848 - Mean Reward 0.0 - Mean Length 6208.839 - Mean Loss 0.0 - Mean Q Value 0.005 - Time Delta 115.383 - Time 2023-04-29T21:19:40
# Episode 31 - tiger - Step 63940 - Epsilon 0.984142080107153 - Mean Reward 35.594 - Mean Length 1998.125 - Mean Loss 0.009 - Mean Q Value 0.117 - Time Delta 282.939 - Time 2023-04-29T21:20:36
# Episode 32 - tiger - Step 66126 - Epsilon 0.9836043933293842 - Mean Reward 35.848 - Mean Length 2003.818 - Mean Loss 0.009 - Mean Q Value 0.126 - Time Delta 54.09 - Time 2023-04-29T21:21:30
# Episode 33 - tiger - Step 68316 - Epsilon 0.9830660172505653 - Mean Reward 36.059 - Mean Length 2009.294 - Mean Loss 0.01 - Mean Q Value 0.135 - Time Delta 54.585 - Time 2023-04-29T21:22:24
# Episode 34 - tiger - Step 71111 - Epsilon 0.9823793397209813 - Mean Reward 36.743 - Mean Length 2031.743 - Mean Loss 0.01 - Mean Q Value 0.144 - Time Delta 53.617 - Time 2023-04-29T21:23:18
# Episode 35 - tiger - Step 73435 - Epsilon 0.9818087430275918 - Mean Reward 36.833 - Mean Length 2039.861 - Mean Loss 0.011 - Mean Q Value 0.156 - Time Delta 57.159 - Time 2023-04-29T21:24:15
# Episode 36 - tiger - Step 76096 - Epsilon 0.9811558118848865 - Mean Reward 37.297 - Mean Length 2056.649 - Mean Loss 0.011 - Mean Q Value 0.166 - Time Delta 55.609 - Time 2023-04-29T21:25:11
# Episode 37 - tiger - Step 78418 - Epsilon 0.9805864161479347 - Mean Reward 37.368 - Mean Length 2063.632 - Mean Loss 0.011 - Mean Q Value 0.176 - Time Delta 57.101 - Time 2023-04-29T21:26:08
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_4.chkpt at step 200000
# Episode 38 - deer - Step 217590 - Epsilon 0.9470555706327491 - Mean Reward 0.0 - Mean Length 5579.231 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 492.076 - Time 2023-04-29T21:27:52
# Episode 39 - tiger - Step 80903 - Epsilon 0.9799774159509665 - Mean Reward 36.6 - Mean Length 2022.575 - Mean Loss 0.011 - Mean Q Value 0.181 - Time Delta 157.604 - Time 2023-04-29T21:28:45
# Episode 40 - tiger - Step 83052 - Epsilon 0.9794510644222184 - Mean Reward 36.463 - Mean Length 2025.659 - Mean Loss 0.012 - Mean Q Value 0.191 - Time Delta 59.614 - Time 2023-04-29T21:29:45
# Episode 41 - tiger - Step 85569 - Epsilon 0.9788349386317357 - Mean Reward 36.571 - Mean Length 2037.357 - Mean Loss 0.012 - Mean Q Value 0.201 - Time Delta 56.904 - Time 2023-04-29T21:30:42
# Episode 42 - tiger - Step 88418 - Epsilon 0.9781380115820926 - Mean Reward 36.907 - Mean Length 2056.233 - Mean Loss 0.012 - Mean Q Value 0.209 - Time Delta 57.023 - Time 2023-04-29T21:31:39
# Episode 43 - tiger - Step 91168 - Epsilon 0.9774657727235914 - Mean Reward 37.159 - Mean Length 2072.0 - Mean Loss 0.012 - Mean Q Value 0.218 - Time Delta 58.285 - Time 2023-04-29T21:32:37
# Episode 44 - deer - Step 245758 - Epsilon 0.9404098315832734 - Mean Reward 0.0 - Mean Length 5461.289 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 402.795 - Time 2023-04-29T21:34:34
# Episode 45 - tiger - Step 93586 - Epsilon 0.9768750731469973 - Mean Reward 36.457 - Mean Length 2034.478 - Mean Loss 0.012 - Mean Q Value 0.223 - Time Delta 174.057 - Time 2023-04-29T21:35:31
# Episode 46 - tiger - Step 96494 - Epsilon 0.976165142970866 - Mean Reward 37.085 - Mean Length 2053.064 - Mean Loss 0.012 - Mean Q Value 0.231 - Time Delta 50.779 - Time 2023-04-29T21:36:22
# Episode 47 - tiger - Step 99148 - Epsilon 0.9755176721396809 - Mean Reward 37.292 - Mean Length 2065.583 - Mean Loss 0.013 - Mean Q Value 0.24 - Time Delta 55.325 - Time 2023-04-29T21:37:17
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_2.chkpt at step 100000
# Episode 48 - tiger - Step 101692 - Epsilon 0.9748974400772894 - Mean Reward 37.347 - Mean Length 2075.347 - Mean Loss 0.013 - Mean Q Value 0.249 - Time Delta 58.02 - Time 2023-04-29T21:38:15
# Episode 49 - tiger - Step 103949 - Epsilon 0.9743475092917199 - Mean Reward 37.42 - Mean Length 2078.98 - Mean Loss 0.013 - Mean Q Value 0.258 - Time Delta 55.363 - Time 2023-04-29T21:39:11
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_5.chkpt at step 250000
# Episode 50 - deer - Step 272753 - Epsilon 0.9340846076256074 - Mean Reward 0.0 - Mean Length 5348.098 - Mean Loss 0.0 - Mean Q Value 0.004 - Time Delta 391.695 - Time 2023-04-29T21:41:06
# Episode 51 - tiger - Step 106515 - Epsilon 0.9737226657263195 - Mean Reward 37.0 - Mean Length 2048.365 - Mean Loss 0.013 - Mean Q Value 0.261 - Time Delta 168.023 - Time 2023-04-29T21:41:59
# Episode 52 - tiger - Step 109720 - Epsilon 0.9729427828251243 - Mean Reward 37.415 - Mean Length 2070.189 - Mean Loss 0.013 - Mean Q Value 0.269 - Time Delta 56.098 - Time 2023-04-29T21:42:55
# Episode 53 - tiger - Step 111885 - Epsilon 0.9724163199649024 - Mean Reward 37.537 - Mean Length 2071.944 - Mean Loss 0.014 - Mean Q Value 0.278 - Time Delta 53.152 - Time 2023-04-29T21:43:48
# Episode 54 - tiger - Step 114451 - Epsilon 0.9717927148603296 - Mean Reward 37.6 - Mean Length 2080.927 - Mean Loss 0.014 - Mean Q Value 0.286 - Time Delta 56.23 - Time 2023-04-29T21:44:44
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_6.chkpt at step 300000
# Episode 55 - deer - Step 300958 - Epsilon 0.9275213096362088 - Mean Reward 0.0 - Mean Length 5374.25 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 333.399 - Time 2023-04-29T21:46:40
# Episode 56 - tiger - Step 116841 - Epsilon 0.9712122420740771 - Mean Reward 36.93 - Mean Length 2049.842 - Mean Loss 0.014 - Mean Q Value 0.289 - Time Delta 173.165 - Time 2023-04-29T21:47:37
# Episode 57 - tiger - Step 119093 - Epsilon 0.9706656034066069 - Mean Reward 36.914 - Mean Length 2053.328 - Mean Loss 0.014 - Mean Q Value 0.296 - Time Delta 56.746 - Time 2023-04-29T21:48:34
# Episode 58 - tiger - Step 121604 - Epsilon 0.9700564592129779 - Mean Reward 37.068 - Mean Length 2061.085 - Mean Loss 0.014 - Mean Q Value 0.305 - Time Delta 55.521 - Time 2023-04-29T21:49:30
# Episode 59 - tiger - Step 124109 - Epsilon 0.9694491514624811 - Mean Reward 37.233 - Mean Length 2068.483 - Mean Loss 0.014 - Mean Q Value 0.313 - Time Delta 55.853 - Time 2023-04-29T21:50:26
# Episode 60 - tiger - Step 126656 - Epsilon 0.9688320511282339 - Mean Reward 37.557 - Mean Length 2076.328 - Mean Loss 0.014 - Mean Q Value 0.321 - Time Delta 51.911 - Time 2023-04-29T21:51:17
# Episode 61 - deer - Step 327925 - Epsilon 0.9212892232558946 - Mean Reward 0.0 - Mean Length 5289.113 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 390.387 - Time 2023-04-29T21:53:10
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_7.chkpt at step 350000
# Episode 62 - deer - Step 356154 - Epsilon 0.9148103425048046 - Mean Reward 0.0 - Mean Length 5653.238 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 113.083 - Time 2023-04-29T21:55:03
# Episode 63 - tiger - Step 129063 - Epsilon 0.9682492317419024 - Mean Reward 36.469 - Mean Length 2016.609 - Mean Loss 0.014 - Mean Q Value 0.318 - Time Delta 281.042 - Time 2023-04-29T21:55:58
# Episode 64 - tiger - Step 131698 - Epsilon 0.9676116075212355 - Mean Reward 36.754 - Mean Length 2026.123 - Mean Loss 0.014 - Mean Q Value 0.327 - Time Delta 53.032 - Time 2023-04-29T21:56:52
# Episode 65 - tiger - Step 133982 - Epsilon 0.9670592589347485 - Mean Reward 36.758 - Mean Length 2030.03 - Mean Loss 0.014 - Mean Q Value 0.335 - Time Delta 58.507 - Time 2023-04-29T21:57:50
# Episode 66 - tiger - Step 136857 - Epsilon 0.9663644347377981 - Mean Reward 36.985 - Mean Length 2042.642 - Mean Loss 0.014 - Mean Q Value 0.343 - Time Delta 55.663 - Time 2023-04-29T21:58:46
# Episode 67 - tiger - Step 139255 - Epsilon 0.9657852728078281 - Mean Reward 37.044 - Mean Length 2047.868 - Mean Loss 0.015 - Mean Q Value 0.351 - Time Delta 56.54 - Time 2023-04-29T21:59:42
# Episode 68 - tiger - Step 142160 - Epsilon 0.9650841258005336 - Mean Reward 37.391 - Mean Length 2060.29 - Mean Loss 0.015 - Mean Q Value 0.359 - Time Delta 55.284 - Time 2023-04-29T22:00:38
# Episode 69 - tiger - Step 144972 - Epsilon 0.9644059099960106 - Mean Reward 37.671 - Mean Length 2071.029 - Mean Loss 0.015 - Mean Q Value 0.367 - Time Delta 53.516 - Time 2023-04-29T22:01:31
# Episode 70 - deer - Step 386581 - Epsilon 0.9078780077600241 - Mean Reward 0.0 - Mean Length 5444.803 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 513.404 - Time 2023-04-29T22:03:36
# Episode 71 - tiger - Step 147790 - Epsilon 0.9637267252183548 - Mean Reward 37.431 - Mean Length 2052.639 - Mean Loss 0.015 - Mean Q Value 0.37 - Time Delta 177.679 - Time 2023-04-29T22:04:29
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_3.chkpt at step 150000
# Episode 72 - tiger - Step 150596 - Epsilon 0.9630509079066789 - Mean Reward 37.781 - Mean Length 2062.959 - Mean Loss 0.015 - Mean Q Value 0.377 - Time Delta 51.072 - Time 2023-04-29T22:05:20
# Episode 73 - tiger - Step 152990 - Epsilon 0.9624746943153065 - Mean Reward 37.919 - Mean Length 2067.432 - Mean Loss 0.015 - Mean Q Value 0.386 - Time Delta 53.82 - Time 2023-04-29T22:06:14
# Episode 74 - tiger - Step 155488 - Epsilon 0.9618738164371583 - Mean Reward 38.04 - Mean Length 2073.173 - Mean Loss 0.015 - Mean Q Value 0.394 - Time Delta 53.983 - Time 2023-04-29T22:07:08
# Episode 75 - tiger - Step 158331 - Epsilon 0.9611904074318481 - Mean Reward 38.289 - Mean Length 2083.303 - Mean Loss 0.015 - Mean Q Value 0.402 - Time Delta 53.029 - Time 2023-04-29T22:08:01
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_8.chkpt at step 400000
# Episode 76 - deer - Step 414705 - Epsilon 0.9015171046505791 - Mean Reward 0.0 - Mean Length 5385.779 - Mean Loss 0.0 - Mean Q Value 0.003 - Time Delta 375.072 - Time 2023-04-29T22:09:52
# Episode 77 - tiger - Step 160797 - Epsilon 0.9605980160949288 - Mean Reward 37.833 - Mean Length 2061.5 - Mean Loss 0.015 - Mean Q Value 0.404 - Time Delta 169.228 - Time 2023-04-29T22:10:50
# Episode 78 - tiger - Step 163212 - Epsilon 0.9600182300106936 - Mean Reward 37.848 - Mean Length 2065.975 - Mean Loss 0.015 - Mean Q Value 0.412 - Time Delta 56.021 - Time 2023-04-29T22:11:46
# Episode 79 - tiger - Step 165703 - Epsilon 0.9594205647005125 - Mean Reward 37.9 - Mean Length 2071.288 - Mean Loss 0.015 - Mean Q Value 0.419 - Time Delta 56.808 - Time 2023-04-29T22:12:43
# Episode 80 - tiger - Step 168069 - Epsilon 0.9588532351697429 - Mean Reward 37.988 - Mean Length 2074.926 - Mean Loss 0.015 - Mean Q Value 0.426 - Time Delta 54.794 - Time 2023-04-29T22:13:37
# Episode 81 - deer - Step 443798 - Epsilon 0.8949839320509014 - Mean Reward 0.0 - Mean Length 5412.171 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 347.179 - Time 2023-04-29T22:15:39
# Episode 82 - tiger - Step 170065 - Epsilon 0.9583748867034014 - Mean Reward 37.434 - Mean Length 2048.976 - Mean Loss 0.015 - Mean Q Value 0.428 - Time Delta 178.34 - Time 2023-04-29T22:16:36
# Episode 83 - tiger - Step 172831 - Epsilon 0.9577123994677018 - Mean Reward 37.607 - Mean Length 2057.512 - Mean Loss 0.015 - Mean Q Value 0.435 - Time Delta 54.772 - Time 2023-04-29T22:17:31
# Episode 84 - tiger - Step 175527 - Epsilon 0.957067118713752 - Mean Reward 37.824 - Mean Length 2065.024 - Mean Loss 0.015 - Mean Q Value 0.443 - Time Delta 52.762 - Time 2023-04-29T22:18:23
# Episode 85 - tiger - Step 178048 - Epsilon 0.9564641171275597 - Mean Reward 37.895 - Mean Length 2070.326 - Mean Loss 0.015 - Mean Q Value 0.45 - Time Delta 55.593 - Time 2023-04-29T22:19:19
# Episode 86 - tiger - Step 180615 - Epsilon 0.9558505031180603 - Mean Reward 38.011 - Mean Length 2076.034 - Mean Loss 0.015 - Mean Q Value 0.457 - Time Delta 54.697 - Time 2023-04-29T22:20:14
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_9.chkpt at step 450000
# Episode 87 - deer - Step 474005 - Epsilon 0.888250692170665 - Mean Reward 0.0 - Mean Length 5386.42 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 397.856 - Time 2023-04-29T22:22:17
# Episode 88 - tiger - Step 182923 - Epsilon 0.9552991363933605 - Mean Reward 37.573 - Mean Length 2055.315 - Mean Loss 0.015 - Mean Q Value 0.459 - Time Delta 178.746 - Time 2023-04-29T22:23:12
# Episode 89 - tiger - Step 185537 - Epsilon 0.954675052271327 - Mean Reward 37.656 - Mean Length 2061.522 - Mean Loss 0.015 - Mean Q Value 0.467 - Time Delta 55.526 - Time 2023-04-29T22:24:08
# Episode 90 - tiger - Step 187726 - Epsilon 0.9541527492118204 - Mean Reward 37.582 - Mean Length 2062.923 - Mean Loss 0.015 - Mean Q Value 0.474 - Time Delta 57.558 - Time 2023-04-29T22:25:05
# Episode 91 - tiger - Step 190134 - Epsilon 0.9535785220446572 - Mean Reward 37.641 - Mean Length 2066.674 - Mean Loss 0.015 - Mean Q Value 0.481 - Time Delta 54.537 - Time 2023-04-29T22:26:00
# Episode 92 - tiger - Step 193011 - Epsilon 0.9528929072006733 - Mean Reward 37.86 - Mean Length 2075.387 - Mean Loss 0.016 - Mean Q Value 0.488 - Time Delta 53.219 - Time 2023-04-29T22:26:53
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_10.chkpt at step 500000
# Episode 93 - deer - Step 502605 - Epsilon 0.8819223497140365 - Mean Reward 0.0 - Mean Length 5346.862 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 389.268 - Time 2023-04-29T22:28:46
# Episode 94 - tiger - Step 195250 - Epsilon 0.9523596745815408 - Mean Reward 37.379 - Mean Length 2055.263 - Mean Loss 0.015 - Mean Q Value 0.49 - Time Delta 171.13 - Time 2023-04-29T22:29:44
# Episode 95 - tiger - Step 197876 - Epsilon 0.9517346555619074 - Mean Reward 37.552 - Mean Length 2061.208 - Mean Loss 0.016 - Mean Q Value 0.497 - Time Delta 53.634 - Time 2023-04-29T22:30:38
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_4.chkpt at step 200000
# Episode 96 - tiger - Step 200592 - Epsilon 0.9510886469946679 - Mean Reward 37.68 - Mean Length 2067.959 - Mean Loss 0.016 - Mean Q Value 0.504 - Time Delta 57.987 - Time 2023-04-29T22:31:36
# Episode 97 - tiger - Step 202929 - Epsilon 0.950533135677689 - Mean Reward 37.796 - Mean Length 2070.704 - Mean Loss 0.016 - Mean Q Value 0.512 - Time Delta 50.694 - Time 2023-04-29T22:32:27
# Episode 98 - tiger - Step 205682 - Epsilon 0.9498791562417067 - Mean Reward 38.0 - Mean Length 2077.596 - Mean Loss 0.016 - Mean Q Value 0.519 - Time Delta 51.557 - Time 2023-04-29T22:33:18
# Episode 99 - deer - Step 530532 - Epsilon 0.8757864322265306 - Mean Reward 0.0 - Mean Length 5305.32 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 383.146 - Time 2023-04-29T22:35:09
# Episode 100 - tiger - Step 208638 - Epsilon 0.9491774547680616 - Mean Reward 38.2 - Mean Length 2086.38 - Mean Loss 0.016 - Mean Q Value 0.526 - Time Delta 167.988 - Time 2023-04-29T22:36:06
# Episode 101 - tiger - Step 211385 - Epsilon 0.9485258308464277 - Mean Reward 38.27 - Mean Length 2086.0 - Mean Loss 0.016 - Mean Q Value 0.538 - Time Delta 51.718 - Time 2023-04-29T22:36:58
# Episode 102 - tiger - Step 213952 - Epsilon 0.9479173095984719 - Mean Reward 38.27 - Mean Length 2086.9 - Mean Loss 0.016 - Mean Q Value 0.55 - Time Delta 54.017 - Time 2023-04-29T22:37:52
# Episode 103 - tiger - Step 216445 - Epsilon 0.9473267041279022 - Mean Reward 38.44 - Mean Length 2089.89 - Mean Loss 0.016 - Mean Q Value 0.563 - Time Delta 52.543 - Time 2023-04-29T22:38:44
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_11.chkpt at step 550000
# Episode 104 - deer - Step 558979 - Epsilon 0.8695801522043574 - Mean Reward 0.0 - Mean Length 5316.8 - Mean Loss 0.0 - Mean Q Value 0.002 - Time Delta 329.422 - Time 2023-04-29T22:40:38
# Episode 105 - tiger - Step 218820 - Epsilon 0.9467643957787717 - Mean Reward 38.05 - Mean Length 2068.23 - Mean Loss 0.016 - Mean Q Value 0.575 - Time Delta 169.574 - Time 2023-04-29T22:41:34
# Episode 106 - tiger - Step 221164 - Epsilon 0.9462097542992627 - Mean Reward 38.08 - Mean Length 2069.71 - Mean Loss 0.017 - Mean Q Value 0.587 - Time Delta 55.005 - Time 2023-04-29T22:42:29
# Episode 107 - tiger - Step 223406 - Epsilon 0.9456795522686299 - Mean Reward 38.37 - Mean Length 2092.13 - Mean Loss 0.017 - Mean Q Value 0.6 - Time Delta 50.897 - Time 2023-04-29T22:43:20
# Episode 108 - tiger - Step 226149 - Epsilon 0.9450312747380976 - Mean Reward 38.45 - Mean Length 2090.15 - Mean Loss 0.017 - Mean Q Value 0.613 - Time Delta 53.779 - Time 2023-04-29T22:44:14
# Episode 109 - tiger - Step 228408 - Epsilon 0.9444977189359169 - Mean Reward 38.39 - Mean Length 2085.06 - Mean Loss 0.017 - Mean Q Value 0.625 - Time Delta 57.143 - Time 2023-04-29T22:45:11
# Episode 110 - deer - Step 586053 - Epsilon 0.8637142722087412 - Mean Reward 0.0 - Mean Length 5281.48 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 383.998 - Time 2023-04-29T22:47:02
# Episode 111 - tiger - Step 231035 - Epsilon 0.9438776236274932 - Mean Reward 37.92 - Mean Length 2063.55 - Mean Loss 0.017 - Mean Q Value 0.636 - Time Delta 164.811 - Time 2023-04-29T22:47:56
# Episode 112 - tiger - Step 233566 - Epsilon 0.9432805738979583 - Mean Reward 38.44 - Mean Length 2088.86 - Mean Loss 0.017 - Mean Q Value 0.65 - Time Delta 52.753 - Time 2023-04-29T22:48:48
# Episode 113 - tiger - Step 236010 - Epsilon 0.9427044054325973 - Mean Reward 38.53 - Mean Length 2085.84 - Mean Loss 0.017 - Mean Q Value 0.662 - Time Delta 53.199 - Time 2023-04-29T22:49:42
# Episode 114 - tiger - Step 238467 - Epsilon 0.9421255269853654 - Mean Reward 38.68 - Mean Length 2086.9 - Mean Loss 0.017 - Mean Q Value 0.674 - Time Delta 53.827 - Time 2023-04-29T22:50:35
# Episode 115 - tiger - Step 241175 - Epsilon 0.9414879237768453 - Mean Reward 38.74 - Mean Length 2085.49 - Mean Loss 0.017 - Mean Q Value 0.686 - Time Delta 52.826 - Time 2023-04-29T22:51:28
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_12.chkpt at step 600000
# Episode 116 - deer - Step 614436 - Epsilon 0.8576072634250718 - Mean Reward 0.0 - Mean Length 5273.43 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 382.348 - Time 2023-04-29T22:53:25
# Episode 117 - deer - Step 641399 - Epsilon 0.851845786695962 - Mean Reward 0.0 - Mean Length 5543.06 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 107.64 - Time 2023-04-29T22:55:12
# Episode 118 - tiger - Step 243543 - Epsilon 0.9409307278025265 - Mean Reward 38.26 - Mean Length 2060.84 - Mean Loss 0.017 - Mean Q Value 0.697 - Time Delta 281.678 - Time 2023-04-29T22:56:10
# Episode 119 - tiger - Step 246145 - Epsilon 0.9403188513219237 - Mean Reward 38.37 - Mean Length 2061.61 - Mean Loss 0.017 - Mean Q Value 0.709 - Time Delta 53.296 - Time 2023-04-29T22:57:03
# Episode 120 - tiger - Step 248855 - Epsilon 0.9396820009778712 - Mean Reward 38.51 - Mean Length 2063.02 - Mean Loss 0.017 - Mean Q Value 0.72 - Time Delta 52.533 - Time 2023-04-29T22:57:56
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_5.chkpt at step 250000
# Episode 121 - tiger - Step 251865 - Epsilon 0.9389751561673956 - Mean Reward 38.54 - Mean Length 2067.0 - Mean Loss 0.017 - Mean Q Value 0.732 - Time Delta 57.522 - Time 2023-04-29T22:58:53
# Episode 122 - tiger - Step 254961 - Epsilon 0.9382486704918347 - Mean Reward 38.63 - Mean Length 2070.31 - Mean Loss 0.017 - Mean Q Value 0.744 - Time Delta 54.569 - Time 2023-04-29T22:59:48
# Episode 123 - tiger - Step 257246 - Epsilon 0.9377128489303705 - Mean Reward 38.5 - Mean Length 2062.37 - Mean Loss 0.017 - Mean Q Value 0.756 - Time Delta 52.789 - Time 2023-04-29T23:00:41
# Episode 124 - tiger - Step 259982 - Epsilon 0.9370716725687788 - Mean Reward 39.1 - Mean Length 2089.73 - Mean Loss 0.017 - Mean Q Value 0.77 - Time Delta 51.307 - Time 2023-04-29T23:01:32
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_13.chkpt at step 650000
# Episode 125 - deer - Step 671288 - Epsilon 0.845504303303504 - Mean Reward 0.0 - Mean Length 5342.84 - Mean Loss 0.0 - Mean Q Value 0.001 - Time Delta 497.744 - Time 2023-04-29T23:03:30
# Episode 126 - tiger - Step 262713 - Epsilon 0.9364321051614672 - Mean Reward 38.85 - Mean Length 2067.61 - Mean Loss 0.017 - Mean Q Value 0.778 - Time Delta 169.739 - Time 2023-04-29T23:04:22
# Episode 127 - tiger - Step 265311 - Epsilon 0.935824089907402 - Mean Reward 38.85 - Mean Length 2068.12 - Mean Loss 0.017 - Mean Q Value 0.79 - Time Delta 56.346 - Time 2023-04-29T23:05:18
# Episode 128 - tiger - Step 268160 - Epsilon 0.9351577864314782 - Mean Reward 38.94 - Mean Length 2072.66 - Mean Loss 0.017 - Mean Q Value 0.801 - Time Delta 51.063 - Time 2023-04-29T23:06:09
# Episode 129 - tiger - Step 270848 - Epsilon 0.9345295714242652 - Mean Reward 39.45 - Mean Length 2099.54 - Mean Loss 0.017 - Mean Q Value 0.816 - Time Delta 57.138 - Time 2023-04-29T23:07:06
# Episode 130 - deer - Step 697112 - Epsilon 0.8400633092675864 - Mean Reward 0.0 - Mean Length 5046.38 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 321.955 - Time 2023-04-29T23:08:52
# Episode 131 - tiger - Step 273733 - Epsilon 0.9338557849000328 - Mean Reward 39.56 - Mean Length 2097.93 - Mean Loss 0.017 - Mean Q Value 0.826 - Time Delta 157.711 - Time 2023-04-29T23:09:44
# Episode 132 - tiger - Step 276405 - Epsilon 0.9332321774657539 - Mean Reward 39.65 - Mean Length 2102.79 - Mean Loss 0.017 - Mean Q Value 0.837 - Time Delta 53.277 - Time 2023-04-29T23:10:37
# Episode 133 - tiger - Step 279028 - Epsilon 0.9326204109936796 - Mean Reward 39.73 - Mean Length 2107.12 - Mean Loss 0.017 - Mean Q Value 0.848 - Time Delta 53.756 - Time 2023-04-29T23:11:31
# Episode 134 - tiger - Step 281495 - Epsilon 0.9320453946221406 - Mean Reward 39.6 - Mean Length 2103.84 - Mean Loss 0.017 - Mean Q Value 0.859 - Time Delta 54.19 - Time 2023-04-29T23:12:25
# Episode 135 - tiger - Step 283896 - Epsilon 0.9314861021784664 - Mean Reward 39.68 - Mean Length 2104.61 - Mean Loss 0.017 - Mean Q Value 0.869 - Time Delta 53.82 - Time 2023-04-29T23:13:19
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_14.chkpt at step 700000
# Episode 136 - deer - Step 726105 - Epsilon 0.8339963336666891 - Mean Reward 0.0 - Mean Length 5336.31 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 385.001 - Time 2023-04-29T23:15:17
# Episode 137 - tiger - Step 286650 - Epsilon 0.9308449946434836 - Mean Reward 39.34 - Mean Length 2082.32 - Mean Loss 0.017 - Mean Q Value 0.873 - Time Delta 169.427 - Time 2023-04-29T23:16:08
# Episode 138 - tiger - Step 289195 - Epsilon 0.9302529328111957 - Mean Reward 39.86 - Mean Length 2107.77 - Mean Loss 0.017 - Mean Q Value 0.889 - Time Delta 52.757 - Time 2023-04-29T23:17:01
# Episode 139 - tiger - Step 292015 - Epsilon 0.9295973355367148 - Mean Reward 40.03 - Mean Length 2111.12 - Mean Loss 0.017 - Mean Q Value 0.899 - Time Delta 52.883 - Time 2023-04-29T23:17:54
# Episode 140 - tiger - Step 294892 - Epsilon 0.9289289629617865 - Mean Reward 40.34 - Mean Length 2118.4 - Mean Loss 0.017 - Mean Q Value 0.909 - Time Delta 52.643 - Time 2023-04-29T23:18:47
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_15.chkpt at step 750000
# Episode 141 - deer - Step 752840 - Epsilon 0.8284406969019351 - Mean Reward 0.0 - Mean Length 5352.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 317.9 - Time 2023-04-29T23:20:35
# Episode 142 - tiger - Step 297062 - Epsilon 0.9284251556064355 - Mean Reward 39.82 - Mean Length 2086.44 - Mean Loss 0.016 - Mean Q Value 0.913 - Time Delta 161.649 - Time 2023-04-29T23:21:28
# Episode 143 - tiger - Step 299763 - Epsilon 0.9277984480576347 - Mean Reward 39.81 - Mean Length 2085.95 - Mean Loss 0.016 - Mean Q Value 0.922 - Time Delta 59.587 - Time 2023-04-29T23:22:28
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_6.chkpt at step 300000
# Episode 144 - tiger - Step 302307 - Epsilon 0.92720855577648 - Mean Reward 40.29 - Mean Length 2111.39 - Mean Loss 0.017 - Mean Q Value 0.938 - Time Delta 54.483 - Time 2023-04-29T23:23:22
# Episode 145 - tiger - Step 304904 - Epsilon 0.9266067609251268 - Mean Reward 40.28 - Mean Length 2113.18 - Mean Loss 0.016 - Mean Q Value 0.948 - Time Delta 56.047 - Time 2023-04-29T23:24:19
# Episode 146 - tiger - Step 307475 - Epsilon 0.9260113757174545 - Mean Reward 40.13 - Mean Length 2109.81 - Mean Loss 0.016 - Mean Q Value 0.957 - Time Delta 52.831 - Time 2023-04-29T23:25:11
# Episode 147 - deer - Step 779848 - Epsilon 0.8228659062912483 - Mean Reward 0.0 - Mean Length 5340.9 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 383.432 - Time 2023-04-29T23:26:58
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_16.chkpt at step 800000
# Episode 148 - deer - Step 806413 - Epsilon 0.8174191540507508 - Mean Reward 0.0 - Mean Length 5606.55 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 108.285 - Time 2023-04-29T23:28:47
# Episode 149 - tiger - Step 309867 - Epsilon 0.9254577863852023 - Mean Reward 39.3 - Mean Length 2059.18 - Mean Loss 0.016 - Mean Q Value 0.953 - Time Delta 268.683 - Time 2023-04-29T23:29:40
# Episode 150 - tiger - Step 312387 - Epsilon 0.9248749315253987 - Mean Reward 39.8 - Mean Length 2084.38 - Mean Loss 0.016 - Mean Q Value 0.968 - Time Delta 55.779 - Time 2023-04-29T23:30:36
# Episode 151 - tiger - Step 315251 - Epsilon 0.9242129580063868 - Mean Reward 39.89 - Mean Length 2087.36 - Mean Loss 0.016 - Mean Q Value 0.977 - Time Delta 54.616 - Time 2023-04-29T23:31:30
# Episode 152 - tiger - Step 317843 - Epsilon 0.923614261933157 - Mean Reward 39.9 - Mean Length 2081.23 - Mean Loss 0.016 - Mean Q Value 0.986 - Time Delta 51.031 - Time 2023-04-29T23:32:21
# Episode 153 - tiger - Step 320360 - Epsilon 0.9230332604029075 - Mean Reward 39.92 - Mean Length 2084.75 - Mean Loss 0.016 - Mean Q Value 0.994 - Time Delta 54.492 - Time 2023-04-29T23:33:16
# Episode 154 - tiger - Step 322993 - Epsilon 0.9224258736113468 - Mean Reward 40.09 - Mean Length 2085.42 - Mean Loss 0.016 - Mean Q Value 1.003 - Time Delta 53.508 - Time 2023-04-29T23:34:09
# Episode 155 - tiger - Step 325274 - Epsilon 0.9219000101421879 - Mean Reward 40.65 - Mean Length 2108.23 - Mean Loss 0.016 - Mean Q Value 1.018 - Time Delta 50.338 - Time 2023-04-29T23:35:00
# Episode 156 - deer - Step 833676 - Epsilon 0.8118667720748235 - Mean Reward 0.0 - Mean Length 5327.18 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 484.305 - Time 2023-04-29T23:36:51
# Episode 157 - tiger - Step 327721 - Epsilon 0.9213362102103175 - Mean Reward 40.41 - Mean Length 2086.28 - Mean Loss 0.015 - Mean Q Value 1.019 - Time Delta 164.829 - Time 2023-04-29T23:37:45
# Episode 158 - tiger - Step 330494 - Epsilon 0.9206977151466114 - Mean Reward 40.62 - Mean Length 2088.9 - Mean Loss 0.015 - Mean Q Value 1.027 - Time Delta 50.952 - Time 2023-04-29T23:38:36
# Episode 159 - tiger - Step 333343 - Epsilon 0.9200421815965621 - Mean Reward 40.75 - Mean Length 2092.34 - Mean Loss 0.015 - Mean Q Value 1.034 - Time Delta 53.317 - Time 2023-04-29T23:39:29
# Episode 160 - tiger - Step 336111 - Epsilon 0.9194057325640148 - Mean Reward 40.81 - Mean Length 2094.55 - Mean Loss 0.015 - Mean Q Value 1.042 - Time Delta 53.155 - Time 2023-04-29T23:40:22
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_17.chkpt at step 850000
# Episode 161 - deer - Step 861444 - Epsilon 0.8062503095371091 - Mean Reward 0.0 - Mean Length 5335.19 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 322.917 - Time 2023-04-29T23:42:14
# Episode 162 - tiger - Step 338931 - Epsilon 0.9187577798716344 - Mean Reward 41.39 - Mean Length 2122.75 - Mean Loss 0.015 - Mean Q Value 1.057 - Time Delta 163.981 - Time 2023-04-29T23:43:06
# Episode 163 - tiger - Step 341504 - Epsilon 0.9181669788925311 - Mean Reward 41.46 - Mean Length 2124.41 - Mean Loss 0.015 - Mean Q Value 1.064 - Time Delta 54.38 - Time 2023-04-29T23:44:00
# Episode 164 - tiger - Step 344308 - Epsilon 0.9175235693012218 - Mean Reward 41.51 - Mean Length 2126.1 - Mean Loss 0.015 - Mean Q Value 1.071 - Time Delta 51.72 - Time 2023-04-29T23:44:52
# Episode 165 - tiger - Step 347032 - Epsilon 0.9168989483799243 - Mean Reward 41.66 - Mean Length 2130.5 - Mean Loss 0.015 - Mean Q Value 1.077 - Time Delta 55.381 - Time 2023-04-29T23:45:48
# Episode 166 - tiger - Step 349390 - Epsilon 0.9163585956668427 - Mean Reward 41.49 - Mean Length 2125.33 - Mean Loss 0.015 - Mean Q Value 1.083 - Time Delta 58.454 - Time 2023-04-29T23:46:46
# Episode 167 - deer - Step 889774 - Epsilon 0.8005602148410395 - Mean Reward 0.0 - Mean Length 5336.2 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 393.046 - Time 2023-04-29T23:48:47
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_7.chkpt at step 350000
# Episode 168 - tiger - Step 351857 - Epsilon 0.9157936056789592 - Mean Reward 40.96 - Mean Length 2096.97 - Mean Loss 0.015 - Mean Q Value 1.08 - Time Delta 178.887 - Time 2023-04-29T23:49:45
# Episode 169 - tiger - Step 354355 - Epsilon 0.9152218710433881 - Mean Reward 40.79 - Mean Length 2093.83 - Mean Loss 0.014 - Mean Q Value 1.086 - Time Delta 59.855 - Time 2023-04-29T23:50:45
# Episode 170 - tiger - Step 357114 - Epsilon 0.9145908143395655 - Mean Reward 41.41 - Mean Length 2121.42 - Mean Loss 0.015 - Mean Q Value 1.1 - Time Delta 56.659 - Time 2023-04-29T23:51:41
# Episode 171 - tiger - Step 359842 - Epsilon 0.9139672759769075 - Mean Reward 41.35 - Mean Length 2120.52 - Mean Loss 0.014 - Mean Q Value 1.106 - Time Delta 57.772 - Time 2023-04-29T23:52:39
# Episode 172 - tiger - Step 362907 - Epsilon 0.9132672167085455 - Mean Reward 41.45 - Mean Length 2123.11 - Mean Loss 0.014 - Mean Q Value 1.112 - Time Delta 57.073 - Time 2023-04-29T23:53:36
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_18.chkpt at step 900000
# Episode 173 - deer - Step 917333 - Epsilon 0.7950635116119238 - Mean Reward 0.0 - Mean Length 5307.52 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 424.748 - Time 2023-04-29T23:55:52
# Episode 174 - tiger - Step 365412 - Epsilon 0.9126954620918856 - Mean Reward 41.15 - Mean Length 2099.24 - Mean Loss 0.014 - Mean Q Value 1.106 - Time Delta 194.207 - Time 2023-04-29T23:56:50
# Episode 175 - tiger - Step 367991 - Epsilon 0.9121071912832661 - Mean Reward 41.21 - Mean Length 2096.6 - Mean Loss 0.014 - Mean Q Value 1.111 - Time Delta 55.643 - Time 2023-04-29T23:57:46
# Episode 176 - tiger - Step 370436 - Epsilon 0.9115498360518944 - Mean Reward 41.67 - Mean Length 2121.05 - Mean Loss 0.014 - Mean Q Value 1.125 - Time Delta 61.579 - Time 2023-04-29T23:58:48
# Episode 177 - tiger - Step 373145 - Epsilon 0.9109326978502136 - Mean Reward 41.86 - Mean Length 2123.48 - Mean Loss 0.014 - Mean Q Value 1.13 - Time Delta 57.722 - Time 2023-04-29T23:59:45
# Episode 178 - deer - Step 944452 - Epsilon 0.7896914104256914 - Mean Reward 0.0 - Mean Length 5297.47 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 367.007 - Time 2023-04-30T00:01:59
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_19.chkpt at step 950000
# Episode 179 - deer - Step 972187 - Epsilon 0.7842348260829366 - Mean Reward 0.0 - Mean Length 5574.82 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 137.359 - Time 2023-04-30T00:04:16
# Episode 180 - tiger - Step 375591 - Epsilon 0.9103758327146605 - Mean Reward 41.1 - Mean Length 2075.22 - Mean Loss 0.014 - Mean Q Value 1.115 - Time Delta 332.52 - Time 2023-04-30T00:05:18
# Episode 181 - tiger - Step 377843 - Epsilon 0.9098634353101258 - Mean Reward 41.57 - Mean Length 2097.74 - Mean Loss 0.014 - Mean Q Value 1.129 - Time Delta 57.22 - Time 2023-04-30T00:06:15
# Episode 182 - tiger - Step 380557 - Epsilon 0.9092463022780984 - Mean Reward 41.85 - Mean Length 2104.92 - Mean Loss 0.014 - Mean Q Value 1.134 - Time Delta 59.068 - Time 2023-04-30T00:07:14
# Episode 183 - tiger - Step 382528 - Epsilon 0.9087983814721501 - Mean Reward 41.54 - Mean Length 2096.97 - Mean Loss 0.014 - Mean Q Value 1.138 - Time Delta 64.613 - Time 2023-04-30T00:08:19
# Episode 184 - tiger - Step 384987 - Epsilon 0.9082398692875203 - Mean Reward 41.4 - Mean Length 2094.6 - Mean Loss 0.014 - Mean Q Value 1.142 - Time Delta 60.081 - Time 2023-04-30T00:09:19
# Episode 185 - tiger - Step 387962 - Epsilon 0.907564616940832 - Mean Reward 41.59 - Mean Length 2099.14 - Mean Loss 0.013 - Mean Q Value 1.146 - Time Delta 56.165 - Time 2023-04-30T00:10:15
# Episode 186 - tiger - Step 390071 - Epsilon 0.9070862295626406 - Mean Reward 41.52 - Mean Length 2094.56 - Mean Loss 0.013 - Mean Q Value 1.15 - Time Delta 56.438 - Time 2023-04-30T00:11:11
# Episode 187 - deer - Step 998666 - Epsilon 0.779060532106991 - Mean Reward 0.0 - Mean Length 5246.61 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 534.762 - Time 2023-04-30T00:13:11
# Episode 188 - tiger - Step 392993 - Epsilon 0.9064238449544877 - Mean Reward 41.8 - Mean Length 2100.7 - Mean Loss 0.013 - Mean Q Value 1.153 - Time Delta 174.959 - Time 2023-04-30T00:14:06
# Episode 189 - tiger - Step 395544 - Epsilon 0.905845957368542 - Mean Reward 41.84 - Mean Length 2100.07 - Mean Loss 0.013 - Mean Q Value 1.157 - Time Delta 57.848 - Time 2023-04-30T00:15:04
# Episode 190 - tiger - Step 398126 - Epsilon 0.9052614224088658 - Mean Reward 42.03 - Mean Length 2104.0 - Mean Loss 0.013 - Mean Q Value 1.16 - Time Delta 60.441 - Time 2023-04-30T00:16:05
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_8.chkpt at step 400000
# Episode 191 - tiger - Step 400775 - Epsilon 0.9046621114256309 - Mean Reward 42.1 - Mean Length 2106.41 - Mean Loss 0.013 - Mean Q Value 1.164 - Time Delta 60.569 - Time 2023-04-30T00:17:05
# Episode 192 - tiger - Step 403236 - Epsilon 0.9041056891788932 - Mean Reward 41.99 - Mean Length 2102.25 - Mean Loss 0.013 - Mean Q Value 1.166 - Time Delta 58.185 - Time 2023-04-30T00:18:03
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_20.chkpt at step 1000000
# Episode 193 - deer - Step 1025827 - Epsilon 0.7737884353535025 - Mean Reward 0.0 - Mean Length 5232.22 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 413.477 - Time 2023-04-30T00:20:04
# Episode 194 - tiger - Step 405774 - Epsilon 0.9035322160009499 - Mean Reward 42.25 - Mean Length 2105.24 - Mean Loss 0.013 - Mean Q Value 1.17 - Time Delta 175.851 - Time 2023-04-30T00:20:59
# Episode 195 - tiger - Step 408293 - Epsilon 0.9029633956428506 - Mean Reward 42.23 - Mean Length 2104.17 - Mean Loss 0.013 - Mean Q Value 1.172 - Time Delta 56.508 - Time 2023-04-30T00:21:56
# Episode 196 - tiger - Step 410613 - Epsilon 0.9024398286569617 - Mean Reward 42.17 - Mean Length 2100.21 - Mean Loss 0.013 - Mean Q Value 1.175 - Time Delta 58.323 - Time 2023-04-30T00:22:54
# Episode 197 - tiger - Step 413288 - Epsilon 0.901836523698632 - Mean Reward 42.17 - Mean Length 2103.59 - Mean Loss 0.012 - Mean Q Value 1.178 - Time Delta 57.296 - Time 2023-04-30T00:23:51
# Episode 198 - tiger - Step 415812 - Epsilon 0.9012676442813214 - Mean Reward 42.15 - Mean Length 2101.3 - Mean Loss 0.012 - Mean Q Value 1.18 - Time Delta 56.361 - Time 2023-04-30T00:24:48
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_21.chkpt at step 1050000
# Episode 199 - deer - Step 1052885 - Epsilon 0.7685718066641928 - Mean Reward 0.0 - Mean Length 5223.53 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 397.742 - Time 2023-04-30T00:26:42
# Episode 200 - tiger - Step 418161 - Epsilon 0.9007385301673406 - Mean Reward 41.98 - Mean Length 2095.23 - Mean Loss 0.012 - Mean Q Value 1.182 - Time Delta 171.105 - Time 2023-04-30T00:27:39
# Episode 201 - tiger - Step 420976 - Epsilon 0.9001048583468629 - Mean Reward 41.98 - Mean Length 2095.91 - Mean Loss 0.012 - Mean Q Value 1.184 - Time Delta 56.705 - Time 2023-04-30T00:28:36
# Episode 202 - tiger - Step 423714 - Epsilon 0.8994889473138501 - Mean Reward 42.15 - Mean Length 2097.62 - Mean Loss 0.012 - Mean Q Value 1.186 - Time Delta 52.041 - Time 2023-04-30T00:29:28
# Episode 203 - tiger - Step 425921 - Epsilon 0.8989927911147596 - Mean Reward 42.07 - Mean Length 2094.76 - Mean Loss 0.012 - Mean Q Value 1.187 - Time Delta 58.311 - Time 2023-04-30T00:30:26
# Episode 204 - tiger - Step 428871 - Epsilon 0.8983300282722159 - Mean Reward 42.71 - Mean Length 2124.26 - Mean Loss 0.012 - Mean Q Value 1.202 - Time Delta 53.415 - Time 2023-04-30T00:31:19
# Episode 205 - deer - Step 1079667 - Epsilon 0.7634430225380563 - Mean Reward 0.0 - Mean Length 5206.88 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 389.781 - Time 2023-04-30T00:33:12
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_22.chkpt at step 1100000
# Episode 206 - deer - Step 1106175 - Epsilon 0.7584004121409561 - Mean Reward 0.0 - Mean Length 5471.96 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 112.102 - Time 2023-04-30T00:35:04
# Episode 207 - tiger - Step 431924 - Epsilon 0.8976446393871749 - Mean Reward 42.3 - Mean Length 2085.18 - Mean Loss 0.012 - Mean Q Value 1.178 - Time Delta 275.011 - Time 2023-04-30T00:35:54
# Episode 208 - tiger - Step 434634 - Epsilon 0.8970366910336728 - Mean Reward 42.2 - Mean Length 2084.85 - Mean Loss 0.012 - Mean Q Value 1.179 - Time Delta 58.526 - Time 2023-04-30T00:36:53
# Episode 209 - tiger - Step 436713 - Epsilon 0.8965705772969795 - Mean Reward 42.23 - Mean Length 2083.05 - Mean Loss 0.011 - Mean Q Value 1.18 - Time Delta 57.345 - Time 2023-04-30T00:37:50
# Episode 210 - tiger - Step 439087 - Epsilon 0.8960386204665882 - Mean Reward 42.71 - Mean Length 2106.79 - Mean Loss 0.012 - Mean Q Value 1.194 - Time Delta 55.14 - Time 2023-04-30T00:38:45
# Episode 211 - tiger - Step 441647 - Epsilon 0.8954653391473398 - Mean Reward 42.68 - Mean Length 2106.12 - Mean Loss 0.011 - Mean Q Value 1.195 - Time Delta 56.048 - Time 2023-04-30T00:39:41
# Episode 212 - tiger - Step 444543 - Epsilon 0.8948172567948139 - Mean Reward 42.79 - Mean Length 2109.77 - Mean Loss 0.011 - Mean Q Value 1.195 - Time Delta 54.225 - Time 2023-04-30T00:40:36
# Episode 213 - deer - Step 1133524 - Epsilon 0.753232724793089 - Mean Reward 0.0 - Mean Length 5474.71 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 447.269 - Time 2023-04-30T00:42:31
# Episode 214 - tiger - Step 447471 - Epsilon 0.8941624901547286 - Mean Reward 42.43 - Mean Length 2090.04 - Mean Loss 0.011 - Mean Q Value 1.182 - Time Delta 169.33 - Time 2023-04-30T00:43:25
# Episode 215 - tiger - Step 449947 - Epsilon 0.8936091747728604 - Mean Reward 42.35 - Mean Length 2087.72 - Mean Loss 0.011 - Mean Q Value 1.183 - Time Delta 57.828 - Time 2023-04-30T00:44:23
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_9.chkpt at step 450000
# Episode 216 - tiger - Step 452575 - Epsilon 0.8930222662921322 - Mean Reward 42.8 - Mean Length 2114.0 - Mean Loss 0.011 - Mean Q Value 1.196 - Time Delta 58.716 - Time 2023-04-30T00:45:22
# Episode 217 - tiger - Step 455091 - Epsilon 0.8924607318374651 - Mean Reward 43.24 - Mean Length 2139.16 - Mean Loss 0.011 - Mean Q Value 1.21 - Time Delta 57.573 - Time 2023-04-30T00:46:19
# Episode 218 - tiger - Step 457858 - Epsilon 0.8918435855290758 - Mean Reward 43.46 - Mean Length 2143.15 - Mean Loss 0.011 - Mean Q Value 1.209 - Time Delta 54.324 - Time 2023-04-30T00:47:13
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_23.chkpt at step 1150000
# Episode 219 - deer - Step 1162250 - Epsilon 0.7478427604849485 - Mean Reward 0.0 - Mean Length 5208.51 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 399.29 - Time 2023-04-30T00:49:10
# Episode 220 - tiger - Step 460950 - Epsilon 0.8911544567338195 - Mean Reward 43.09 - Mean Length 2120.95 - Mean Loss 0.011 - Mean Q Value 1.195 - Time Delta 169.7 - Time 2023-04-30T00:50:03
# Episode 221 - tiger - Step 463906 - Epsilon 0.8904961367870927 - Mean Reward 43.3 - Mean Length 2120.41 - Mean Loss 0.011 - Mean Q Value 1.195 - Time Delta 50.586 - Time 2023-04-30T00:50:54
# Episode 222 - tiger - Step 466850 - Epsilon 0.8898409726783977 - Mean Reward 43.33 - Mean Length 2118.89 - Mean Loss 0.011 - Mean Q Value 1.194 - Time Delta 52.095 - Time 2023-04-30T00:51:46
# Episode 223 - tiger - Step 469120 - Epsilon 0.8893361311255666 - Mean Reward 43.4 - Mean Length 2118.74 - Mean Loss 0.011 - Mean Q Value 1.193 - Time Delta 52.095 - Time 2023-04-30T00:52:38
# Episode 224 - deer - Step 1187839 - Epsilon 0.743073892871562 - Mean Reward 0.0 - Mean Length 5464.4 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 312.343 - Time 2023-04-30T00:54:23
# Episode 225 - tiger - Step 471711 - Epsilon 0.8887602501081635 - Mean Reward 43.31 - Mean Length 2117.29 - Mean Loss 0.011 - Mean Q Value 1.193 - Time Delta 159.818 - Time 2023-04-30T00:55:18
# Episode 226 - tiger - Step 474329 - Epsilon 0.8881787467694238 - Mean Reward 43.22 - Mean Length 2116.16 - Mean Loss 0.011 - Mean Q Value 1.191 - Time Delta 54.756 - Time 2023-04-30T00:56:12
# Episode 227 - tiger - Step 477213 - Epsilon 0.8875386006133145 - Mean Reward 43.4 - Mean Length 2119.02 - Mean Loss 0.01 - Mean Q Value 1.19 - Time Delta 52.606 - Time 2023-04-30T00:57:05
# Episode 228 - tiger - Step 479768 - Epsilon 0.8869718662812984 - Mean Reward 43.41 - Mean Length 2116.08 - Mean Loss 0.01 - Mean Q Value 1.189 - Time Delta 52.752 - Time 2023-04-30T00:57:58
# Episode 229 - tiger - Step 482650 - Epsilon 0.8863330331389779 - Mean Reward 43.48 - Mean Length 2118.02 - Mean Loss 0.01 - Mean Q Value 1.188 - Time Delta 55.115 - Time 2023-04-30T00:58:53
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_24.chkpt at step 1200000
# Episode 230 - deer - Step 1213858 - Epsilon 0.7382560687223667 - Mean Reward 0.0 - Mean Length 5167.46 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 375.969 - Time 2023-04-30T01:00:39
# Episode 231 - deer - Step 1241241 - Epsilon 0.7332194111289229 - Mean Reward 0.0 - Mean Length 5441.29 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 110.527 - Time 2023-04-30T01:02:29
# Episode 232 - tiger - Step 485432 - Epsilon 0.8857168027562715 - Mean Reward 42.9 - Mean Length 2090.27 - Mean Loss 0.01 - Mean Q Value 1.171 - Time Delta 271.5 - Time 2023-04-30T01:03:24
# ...
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_114.chkpt at step 5700000
# Episode 1074 - deer - Step 5718962 - Epsilon 0.23937098813965332 - Mean Reward 0.0 - Mean Length 5407.6 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 85.422 - Time 2023-04-30T16:19:36
# Episode 1075 - tiger - Step 2278838 - Epsilon 0.5656897073742541 - Mean Reward 47.37 - Mean Length 2017.38 - Mean Loss 0.014 - Mean Q Value 1.932 - Time Delta 224.945 - Time 2023-04-30T16:20:21
# Episode 1076 - tiger - Step 2281474 - Epsilon 0.5653170406176428 - Mean Reward 48.15 - Mean Length 2043.74 - Mean Loss 0.015 - Mean Q Value 1.958 - Time Delta 44.919 - Time 2023-04-30T16:21:06
# Episode 1077 - tiger - Step 2284428 - Epsilon 0.5648997080499396 - Mean Reward 48.97 - Mean Length 2073.28 - Mean Loss 0.015 - Mean Q Value 1.984 - Time Delta 48.269 - Time 2023-04-30T16:21:54
# Episode 1078 - tiger - Step 2287583 - Epsilon 0.5644543190228667 - Mean Reward 49.25 - Mean Length 2078.94 - Mean Loss 0.015 - Mean Q Value 1.984 - Time Delta 47.615 - Time 2023-04-30T16:22:41
# Episode 1079 - tiger - Step 2290501 - Epsilon 0.5640426997020309 - Mean Reward 49.41 - Mean Length 2083.09 - Mean Loss 0.015 - Mean Q Value 1.985 - Time Delta 49.029 - Time 2023-04-30T16:23:31
# Episode 1080 - tiger - Step 2293207 - Epsilon 0.5636612538065696 - Mean Reward 49.72 - Mean Length 2085.94 - Mean Loss 0.015 - Mean Q Value 1.986 - Time Delta 45.475 - Time 2023-04-30T16:24:16
# Episode 1081 - deer - Step 5740421 - Epsilon 0.23809026093306854 - Mean Reward 0.0 - Mean Length 5132.11 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 363.177 - Time 2023-04-30T16:25:39
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_115.chkpt at step 5750000
# Episode 1082 - deer - Step 5764365 - Epsilon 0.23666930960361748 - Mean Reward 0.0 - Mean Length 5371.55 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 93.144 - Time 2023-04-30T16:27:13
# Episode 1083 - tiger - Step 2296344 - Epsilon 0.5632193757070744 - Mean Reward 49.31 - Mean Length 2043.59 - Mean Loss 0.015 - Mean Q Value 1.937 - Time Delta 217.587 - Time 2023-04-30T16:27:54
# Episode 1084 - tiger - Step 2299750 - Epsilon 0.5627399984724951 - Mean Reward 49.65 - Mean Length 2049.34 - Mean Loss 0.015 - Mean Q Value 1.938 - Time Delta 47.753 - Time 2023-04-30T16:28:41
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_46.chkpt at step 2300000
# Episode 1085 - tiger - Step 2302795 - Epsilon 0.5623117756080794 - Mean Reward 50.46 - Mean Length 2079.79 - Mean Loss 0.015 - Mean Q Value 1.965 - Time Delta 48.159 - Time 2023-04-30T16:29:29
# Episode 1086 - tiger - Step 2306047 - Epsilon 0.5618548018623223 - Mean Reward 51.39 - Mean Length 2112.31 - Mean Loss 0.015 - Mean Q Value 1.991 - Time Delta 45.634 - Time 2023-04-30T16:30:15
# Episode 1087 - tiger - Step 2309059 - Epsilon 0.5614318843920073 - Mean Reward 51.57 - Mean Length 2113.44 - Mean Loss 0.015 - Mean Q Value 1.992 - Time Delta 46.418 - Time 2023-04-30T16:31:02
# Episode 1088 - tiger - Step 2312335 - Epsilon 0.5609722598631052 - Mean Reward 51.62 - Mean Length 2116.89 - Mean Loss 0.015 - Mean Q Value 1.994 - Time Delta 43.467 - Time 2023-04-30T16:31:45
# Episode 1089 - deer - Step 5785913 - Epsilon 0.23539779976033798 - Mean Reward 0.0 - Mean Length 5139.03 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 357.366 - Time 2023-04-30T16:33:10
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_116.chkpt at step 5800000
# Episode 1090 - deer - Step 5809647 - Epsilon 0.23400520231535804 - Mean Reward 0.0 - Mean Length 5376.37 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 92.622 - Time 2023-04-30T16:34:43
# Episode 1091 - tiger - Step 2315431 - Epsilon 0.5605382352688418 - Mean Reward 50.06 - Mean Length 2061.69 - Mean Loss 0.015 - Mean Q Value 1.947 - Time Delta 223.498 - Time 2023-04-30T16:35:29
# Episode 1092 - tiger - Step 2318321 - Epsilon 0.5601333926102212 - Mean Reward 50.15 - Mean Length 2061.68 - Mean Loss 0.015 - Mean Q Value 1.949 - Time Delta 45.673 - Time 2023-04-30T16:36:14
# Episode 1093 - tiger - Step 2321266 - Epsilon 0.5597211461251829 - Mean Reward 50.93 - Mean Length 2091.13 - Mean Loss 0.015 - Mean Q Value 1.975 - Time Delta 49.74 - Time 2023-04-30T16:37:04
# Episode 1094 - tiger - Step 2324416 - Epsilon 0.5592805391792275 - Mean Reward 51.35 - Mean Length 2099.0 - Mean Loss 0.015 - Mean Q Value 1.977 - Time Delta 45.611 - Time 2023-04-30T16:37:50
# Episode 1095 - tiger - Step 2327485 - Epsilon 0.5588515957063465 - Mean Reward 51.9 - Mean Length 2106.8 - Mean Loss 0.015 - Mean Q Value 1.979 - Time Delta 43.798 - Time 2023-04-30T16:38:33
# Episode 1096 - tiger - Step 2330146 - Epsilon 0.5584799432703921 - Mean Reward 52.09 - Mean Length 2105.25 - Mean Loss 0.015 - Mean Q Value 1.98 - Time Delta 41.216 - Time 2023-04-30T16:39:15
# Episode 1097 - deer - Step 5834220 - Epsilon 0.2325720562712909 - Mean Reward 0.0 - Mean Length 5391.86 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 368.067 - Time 2023-04-30T16:40:51
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_117.chkpt at step 5850000
# Episode 1098 - deer - Step 5855979 - Epsilon 0.2313103570457123 - Mean Reward 0.0 - Mean Length 5609.45 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 85.196 - Time 2023-04-30T16:42:16
# Episode 1099 - tiger - Step 2332459 - Epsilon 0.5581570955551363 - Mean Reward 51.58 - Mean Length 2075.04 - Mean Loss 0.015 - Mean Q Value 1.956 - Time Delta 237.476 - Time 2023-04-30T16:43:12
# Episode 1100 - tiger - Step 2334852 - Epsilon 0.5578232778941098 - Mean Reward 52.08 - Mean Length 2098.97 - Mean Loss 0.015 - Mean Q Value 1.982 - Time Delta 54.955 - Time 2023-04-30T16:44:07
# Episode 1101 - tiger - Step 2337493 - Epsilon 0.5574550965880364 - Mean Reward 51.96 - Mean Length 2097.76 - Mean Loss 0.015 - Mean Q Value 1.983 - Time Delta 56.551 - Time 2023-04-30T16:45:04
# Episode 1102 - tiger - Step 2340040 - Epsilon 0.5571002499971508 - Mean Reward 51.95 - Mean Length 2099.78 - Mean Loss 0.015 - Mean Q Value 1.983 - Time Delta 53.006 - Time 2023-04-30T16:45:57
# Episode 1103 - tiger - Step 2342693 - Epsilon 0.5567308757174019 - Mean Reward 52.07 - Mean Length 2104.19 - Mean Loss 0.015 - Mean Q Value 1.984 - Time Delta 53.336 - Time 2023-04-30T16:46:50
# Episode 1104 - tiger - Step 2344956 - Epsilon 0.5564159942655496 - Mean Reward 52.09 - Mean Length 2104.72 - Mean Loss 0.015 - Mean Q Value 1.985 - Time Delta 55.09 - Time 2023-04-30T16:47:45
# Episode 1105 - tiger - Step 2347449 - Epsilon 0.5560693159985785 - Mean Reward 52.09 - Mean Length 2105.25 - Mean Loss 0.015 - Mean Q Value 1.986 - Time Delta 53.272 - Time 2023-04-30T16:48:38
# Episode 1106 - deer - Step 5882762 - Epsilon 0.22976673415295662 - Mean Reward 0.0 - Mean Length 5426.3 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 486.267 - Time 2023-04-30T16:50:22
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_47.chkpt at step 2350000
# Episode 1107 - tiger - Step 2350026 - Epsilon 0.5557111836726856 - Mean Reward 51.6 - Mean Length 2084.65 - Mean Loss 0.015 - Mean Q Value 1.961 - Time Delta 162.321 - Time 2023-04-30T16:51:21
# Episode 1108 - tiger - Step 2352446 - Epsilon 0.5553750800461038 - Mean Reward 51.64 - Mean Length 2084.44 - Mean Loss 0.015 - Mean Q Value 1.963 - Time Delta 53.883 - Time 2023-04-30T16:52:14
# Episode 1109 - tiger - Step 2354632 - Epsilon 0.5550716504465758 - Mean Reward 52.02 - Mean Length 2106.3 - Mean Loss 0.016 - Mean Q Value 1.99 - Time Delta 56.496 - Time 2023-04-30T16:53:11
# Episode 1110 - tiger - Step 2357624 - Epsilon 0.5546566120438183 - Mean Reward 52.75 - Mean Length 2136.22 - Mean Loss 0.016 - Mean Q Value 2.017 - Time Delta 50.852 - Time 2023-04-30T16:54:02
# Episode 1111 - tiger - Step 2360219 - Epsilon 0.5542968952175029 - Mean Reward 52.63 - Mean Length 2135.33 - Mean Loss 0.016 - Mean Q Value 2.019 - Time Delta 53.763 - Time 2023-04-30T16:54:56
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_118.chkpt at step 5900000
# Episode 1112 - deer - Step 5906360 - Epsilon 0.22841521569712048 - Mean Reward 0.0 - Mean Length 5211.34 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 366.245 - Time 2023-04-30T16:56:28
# Episode 1113 - deer - Step 5928685 - Epsilon 0.22714392411359602 - Mean Reward 0.0 - Mean Length 5434.59 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 89.458 - Time 2023-04-30T16:57:58
# Episode 1114 - tiger - Step 2363187 - Epsilon 0.5538857594200388 - Mean Reward 51.55 - Mean Length 2086.04 - Mean Loss 0.016 - Mean Q Value 1.971 - Time Delta 236.32 - Time 2023-04-30T16:58:52
# Episode 1115 - tiger - Step 2365596 - Epsilon 0.553552282108132 - Mean Reward 51.54 - Mean Length 2086.38 - Mean Loss 0.016 - Mean Q Value 1.974 - Time Delta 58.729 - Time 2023-04-30T16:59:51
# Episode 1116 - tiger - Step 2368318 - Epsilon 0.5531757178735479 - Mean Reward 51.48 - Mean Length 2089.47 - Mean Loss 0.016 - Mean Q Value 1.976 - Time Delta 59.448 - Time 2023-04-30T17:00:50
# Episode 1117 - tiger - Step 2370847 - Epsilon 0.5528260830221328 - Mean Reward 51.43 - Mean Length 2087.56 - Mean Loss 0.016 - Mean Q Value 1.979 - Time Delta 55.736 - Time 2023-04-30T17:01:46
# Episode 1118 - tiger - Step 2373360 - Epsilon 0.5524788790688867 - Mean Reward 51.92 - Mean Length 2112.69 - Mean Loss 0.016 - Mean Q Value 2.007 - Time Delta 56.109 - Time 2023-04-30T17:02:42
# Episode 1119 - tiger - Step 2375590 - Epsilon 0.5521709578962771 - Mean Reward 52.43 - Mean Length 2134.99 - Mean Loss 0.016 - Mean Q Value 2.035 - Time Delta 56.001 - Time 2023-04-30T17:03:38
# Episode 1120 - tiger - Step 2377904 - Epsilon 0.5518516193347577 - Mean Reward 52.3 - Mean Length 2134.73 - Mean Loss 0.016 - Mean Q Value 2.038 - Time Delta 55.021 - Time 2023-04-30T17:04:33
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_119.chkpt at step 5950000
# Episode 1121 - deer - Step 5952390 - Epsilon 0.22580179309535497 - Mean Reward 0.0 - Mean Length 5230.04 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 490.045 - Time 2023-04-30T17:06:08
# Episode 1122 - deer - Step 5977012 - Epsilon 0.2244161390564963 - Mean Reward 0.0 - Mean Length 5476.26 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 98.333 - Time 2023-04-30T17:07:46
# Episode 1123 - tiger - Step 2381077 - Epsilon 0.551414036562175 - Mean Reward 51.67 - Mean Length 2090.39 - Mean Loss 0.016 - Mean Q Value 1.99 - Time Delta 238.818 - Time 2023-04-30T17:08:32
# Episode 1124 - tiger - Step 2384050 - Epsilon 0.5510043502967492 - Mean Reward 52.45 - Mean Length 2120.12 - Mean Loss 0.016 - Mean Q Value 2.018 - Time Delta 49.149 - Time 2023-04-30T17:09:21
# Episode 1125 - tiger - Step 2387127 - Epsilon 0.5505806531326769 - Mean Reward 52.93 - Mean Length 2129.93 - Mean Loss 0.016 - Mean Q Value 2.021 - Time Delta 44.233 - Time 2023-04-30T17:10:05
# Episode 1126 - tiger - Step 2390110 - Epsilon 0.5501702106220143 - Mean Reward 53.22 - Mean Length 2133.26 - Mean Loss 0.016 - Mean Q Value 2.024 - Time Delta 44.365 - Time 2023-04-30T17:10:49
# Episode 1127 - tiger - Step 2392940 - Epsilon 0.5497811028124249 - Mean Reward 53.51 - Mean Length 2136.45 - Mean Loss 0.016 - Mean Q Value 2.026 - Time Delta 40.569 - Time 2023-04-30T17:11:30
# Episode 1128 - tiger - Step 2395828 - Epsilon 0.5493843040681226 - Mean Reward 53.74 - Mean Length 2137.3 - Mean Loss 0.016 - Mean Q Value 2.029 - Time Delta 45.099 - Time 2023-04-30T17:12:15
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_120.chkpt at step 6000000
# Episode 1129 - deer - Step 6003325 - Epsilon 0.22294471839819638 - Mean Reward 0.0 - Mean Length 5503.51 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 373.058 - Time 2023-04-30T17:13:59
# Episode 1130 - tiger - Step 2398375 - Epsilon 0.549034594919211 - Mean Reward 53.73 - Mean Length 2137.72 - Mean Loss 0.016 - Mean Q Value 2.031 - Time Delta 157.337 - Time 2023-04-30T17:14:52
# Animal saved to tiger_checkpoints\2023-04-29T20-43-55\animal_net_48.chkpt at step 2400000
# Episode 1131 - tiger - Step 2401250 - Epsilon 0.5486401180368631 - Mean Reward 54.33 - Mean Length 2166.47 - Mean Loss 0.016 - Mean Q Value 2.059 - Time Delta 54.003 - Time 2023-04-30T17:15:46
# Episode 1132 - tiger - Step 2404120 - Epsilon 0.5482466098908567 - Mean Reward 54.13 - Mean Length 2167.74 - Mean Loss 0.016 - Mean Q Value 2.062 - Time Delta 54.308 - Time 2023-04-30T17:16:41
# Episode 1133 - tiger - Step 2406729 - Epsilon 0.5478891325897806 - Mean Reward 53.68 - Mean Length 2162.81 - Mean Loss 0.017 - Mean Q Value 2.064 - Time Delta 55.972 - Time 2023-04-30T17:17:37
# Episode 1134 - deer - Step 6028252 - Epsilon 0.22155970249464754 - Mean Reward 0.0 - Mean Length 5343.42 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 320.391 - Time 2023-04-30T17:19:20
# Episode 1135 - deer - Step 6049982 - Epsilon 0.22035934269004165 - Mean Reward 0.0 - Mean Length 5560.72 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 89.928 - Time 2023-04-30T17:20:50
# Episode 1136 - tiger - Step 2409313 - Epsilon 0.5475353104627015 - Mean Reward 51.58 - Mean Length 2096.81 - Mean Loss 0.016 - Mean Q Value 2.015 - Time Delta 251.753 - Time 2023-04-30T17:21:49
# Episode 1137 - tiger - Step 2411811 - Epsilon 0.5471934813657855 - Mean Reward 51.4 - Mean Length 2096.75 - Mean Loss 0.016 - Mean Q Value 2.018 - Time Delta 54.741 - Time 2023-04-30T17:22:43
# Episode 1138 - tiger - Step 2414000 - Epsilon 0.5468941116181624 - Mean Reward 51.77 - Mean Length 2118.64 - Mean Loss 0.016 - Mean Q Value 2.046 - Time Delta 59.671 - Time 2023-04-30T17:23:43
# Episode 1139 - tiger - Step 2416122 - Epsilon 0.5466040611983284 - Mean Reward 52.13 - Mean Length 2139.86 - Mean Loss 0.017 - Mean Q Value 2.075 - Time Delta 56.363 - Time 2023-04-30T17:24:39
# Episode 1140 - tiger - Step 2418359 - Epsilon 0.5462984583010352 - Mean Reward 51.68 - Mean Length 2132.87 - Mean Loss 0.017 - Mean Q Value 2.078 - Time Delta 56.946 - Time 2023-04-30T17:25:36
# Episode 1141 - tiger - Step 2420891 - Epsilon 0.545952760758484 - Mean Reward 51.52 - Mean Length 2130.26 - Mean Loss 0.017 - Mean Q Value 2.08 - Time Delta 52.491 - Time 2023-04-30T17:26:29
# Episode 1142 - tiger - Step 2423451 - Epsilon 0.5456034627351773 - Mean Reward 51.13 - Mean Length 2127.08 - Mean Loss 0.017 - Mean Q Value 2.083 - Time Delta 62.238 - Time 2023-04-30T17:27:31
# Episode 1143 - tiger - Step 2425864 - Epsilon 0.5452744266605942 - Mean Reward 50.95 - Mean Length 2125.47 - Mean Loss 0.017 - Mean Q Value 2.087 - Time Delta 60.686 - Time 2023-04-30T17:28:32
# Animal saved to deer_checkpoints\2023-04-29T20-43-55\animal_net_121.chkpt at step 6050000
# Episode 1144 - deer - Step 6073315 - Epsilon 0.21907767317750818 - Mean Reward 0.0 - Mean Length 5335.61 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 556.442 - Time 2023-04-30T17:30:06
# Episode 1145 - deer - Step 6098692 - Epsilon 0.2176921890519901 - Mean Reward 0.0 - Mean Length 5589.38 - Mean Loss 0.0 - Mean Q Value -0.0 - Time Delta 101.717 - Time 2023-04-30T17:31:48
# Episode 1146 - tiger - Step 2428533 - Epsilon 0.5449107136111512 - Mean Reward 49.08 - Mean Length 2059.04 - Mean Loss 0.016 - Mean Q Value 2.038 - Time Delta 244.586 - Time 2023-04-30T17:32:36
# Episode 1147 - tiger - Step 2431498 - Epsilon 0.5445069481582188 - Mean Reward 49.91 - Mean Length 2088.69 - Mean Loss 0.017 - Mean Q Value 2.068 - Time Delta 47.764 - Time 2023-04-30T17:33:24
# Episode 1148 - tiger - Step 2433882 - Epsilon 0.5441825186661087 - Mean Reward 50.57 - Mean Length 2112.53 - Mean Loss 0.017 - Mean Q Value 2.097 - Time Delta 50.436 - Time 2023-04-30T17:34:14
# Episode 1149 - tiger - Step 2436476 - Epsilon 0.5438297306624807 - Mean Reward 50.77 - Mean Length 2113.37 - Mean Loss 0.017 - Mean Q Value 2.101 - Time Delta 46.53 - Time 2023-04-30T17:35:01
# Episode 1150 - tiger - Step 2439396 - Epsilon 0.5434328797776338 - Mean Reward 50.97 - Mean Length 2118.53 - Mean Loss 0.017 - Mean Q Value 2.105 - Time Delta 48.777 - Time 2023-04-30T17:35:50
# Episode 1151 - tiger - Step 2441856 - Epsilon 0.5430987712636582 - Mean Reward 50.97 - Mean Length 2119.38 - Mean Loss 0.017 - Mean Q Value 2.108 - Time Delta 54.579 - Time 2023-04-30T17:36:44

# %% [markdown]
# ### Visualize Trained Model

# %%
env = tiger_deer_v4.env(map_size=map_size, minimap_mode=False, render_mode='human', max_cycles=max_cycles, extra_features=True)
example_episodes = 10
for e in range(example_episodes):
    print("Episode: ", e)
    env.reset(seed=None)
    state = np.transpose(env.state(),(2,0,1))
    deer_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    tiger_env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    env_map = np.ones((2, state.shape[1], state.shape[2]))*-1
    deer_prev_data = {}
    tiger_prev_data = {}
    # Play the game!
    previousAgent = {'id':None, 'name': None, 'actual_action':None, 'prev_ind':None}
    for agent in env.agent_iter():

        agentType = get_agent_type_from_agent_name(agent)
        agent_id = agent_name_to_id(agent)
        # print("Agent id: ", agent_id)
        
        observation, reward, termination, truncation, info = env.last()
        done = termination or truncation

        if done:
            env.step(None)
            continue
        
        state = np.transpose(env.state(),(2,0,1))
        state_with_ids = convert_numpy_binary_to_integer(state[5:13,:,:])
        env_map[0,:,:] = np.ones_like(env_map[0,:,:])*-1
        deer_mask = state[1,:,:] > 0
        tiger_mask = state[3,:,:] > 0
        mask = deer_mask | tiger_mask
        env_map[0,:,:][mask] = state_with_ids[:,:][mask]
        env_map[0,:,:][~mask] = -1
        env_map[1,:,:][~mask] = -1
        

        if previousAgent['id'] is not None:
            position_indices = np.where(env_map[0,:,:] == previousAgent['id'])
            env_map[1, position_indices[0], position_indices[1]] = previousAgent['actual_action']
            previousAgent['id'] = None

        
        mask = env_map[0,:,:] < indexOfFirstTiger
        deer_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        deer_env_map[0,:,:][~mask] = -1
        deer_env_map[1,:,:][mask] = env_map[1,:,:][mask]

        mask = ~mask
        tiger_env_map[0,:,:][mask] = env_map[0,:,:][mask]
        tiger_env_map[0,:,:][~mask] = -1
        tiger_env_map[1,:,:][mask] = env_map[1,:,:][mask]


        if 'tiger' in agentType:
            agents_prev_data = tiger_prev_data
            animal = tiger
            action_mapper = tiger_action_mapper
            animal_env_map = tiger_env_map
            actual_num_actions = actual_tiger_actions
        else:
            agents_prev_data = deer_prev_data
            animal = deer
            action_mapper = deer_action_mapper
            animal_env_map = deer_env_map
            actual_num_actions = actual_deer_actions

        # print("Env map",env_map)
        # print("Animal Env map",animal_env_map)
        observation = handle_observations(observation, obs_indices_to_keep, agent_id, animal_env_map, actual_num_actions)
        
        
        action = None
        actual_action = None

        # instantiate previous data
        if agent not in agents_prev_data.keys():
            action, actual_action, prev_actual_action = generate_first_action(agentType)
            mask_observations(observation, prev_actual_action)
            hidden = None
            cell = None
        else:
            mask_observations(observation, prev_actual_action)
            action, (hidden, cell) = animal.act(observation, hidden, cell, activeAnimal)
            actual_action = action_mapper(action, prev_actual_action)

        # update previous agent
        previousAgent['id'] = agent_name_to_id(agent)
        previousAgent['name'] = agent
        previousAgent['actual_action'] = actual_action
        previousAgent['prev_ind'] = np.where(env_map[0,:,:] == previousAgent['id'])
        
        # save previous data
        agents_prev_data[agent] = [observation, action, done, actual_action, hidden, cell, reward,  info]

        # step the function to next agent
        env.step(actual_action)
# Out:
# Episode:  0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# deer_save_dir=
# tiger_save_dir=
deer2 = Animal(state_dim=deer_observation_shape, action_dim=deer_action_space, save_dir=deer_save_dir)
tiger2 = Animal(state_dim=tiger_observation_shape, action_dim=tiger_action_space, save_dir=tiger_save_dir)

deer2.load("deer_checkpoints\\2023-04-26T22-43-08\\animal_net_8.chkpt")
tiger2.load("tiger_checkpoints\\2023-04-26T22-43-08\\animal_net_2.chkpt")
# Out:
# odict_keys(['online.0.weight', 'online.0.bias', 'online.2.weight', 'online.2.bias', 'online.4.weight', 'online.4.bias', 'online.6.weight', 'online.6.bias', 'online.9.weight', 'online.9.bias', 'online.11.lstm.weight_ih_l0', 'online.11.lstm.weight_hh_l0', 'online.11.lstm.bias_ih_l0', 'online.11.lstm.bias_hh_l0', 'online.13.weight', 'online.13.bias', 'target.0.weight', 'target.0.bias', 'target.2.weight', 'target.2.bias', 'target.4.weight', 'target.4.bias', 'target.6.weight', 'target.6.bias', 'target.9.weight', 'target.9.bias', 'target.11.lstm.weight_ih_l0', 'target.11.lstm.weight_hh_l0', 'target.11.lstm.bias_ih_l0', 'target.11.lstm.bias_hh_l0', 'target.13.weight', 'target.13.bias'])
# odict_keys(['online.0.weight', 'online.0.bias', 'online.2.weight', 'online.2.bias', 'online.4.weight', 'online.4.bias', 'online.6.weight', 'online.6.bias', 'online.9.weight', 'online.9.bias', 'online.11.lstm.weight_ih_l0', 'online.11.lstm.weight_hh_l0', 'online.11.lstm.bias_ih_l0', 'online.11.lstm.bias_hh_l0', 'online.13.weight', 'online.13.bias', 'target.0.weight', 'target.0.bias', 'target.2.weight', 'target.2.bias', 'target.4.weight', 'target.4.bias', 'target.6.weight', 'target.6.bias', 'target.9.weight', 'target.9.bias', 'target.11.lstm.weight_ih_l0', 'target.11.lstm.weight_hh_l0', 'target.11.lstm.bias_ih_l0', 'target.11.lstm.bias_hh_l0', 'target.13.weight', 'target.13.bias'])
